# %% [markdown]
# # Notebook on segmentation of cluster of cells
#
# Author : Aaron MAMANN

# %% [markdown]
# ## Libraries

# %%
import os
import PIL
from PIL import Image, ImageOps, ImageEnhance, __version__ as PILLOW_VERSION
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
import re
import random
from natsort import natsorted
import glob
from skimage import img_as_ubyte
import skimage 
from skimage.transform import rescale, resize, downscale_local_mean
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision 
from torchvision import transforms
from torchmetrics import Dice
import shutil
import cv2
import csv
from skimage.measure import label, regionprops, regionprops_table
import tifffile
import tifffile as tiff
from pathlib import Path
from tqdm.notebook import tqdm

# %%
from torchmetrics import Accuracy
import torch
target = torch.tensor([[False, True, False, True],[False, True, False, True]])
preds = torch.tensor([[True, False, True, True],[False, True, False, True]])
accuracy = Accuracy(mdmc_reduce='global',num_classes=2,average='none')
#accuracy = Dice(num_classes=2,mdmc_reduce='global',average='none')
accuracy(preds, target)
# Out:
# tensor([0.5000, 0.7500])

# %% [markdown]
# ## Main Function : Galbor Filter with specific Preprocessing and PostProcessing Functions

# %%
def create_masks(file_dir,image_files_name,mask_files_name,gabor_parameter,fill_cells,experiment_name='CNV',save_predicted_mask=True,compute_score=True,ratio_first_thresh=300/(1920*1440),ratio_small_object_thresh=3700/(1920*1440),ratio_thresh_big_objects=30000/(1920*1440),ratio_canal_diameter=100/1440 ):

    experiment_types_dir = [  "".join([file_dir,'/',f]) for f in natsorted(os.listdir(file_dir)) if experiment_name in f]  
    
    if compute_score : 
        score_experiment=dict()
    
    for type_dir in experiment_types_dir:
        l=0
        conditions_experiment= [  f for f in natsorted(os.listdir(type_dir) ) if experiment_name in f]    
        for condition in conditions_experiment : 
            sequences=[ "".join([type_dir,'/',condition,'/',image_files_name,'/',f]) for f in  natsorted(os.listdir( "".join([type_dir,'/',condition,'/',image_files_name]) )) if experiment_name in f]
            if save_predicted_mask :         
                Path("".join([type_dir,'/',condition,'/masks_predicted/'])).mkdir(parents=True, exist_ok=True)
                                              
            for sequence in sequences:
          
                images_in_tiff = tifffile.imread(sequence)              
                if np.ndim(images_in_tiff)==2 :
                    images_in_tiff = np.expand_dims(images_in_tiff, axis=0)
                nb_images_in_tiff = len(images_in_tiff)
                predicted_mask=list()
            
                if compute_score : 
                    masks_in_tiff = tifffile.imread( "".join([type_dir,'/',condition,'/',mask_files_name,'/',os.path.basename(sequence).replace(".tif", "_mask.tif") ]) )
                    if np.ndim(masks_in_tiff)==2 :
                        masks_in_tiff = np.expand_dims(masks_in_tiff, axis=0)
                    score_sequence=0
            
                j=0         
                for index_one_image in range(nb_images_in_tiff): 
                    nb_pixels=images_in_tiff[index_one_image].shape[0]*images_in_tiff[index_one_image].shape[1]
                    nb_vertical_pixels=images_in_tiff[index_one_image].shape[0]
                    thresh_small_objects=ratio_small_object_thresh*nb_pixels
                    first_thresh=ratio_first_thresh*nb_pixels
                    im_original=skimage.morphology.remove_small_objects(scipy.ndimage.binary_fill_holes(skimage.morphology.binary_closing(skimage.morphology.remove_small_objects(scipy.ndimage.binary_fill_holes(skimage.filters.gabor(img_as_ubyte(skimage.exposure.rescale_intensity(images_in_tiff[index_one_image])),gabor_parameter)[1]),min_size=first_thresh, connectivity=1),footprint=np.ones((fill_cells,fill_cells)))),min_size=thresh_small_objects,connectivity=1)
                    im_original = img_as_ubyte(im_original)
                    labeled_im = label(im_original)

                    canal_diameter=ratio_canal_diameter*nb_vertical_pixels 
                    props = regionprops(labeled_im)
                    for i in range(len(props)) :
                        if abs(props[i].bbox[2]-props[i].bbox[0])>canal_diameter :
                            im_original[props[i].bbox[0]:props[i].bbox[2]+1,props[i].bbox[1]:props[i].bbox[3]+1] = 0
        
                    im_original=img_as_ubyte(skimage.morphology.remove_small_objects(np.array(im_original,dtype=bool),min_size=thresh_small_objects,connectivity=1))
                    new_image=img_as_ubyte(np.pad(im_original, (50, 50),'constant',constant_values=255))  
                    thresh_big_objects=ratio_thresh_big_objects*nb_pixels 
                    im_big_objects=img_as_ubyte(skimage.morphology.remove_small_objects(np.array(np.pad(im_original, (50, 50), 'constant', constant_values=255),dtype=bool),min_size=thresh_big_objects)) 
                    new_image = new_image - im_big_objects
                    shape_im = new_image.shape
                    new_image=new_image[50:shape_im[0]-50,50:shape_im[1]-50]   
                    if compute_score : 
                        true_mask = img_as_ubyte(masks_in_tiff[index_one_image])
                        #accuracy = Accuracy(mdmc_reduce='global',num_classes=2,average='none')
                        #accuracy(preds, target)
                        dice = Dice(average=None,num_classes=2)
                        score_sequence = score_sequence + dice(torch.where(torch.from_numpy(new_image)> 0, True, False), torch.where(torch.from_numpy(true_mask)> 0, True, False)).numpy()[1]    
                                                                         
                    if j==0:
                        predicted_mask=[np.array(new_image, dtype=np.uint16)]                 
                    else:
                        predicted_mask=np.append(predicted_mask,[np.array(new_image, dtype=np.uint16)],axis=0)
                    j=j+1
                 
                if save_predicted_mask :       
                    tiff.imsave("".join([type_dir,'/',condition,'/masks_predicted/',os.path.basename(sequence)]),predicted_mask)
            
                if compute_score : 
                    score_sequence = score_sequence/nb_images_in_tiff
                    score_experiment[sequence] = score_sequence
                l=l+1
                if compute_score : 
                    print("".join([os.path.basename(type_dir),',',condition,': Tiff ',str(os.path.basename(sequence).replace(".tif", " ")),'segmented (Tiff n°', str(l) ,'), gabor param ',str(gabor_parameter), ', fill param ', str(fill_cells), ', score: ', str(round(score_sequence, 4)) ]))        
    if compute_score : 
        return score_experiment

# %%
# Clémence you have to simulate that, the following part is the training and the test which allowed to find the value of gabor parameter (equal to 0.78)
# and the value of the fill cell parameter (equal to 5) 

file_dir='//Users/clemence/Documents_Clémence/Analysis/Tracking algorithm/Tracking-seg_Aaron-Gus_CNV/To run/CNV_valid_visuelle' # change this into your own path
image_files_name = 'Source images'
mask_files_name = 'Masks'

create_masks(file_dir,image_files_name,mask_files_name,gabor_parameter=0.78,fill_cells=8,save_predicted_mask=True,compute_score=False)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/skimage/util/dtype.py:541: UserWarning: Downcasting uint16 to uint8 without scaling because max value 255 fits in uint8
#   return _convert(image, np.uint8, force_copy)
# /var/folders/t9/fgr9lrds0dvgw45q0n6x3xfm0000gn/T/ipykernel_50421/27085817.py:67: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   tiff.imsave("".join([type_dir,'/',condition,'/masks_predicted/',os.path.basename(sequence)]),predicted_mask)
# CNV_toutValid,CNV1: Tiff CNV006_20210430_782_t8 segmented (Tiff n°1), gabor param 0.78, fill param 5, score: 0.8529
# CNV_toutValid,CNV1: Tiff CNV006_20210430_787_t8 segmented (Tiff n°2), gabor param 0.78, fill param 5, score: 0.7381
# CNV_toutValid,CNV1: Tiff CNV006_20210430_791_t8 segmented (Tiff n°3), gabor param 0.78, fill param 5, score: 0.856
# CNV_toutValid,CNV1: Tiff CNV006_20210430_793_t8 segmented (Tiff n°4), gabor param 0.78, fill param 5, score: 0.8054
# CNV_toutValid,CNV1: Tiff CNV010_20210606_065_t1 segmented (Tiff n°5), gabor param 0.78, fill param 5, score: 0.8955
# CNV_toutValid,CNV1: Tiff CNV010_20210606_065_t25 segmented (Tiff n°6), gabor param 0.78, fill param 5, score: 0.848
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [12], line 8
#       5 image_files_name = 'Source images'
#       6 mask_files_name = 'Masks'
# ----> 8 create_masks(file_dir,image_files_name,mask_files_name,gabor_parameter=0.78,fill_cells=5,save_predicted_mask=True,compute_score=True)
#
# Cell In [11], line 36, in create_masks(file_dir, image_files_name, mask_files_name, gabor_parameter, fill_cells, experiment_name, save_predicted_mask, compute_score, ratio_first_thresh, ratio_small_object_thresh, ratio_thresh_big_objects, ratio_canal_diameter)
#      34 thresh_small_objects=ratio_small_object_thresh*nb_pixels
#      35 first_thresh=ratio_first_thresh*nb_pixels
# ---> 36 im_original=skimage.morphology.remove_small_objects(scipy.ndimage.binary_fill_holes(skimage.morphology.binary_closing(skimage.morphology.remove_small_objects(scipy.ndimage.binary_fill_holes(skimage.filters.gabor(img_as_ubyte(skimage.exposure.rescale_intensity(images_in_tiff[index_one_image])),gabor_parameter)[1]),min_size=first_thresh, connectivity=1),footprint=np.ones((fill_cells,fill_cells)))),min_size=thresh_small_objects,connectivity=1)
#      37 im_original = img_as_ubyte(im_original)
#      38 labeled_im = label(im_original)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/skimage/morphology/misc.py:39, in default_footprint.<locals>.func_out(image, footprint, *args, **kwargs)
#      37 if footprint is None:
#      38     footprint = _default_footprint(image.ndim)
# ---> 39 return func(image, footprint=footprint, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/skimage/_shared/utils.py:282, in deprecate_kwarg.__call__.<locals>.fixed_func(*args, **kwargs)
#     279         kwargs[new_arg] = kwargs.pop(old_arg)
#     281 # Call the function with the fixed arguments
# --> 282 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/skimage/morphology/binary.py:155, in binary_closing(image, footprint, out)
#     124 @default_footprint
#     125 @deprecate_kwarg(kwarg_mapping={'selem': 'footprint'}, removed_version="1.0",
#     126                  deprecated_version="0.19")
#     127 def binary_closing(image, footprint=None, out=None):
#     128     """Return fast binary morphological closing of an image.
#     129
#     130     This function returns the same result as grayscale closing but performs
#    (...)
#     153
#     154     """
# --> 155     dilated = binary_dilation(image, footprint)
#     156     out = binary_erosion(dilated, footprint, out=out)
#     157     return out
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/skimage/morphology/misc.py:39, in default_footprint.<locals>.func_out(image, footprint, *args, **kwargs)
#      37 if footprint is None:
#      38     footprint = _default_footprint(image.ndim)
# ---> 39 return func(image, footprint=footprint, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/skimage/_shared/utils.py:282, in deprecate_kwarg.__call__.<locals>.fixed_func(*args, **kwargs)
#     279         kwargs[new_arg] = kwargs.pop(old_arg)
#     281 # Call the function with the fixed arguments
# --> 282 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/skimage/morphology/binary.py:84, in binary_dilation(image, footprint, out)
#      82 if out is None:
#      83     out = np.empty(image.shape, dtype=bool)
# ---> 84 ndi.binary_dilation(image, structure=footprint, output=out)
#      85 return out
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/ndimage/_morphology.py:517, in binary_dilation(input, structure, iterations, mask, output, border_value, origin, brute_force)
#     514     if not structure.shape[ii] & 1:
#     515         origin[ii] -= 1
# --> 517 return _binary_erosion(input, structure, iterations, mask,
#     518                        output, border_value, origin, 1, brute_force)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/ndimage/_morphology.py:253, in _binary_erosion(input, structure, iterations, mask, output, border_value, origin, invert, brute_force)
#     251     output = _ni_support._get_output(output.dtype, input)
#     252 if iterations == 1:
# --> 253     _nd_image.binary_erosion(input, structure, mask, output,
#     254                              border_value, origin, invert, cit, 0)
#     255 elif cit and not brute_force:
#     256     changed, coordinate_list = _nd_image.binary_erosion(
#     257         input, structure, mask, output,
#     258         border_value, origin, invert, cit, 1)
#
# KeyboardInterrupt:

# %% [markdown]
# # Allocate randomly .tif file into the training set and the test set

# %%
# This function moves some tif files into a file used for training (tuning the gabor parameter, 
# fill parameter, minimum number of pixels parameter) and into another file used for testing

def create_training_and_test_files_for_each_experiment(file_dir,image_files_name,mask_files_name,experiment_name='CNV'):
                 
    l=0
    sequences=[ "".join([file_dir,'/',image_files_name,'/',f]) for f in  natsorted(os.listdir( "".join([file_dir,'/',image_files_name]) )) if experiment_name in f]
    training_set=random.sample(sequences, k=int(len(sequences)*0.7))
    test_set=list(set(sequences) - set(training_set))
    
    Path("".join([file_dir,'/training/CNV_mutiples/Source images/'])).mkdir(parents=True, exist_ok=True)
    Path("".join([file_dir,'/training/CNV_mutiples/Masks/'])).mkdir(parents=True, exist_ok=True)
    
    for sequence in training_set:
        os.replace(sequence, "".join([file_dir,'/training/CNV_mutiples/Source images/',os.path.basename(sequence)]))
        os.replace( "".join([file_dir,'/',mask_files_name,'/',os.path.basename(sequence).replace(".tif", "_mask.tif") ]), "".join([file_dir,'/training/CNV_mutiples/Masks/',os.path.basename(sequence).replace(".tif", "_mask.tif") ]))
        
    Path("".join([file_dir,'/test/CNV_mutiples/Source images/'])).mkdir(parents=True, exist_ok=True)
    Path("".join([file_dir,'/test/CNV_mutiples/Masks/'])).mkdir(parents=True, exist_ok=True)
    
    for sequence in test_set:
        os.replace(sequence, "".join([file_dir,'/test/CNV_mutiples/Source images/',os.path.basename(sequence)]))
        os.replace( "".join([file_dir,'/',mask_files_name,'/',os.path.basename(sequence).replace(".tif", "_mask.tif") ]), "".join([file_dir,'/test/CNV_mutiples/Masks/',os.path.basename(sequence).replace(".tif", "_mask.tif") ]))
     
    shutil.rmtree("".join([file_dir,'/',image_files_name]) ) 
    shutil.rmtree("".join([file_dir,'/',mask_files_name]) )

# %%
# We execute this function to create a training file (with images and masks) and a test file (with images and masks)

file_dir='/Users/aaronmamann/Desktop/Cleaned_Datasets_Clemence/Validation' # change this into your own path
create_training_and_test_files_for_each_experiment(file_dir=file_dir,image_files_name='Source images',mask_files_name='Masks',experiment_name='CNV')

# %% [markdown]
# ## Tuning hyperparameters (gabor, fill, number pixels for mask) on training set

# %%
file_dir = '/Users/clemence/Documents_Clémence/Analysis/Tracking algorithm/Training data set/230113-CNV-optimization' # change this into your own path
image_files_name = 'Source images'
mask_files_name = 'Masks'
# We are going to tune jointly the gabor parameter and the fill parameter on the training set

hyperparameter_candidates = [[0.78,8],[0.80,8],[0.82,8],[0.84,8],[0.86,8],[0.88,8],[0.90,8],[0.92,8]]
dice_score_hyperparameters = list(map(lambda x: [x[0],x[1],np.array(list(create_masks(file_dir,image_files_name,mask_files_name,gabor_parameter=x[0],fill_cells=x[1],save_predicted_mask=False).values())).mean() ] , hyperparameter_candidates))
df_dice_scores=pd.DataFrame(dice_score_hyperparameters)
df_dice_scores.columns = ['gabor_param', 'fill_param', 'Dice scores']
df_dice_scores
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/skimage/util/dtype.py:541: UserWarning: Downcasting uint16 to uint8 without scaling because max value 255 fits in uint8
#   return _convert(image, np.uint8, force_copy)
# CNV_toutValid,CNV1: Tiff CNV006_20210430_782_t8 segmented (Tiff n°1), gabor param 0.78, fill param 8, score: 0.8513
# CNV_toutValid,CNV1: Tiff CNV006_20210430_787_t8 segmented (Tiff n°2), gabor param 0.78, fill param 8, score: 0.779
# CNV_toutValid,CNV1: Tiff CNV006_20210430_791_t8 segmented (Tiff n°3), gabor param 0.78, fill param 8, score: 0.8568
# CNV_toutValid,CNV1: Tiff CNV006_20210430_793_t8 segmented (Tiff n°4), gabor param 0.78, fill param 8, score: 0.7052
# CNV_toutValid,CNV1: Tiff CNV010_20210606_065_t1 segmented (Tiff n°5), gabor param 0.78, fill param 8, score: 0.8919
# CNV_toutValid,CNV1: Tiff CNV010_20210606_065_t25 segmented (Tiff n°6), gabor param 0.78, fill param 8, score: 0.8465
# CNV_toutValid,CNV1: Tiff CNV010_20210606_066_t1 segmented (Tiff n°7), gabor param 0.78, fill param 8, score: 0.8373
# CNV_toutValid,CNV1: Tiff CNV010_20210606_066_t24 segmented (Tiff n°8), gabor param 0.78, fill param 8, score: 0.9019
# CNV_toutValid,CNV1: Tiff CNV010_20210606_067_t1 segmented (Tiff n°9), gabor param 0.78, fill param 8, score: 0.9199
# CNV_toutValid,CNV1: Tiff CNV010_20210606_067_t25 segmented (Tiff n°10), gabor param 0.78, fill param 8, score: 0.7081
# CNV_toutValid,CNV1: Tiff CNV010_20210606_072_t1 segmented (Tiff n°11), gabor param 0.78, fill param 8, score: 0.8061
# CNV_toutValid,CNV1: Tiff CNV010_20210606_072_t25 segmented (Tiff n°12), gabor param 0.78, fill param 8, score: 0.6222
# CNV_toutValid,CNV1: Tiff CNV010_20210606_095_t7 segmented (Tiff n°13), gabor param 0.78, fill param 8, score: 0.8919
# CNV_toutValid,CNV1: Tiff CNV010_20210606_095_t31 segmented (Tiff n°14), gabor param 0.78, fill param 8, score: 0.8927
# CNV_toutValid,CNV1: Tiff CNV010_20210606_095_t49 segmented (Tiff n°15), gabor param 0.78, fill param 8, score: 0.9112
# CNV_toutValid,CNV1: Tiff CNV010_20210606_111_t31 segmented (Tiff n°16), gabor param 0.78, fill param 8, score: 0.8528
# CNV_toutValid,CNV1: Tiff CNV010_20210606_111_t49 segmented (Tiff n°17), gabor param 0.78, fill param 8, score: 0.8701
# CNV_toutValid,CNV1: Tiff CNV010_20210606_137_t7 segmented (Tiff n°18), gabor param 0.78, fill param 8, score: 0.8882
# CNV_toutValid,CNV1: Tiff CNV010_20210606_137_t31 segmented (Tiff n°19), gabor param 0.78, fill param 8, score: 0.7932
# CNV_toutValid,CNV1: Tiff CNV010_20210606_137_t49 segmented (Tiff n°20), gabor param 0.78, fill param 8, score: 0.8799
# CNV_toutValid,CNV1: Tiff CNV010_20210606_156_t7 segmented (Tiff n°21), gabor param 0.78, fill param 8, score: 0.831
# CNV_toutValid,CNV1: Tiff CNV010_20210606_156_t31 segmented (Tiff n°22), gabor param 0.78, fill param 8, score: 0.7773
# CNV_toutValid,CNV1: Tiff CNV010_20210606_156_t49 segmented (Tiff n°23), gabor param 0.78, fill param 8, score: 0.6633
# CNV_toutValid,CNV1: Tiff CNV011_20210612_205_t1 segmented (Tiff n°24), gabor param 0.78, fill param 8, score: 0.788
# CNV_toutValid,CNV1: Tiff CNV011_20210612_205_t25 segmented (Tiff n°25), gabor param 0.78, fill param 8, score: 0.7962
# CNV_toutValid,CNV1: Tiff CNV011_20210612_219_t1 segmented (Tiff n°26), gabor param 0.78, fill param 8, score: 0.8389
# CNV_toutValid,CNV1: Tiff CNV011_20210612_219_t49 segmented (Tiff n°27), gabor param 0.78, fill param 8, score: 0.7963
# CNV_toutValid,CNV1: Tiff CNV011_20210612_221_t1 segmented (Tiff n°28), gabor param 0.78, fill param 8, score: 0.7973
# CNV_toutValid,CNV1: Tiff CNV011_20210612_221_t49 segmented (Tiff n°29), gabor param 0.78, fill param 8, score: 0.7532
# CNV_toutValid,CNV1: Tiff CNV012_20210618_409_t1 segmented (Tiff n°30), gabor param 0.78, fill param 8, score: 0.8862
# CNV_toutValid,CNV1: Tiff CNV012_20210618_409_t49 segmented (Tiff n°31), gabor param 0.78, fill param 8, score: 0.8369
# CNV_toutValid,CNV1: Tiff CNV012_20210618_410_t1 segmented (Tiff n°32), gabor param 0.78, fill param 8, score: 0.8801
# CNV_toutValid,CNV1: Tiff CNV012_20210618_410_t49 segmented (Tiff n°33), gabor param 0.78, fill param 8, score: 0.8801
# CNV_toutValid,CNV1: Tiff CNV015_20210717_108_t1 segmented (Tiff n°34), gabor param 0.78, fill param 8, score: 0.847
# CNV_toutValid,CNV1: Tiff CNV015_20210717_108_t13 segmented (Tiff n°35), gabor param 0.78, fill param 8, score: 0.9036
# CNV_toutValid,CNV1: Tiff CNV015_20210717_108_t23 segmented (Tiff n°36), gabor param 0.78, fill param 8, score: 0.903
# CNV_toutValid,CNV1: Tiff CNV015_20210717_108_
# CNV_toutValid,CNV1: Tiff CNV016_20210804_442_t1 segmented (Tiff n°74), gabor param 0.78, fill param 8, score: 0.7818
# CNV_toutValid,CNV1: Tiff CNV016_20210804_442_t25 segmented (Tiff n°75), gabor param 0.78, fill param 8, score: 0.7467
# CNV_toutValid,CNV1: Tiff CNV016_20210804_442_t49 segmented (Tiff n°76), gabor param 0.78, fill param 8, score: 0.7279
# CNV_toutValid,CNV1: Tiff CNV016_20210804_487_t1 segmented (Tiff n°77), gabor param 0.78, fill param 8, score: 0.8864
# CNV_toutValid,CNV1: Tiff CNV016_20210804_487_t25 segmented (Tiff n°78), gabor param 0.78, fill param 8, score: 0.8815
# CNV_toutValid,CNV1: Tiff CNV016_20210804_487_t49 segmented (Tiff n°79), gabor param 0.78, fill param 8, score: 0.7602
# CNV_toutValid,CNV1: Tiff CNV016_20210804_492_t1 segmented (Tiff n°80), gabor param 0.78, fill param 8, score: 0.8861
# CNV_toutValid,CNV1: Tiff CNV016_20210804_492_t25 segmented (Tiff n°81), gabor param 0.78, fill param 8, score: 0.8789
# CNV_toutValid,CNV1: Tiff CNV019_20210904_233_t49 segmented (Tiff n°82), gabor param 0.78, fill param 8, score: 0.8274
# CNV_toutValid,CNV1: Tiff CNV022_016_t1 segmented (Tiff n°83), gabor param 0.78, fill param 8, score: 0.8316
# CNV_toutValid,CNV1: Tiff CNV022_016_t25 segmented (Tiff n°84), gabor param 0.78, fill param 8, score: 0.7692
# CNV_toutValid,CNV1: Tiff CNV022_077_t25 segmented (Tiff n°85), gabor param 0.78, fill param 8, score: 0.7555
# CNV_toutValid,CNV1: Tiff CNV022_077_t47 segmented (Tiff n°86), gabor param 0.78, fill param 8, score: 0.6815
# CNV_toutValid,CNV1: Tiff CNV022_077_t48 segmented (Tiff n°87), gabor param 0.78, fill param 8, score: 0.7035
# CNV_toutValid,CNV1: Tiff CNV022_077_t49 segmented (Tiff n°88), gabor param 0.78, fill param 8, score: 0.6733
# CNV_toutValid,CNV1: Tiff CNV026_117_t41 segmented (Tiff n°89), gabor param 0.78, fill param 8, score: 0.6556
# CNV_toutValid,CNV1: Tiff CNV026_119_t41 segmented (Tiff n°90), gabor param 0.78, fill param 8, score: 0.6667
# CNV_toutValid,CNV1: Tiff CNV026_128_t41 segmented (Tiff n°91), gabor param 0.78, fill param 8, score: 0.7105
# CNV_toutValid,CNV1: Tiff CNV026_136_t41 segmented (Tiff n°92), gabor param 0.78, fill param 8, score: 0.8157
# CNV_toutValid,CNV1: Tiff CNV026_138_t41 segmented (Tiff n°93), gabor param 0.78, fill param 8, score: 0.6898
# CNV_toutValid,CNV1: Tiff CNV026_141_t41 segmented (Tiff n°94), gabor param 0.78, fill param 8, score: 0.607
# CNV_toutValid,CNV1: Tiff CNV028_38_t41 segmented (Tiff n°95), gabor param 0.78, fill param 8, score: 0.6799
# CNV_toutValid,CNV1: Tiff CNV028_40_t41 segmented (Tiff n°96), gabor param 0.78, fill param 8, score: 0.7267
# CNV_toutValid,CNV1: Tiff CNV028_80_t41 segmented (Tiff n°97), gabor param 0.78, fill param 8, score: 0.8449
# CNV_toutValid,CNV1: Tiff CNV028_82_t41 segmented (Tiff n°98), gabor param 0.78, fill param 8, score: 0.6434
# CNV_toutValid,CNV1: Tiff CNV047_20220520_039_t41 segmented (Tiff n°99), gabor param 0.78, fill param 8, score: 0.7654
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0039 segmented (Tiff n°137), gabor param 0.78, fill param 8, score: 0.8938
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0040 segmented (Tiff n°138), gabor param 0.78, fill param 8, score: 0.8689
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0041 segmented (Tiff n°139), gabor param 0.78, fill param 8, score: 0.8746
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0042 segmented (Tiff n°140), gabor param 0.78, fill param 8, score: 0.8636
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0043 segmented (Tiff n°141), gabor param 0.78, fill param 8, score: 0.8657
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0044 segmented (Tiff n°142), gabor param 0.78, fill param 8, score: 0.8692
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0045 segmented (Tiff n°143), gabor param 0.78, fill param 8, score: 0.8766
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0046 segmented (Tiff n°144), gabor param 0.78, fill param 8, score: 0.8793
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0047 segmented (Tiff n°145), gabor param 0.78, fill param 8, score: 0.862
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0048 segmented (Tiff n°146), gabor param 0.78, fill param 8, score: 0.88
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0049 segmented (Tiff n°147), gabor param 0.78, fill param 8, score: 0.9034
# CNV_toutValid,CNV1: Tiff CNV053_20220623_286_t49 segmented (Tiff n°148), gabor param 0.78, fill param 8, score: 0.8092
# CNV_toutValid,CNV1: Tiff CNV062_096_t48 segmented (Tiff n°149), gabor param 0.78, fill param 8, score: 0.7056
# CNV_toutValid,CNV1: Tiff CNV062_119_t48 segmented (Tiff n°150), gabor param 0.78, fill param 8, score: 0.6016
# CNV_toutValid,CNV1: Tiff CNV062_208_t48 segmented (Tiff n°151), gabor param 0.78, fill param 8, score: 0.8157
# CNV_toutValid,CNV1: Tiff CNV062_211_t19 segmented (Tiff n°152), gabor param 0.78, fill param 8, score: 0.8459
# CNV_toutValid,CNV1: Tiff CNV062_211_t48 segmented (Tiff n°153), gabor param 0.78, fill param 8, score: 0.852
# CNV_toutValid,CNV1: Tiff CNV006_20210430_782_t8 segmented (Tiff n°1), gabor param 0.8, fill param 8, score: 0.8527
# CNV_toutValid,CNV1: Tiff CNV006_20210430_787_t8 segmented (Tiff n°2), gabor param 0.8, fill param 8, score: 0.7491
# CNV_toutValid,CNV1: Tiff CNV006_20210430_791_t8 segmented (Tiff n°3), gabor param 0.8, fill param 8, score: 0.8582
# CNV_toutValid,CNV1: Tiff CNV006_20210430_793_t8 segmented (Tiff n°4), gabor param 0.8, fill param 8, score: 0.7039
# CNV_toutValid,CNV1: Tiff CNV010_20210606_065_t1 segmented (Tiff n°5), gabor param 0.8, fill param 8, score: 0.8936
# CNV_toutValid,CNV1: Tiff CNV010_20210606_065_t25 segmented (Tiff n°6), gabor param 0.8, fill param 8, score: 0.8463
# CNV_toutValid,CNV1: Tiff CNV010_20210606_066_t1 segmented (Tiff n°7), gabor param 0.8, fill param 8, score: 0.8387
# CNV_toutValid,CNV1: Tiff CNV010_20210606_066_t24 segmented (Tiff n°8), gabor param 0.8, fill param 8, score: 0.9026
# CNV_toutValid,CNV1: Tiff CNV010_20210606_067_t1 segmented (Tiff n°9), gabor param 0.8, fill param 8, score: 0.9218
# CNV_toutValid,CNV1: Tiff CNV010_20210606_067_t25 segmented (Tiff n°10), gabor param 0.8, fill param 8, score: 0.709
# CNV_toutValid,CNV1: Tiff CNV010_20210606_072_t1 segmented (Tiff n°11), gabor param 0.8, fill param 8, score: 0.8092
# CNV_toutValid,CNV1: Tiff CNV010_20210606_067_t25 segmented (Tiff n°10), gabor param 0.82, fill param 8, score: 0.7095
# CNV_toutValid,CNV1: Tiff CNV010_20210606_072_t1 segmented (Tiff n°11), gabor param 0.82, fill param 8, score: 0.8129
# CNV_toutValid,CNV1: Tiff CNV010_20210606_072_t25 segmented (Tiff n°12), gabor param 0.82, fill param 8, score: 0.7731
# CNV_toutValid,CNV1: Tiff CNV010_20210606_095_t7 segmented (Tiff n°13), gabor param 0.82, fill param 8, score: 0.8558
# CNV_toutValid,CNV1: Tiff CNV010_20210606_095_t31 segmented (Tiff n°14), gabor param 0.82, fill param 8, score: 0.895
# CNV_toutValid,CNV1: Tiff CNV010_20210606_095_t49 segmented (Tiff n°15), gabor param 0.82, fill param 8, score: 0.9157
# CNV_toutValid,CNV1: Tiff CNV010_20210606_111_t31 segmented (Tiff n°16), gabor param 0.82, fill param 8, score: 0.8618
# CNV_toutValid,CNV1: Tiff CNV010_20210606_111_t49 segmented (Tiff n°17), gabor param 0.82, fill param 8, score: 0.8695
# CNV_toutValid,CNV1: Tiff CNV010_20210606_137_t7 segmented (Tiff n°18), gabor param 0.82, fill param 8, score: 0.828
# CNV_toutValid,CNV1: Tiff CNV010_20210606_137_t31 segmented (Tiff n°19), gabor param 0.82, fill param 8, score: 0.7967
# CNV_toutValid,CNV1: Tiff CNV010_20210606_137_t49 segmented (Tiff n°20), gabor param 0.82, fill param 8, score: 0.8772
# CNV_toutValid,CNV1: Tiff CNV010_20210606_156_t7 segmented (Tiff n°21), gabor param 0.82, fill param 8, score: 0.8278
# CNV_toutValid,CNV1: Tiff CNV010_20210606_156_t31 segmented (Tiff n°22), gabor param 0.82, fill param 8, score: 0.7665
# CNV_toutValid,CNV1: Tiff CNV010_20210606_156_t49 segmented (Tiff n°23), gabor param 0.82, fill param 8, score: 0.6461
# CNV_toutValid,CNV1: Tiff CNV011_20210612_205_t1 segmented (Tiff n°24), gabor param 0.82, fill param 8, score: 0.7948
# CNV_toutValid,CNV1: Tiff CNV011_20210612_205_t25 segmented (Tiff n°25), gabor param 0.82, fill param 8, score: 0.8034
# CNV_toutValid,CNV1: Tiff CNV011_20210612_219_t1 segmented (Tiff n°26), gabor param 0.82, fill param 8, score: 0.8487
# CNV_toutValid,CNV1: Tiff CNV011_20210612_219_t49 segmented (Tiff n°27), gabor param 0.82, fill param 8, score: 0.8011
# CNV_toutValid,CNV1: Tiff CNV011_20210612_221_t1 segmented (Tiff n°28), gabor param 0.82, fill param 8, score: 0.773
# CNV_toutValid,CNV1: Tiff CNV011_20210612_221_t49 segmented (Tiff n°29), gabor param 0.82, fill param 8, score: 0.7624
# CNV_toutValid,CNV1: Tiff CNV012_20210618_409_t1 segmented (Tiff n°30), gabor param 0.82, fill param 8, score: 0.8903
# CNV_toutValid,CNV1: Tiff CNV012_20210618_409_t49 segmented (Tiff n°31), gabor param 0.82, fill param 8, score: 0.8445
# CNV_toutValid,CNV1: Tiff CNV012_20210618_410_t1 segmented (Tiff n°32), gabor param 0.82, fill param 8, score: 0.8876
# CNV_toutValid,CNV1: Tiff CNV012_20210618_410_t49 segmented (Tiff n°33), gabor param 0.82, fill param 8, score: 0.8858
# CNV_toutValid,CNV1: Tiff CNV015_20210717_108_
# CNV_toutValid,CNV1: Tiff CNV015_20210717_128_t25 segmented (Tiff n°69), gabor param 0.82, fill param 8, score: 0.9107
# CNV_toutValid,CNV1: Tiff CNV016_20210804_434_t49 segmented (Tiff n°70), gabor param 0.82, fill param 8, score: 0.7825
# CNV_toutValid,CNV1: Tiff CNV016_20210804_435_t49 segmented (Tiff n°71), gabor param 0.82, fill param 8, score: 0.718
# CNV_toutValid,CNV1: Tiff CNV016_20210804_440_t49 segmented (Tiff n°72), gabor param 0.82, fill param 8, score: 0.7752
# CNV_toutValid,CNV1: Tiff CNV016_20210804_441_t49 segmented (Tiff n°73), gabor param 0.82, fill param 8, score: 0.6624
# CNV_toutValid,CNV1: Tiff CNV016_20210804_442_t1 segmented (Tiff n°74), gabor param 0.82, fill param 8, score: 0.7853
# CNV_toutValid,CNV1: Tiff CNV016_20210804_442_t25 segmented (Tiff n°75), gabor param 0.82, fill param 8, score: 0.7497
# CNV_toutValid,CNV1: Tiff CNV016_20210804_442_t49 segmented (Tiff n°76), gabor param 0.82, fill param 8, score: 0.737
# CNV_toutValid,CNV1: Tiff CNV016_20210804_487_t1 segmented (Tiff n°77), gabor param 0.82, fill param 8, score: 0.8955
# CNV_toutValid,CNV1: Tiff CNV016_20210804_487_t25 segmented (Tiff n°78), gabor param 0.82, fill param 8, score: 0.8876
# CNV_toutValid,CNV1: Tiff CNV016_20210804_487_t49 segmented (Tiff n°79), gabor param 0.82, fill param 8, score: 0.7773
# CNV_toutValid,CNV1: Tiff CNV016_20210804_492_t1 segmented (Tiff n°80), gabor param 0.82, fill param 8, score: 0.8303
# CNV_toutValid,CNV1: Tiff CNV016_20210804_492_t25 segmented (Tiff n°81), gabor param 0.82, fill param 8, score: 0.8838
# CNV_toutValid,CNV1: Tiff CNV019_20210904_233_t49 segmented (Tiff n°82), gabor param 0.82, fill param 8, score: 0.8365
# CNV_toutValid,CNV1: Tiff CNV022_016_t1 segmented (Tiff n°83), gabor param 0.82, fill param 8, score: 0.8293
# CNV_toutValid,CNV1: Tiff CNV022_016_t25 segmented (Tiff n°84), gabor param 0.82, fill param 8, score: 0.762
# CNV_toutValid,CNV1: Tiff CNV022_077_t25 segmented (Tiff n°85), gabor param 0.82, fill param 8, score: 0.7591
# CNV_toutValid,CNV1: Tiff CNV022_077_t47 segmented (Tiff n°86), gabor param 0.82, fill param 8, score: 0.6091
# CNV_toutValid,CNV1: Tiff CNV022_077_t48 segmented (Tiff n°87), gabor param 0.82, fill param 8, score: 0.6782
# CNV_toutValid,CNV1: Tiff CNV022_077_t49 segmented (Tiff n°88), gabor param 0.82, fill param 8, score: 0.6631
# CNV_toutValid,CNV1: Tiff CNV026_117_t41 segmented (Tiff n°89), gabor param 0.82, fill param 8, score: 0.6442
# CNV_toutValid,CNV1: Tiff CNV026_119_t41 segmented (Tiff n°90), gabor param 0.82, fill param 8, score: 0.6792
# CNV_toutValid,CNV1: Tiff CNV026_128_t41 segmented (Tiff n°91), gabor param 0.82, fill param 8, score: 0.7212
# CNV_toutValid,CNV1: Tiff CNV026_136_t41 segmented (Tiff n°92), gabor param 0.82, fill param 8, score: 0.8239
# CNV_toutValid,CNV1: Tiff CNV026_138_t41 segmented (Tiff n°93), gabor param 0.82, fill param 8, score: 0.7141
# CNV_toutValid,CNV1: Tiff CNV026_141_t41 segmented (Tiff n°94), gabor param 0.82, fill param 8, score: 0.6902
# CNV_toutValid,CNV1: Tiff CNV015_20210717_118_t25 segmented (Tiff n°64), gabor param 0.92, fill param 8, score: 0.4297
# CNV_toutValid,CNV1: Tiff CNV015_20210717_125_t13 segmented (Tiff n°65), gabor param 0.92, fill param 8, score: 0.2537
# CNV_toutValid,CNV1: Tiff CNV015_20210717_125_t25 segmented (Tiff n°66), gabor param 0.92, fill param 8, score: 0.267
# CNV_toutValid,CNV1: Tiff CNV015_20210717_128_t1 segmented (Tiff n°67), gabor param 0.92, fill param 8, score: 0.266
# CNV_toutValid,CNV1: Tiff CNV015_20210717_128_t13 segmented (Tiff n°68), gabor param 0.92, fill param 8, score: 0.3476
# CNV_toutValid,CNV1: Tiff CNV015_20210717_128_t25 segmented (Tiff n°69), gabor param 0.92, fill param 8, score: 0.4313
# CNV_toutValid,CNV1: Tiff CNV016_20210804_434_t49 segmented (Tiff n°70), gabor param 0.92, fill param 8, score: 0.4222
# CNV_toutValid,CNV1: Tiff CNV016_20210804_435_t49 segmented (Tiff n°71), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV016_20210804_440_t49 segmented (Tiff n°72), gabor param 0.92, fill param 8, score: 0.112
# CNV_toutValid,CNV1: Tiff CNV016_20210804_441_t49 segmented (Tiff n°73), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV016_20210804_442_t1 segmented (Tiff n°74), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV016_20210804_442_t25 segmented (Tiff n°75), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV016_20210804_442_t49 segmented (Tiff n°76), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV016_20210804_487_t1 segmented (Tiff n°77), gabor param 0.92, fill param 8, score: 0.2399
# CNV_toutValid,CNV1: Tiff CNV016_20210804_487_t25 segmented (Tiff n°78), gabor param 0.92, fill param 8, score: 0.2081
# CNV_toutValid,CNV1: Tiff CNV016_20210804_487_t49 segmented (Tiff n°79), gabor param 0.92, fill param 8, score: 0.3559
# CNV_toutValid,CNV1: Tiff CNV016_20210804_492_t1 segmented (Tiff n°80), gabor param 0.92, fill param 8, score: 0.4307
# CNV_toutValid,CNV1: Tiff CNV016_20210804_492_t25 segmented (Tiff n°81), gabor param 0.92, fill param 8, score: 0.2613
# CNV_toutValid,CNV1: Tiff CNV019_20210904_233_t49 segmented (Tiff n°82), gabor param 0.92, fill param 8, score: 0.3903
# CNV_toutValid,CNV1: Tiff CNV022_016_t1 segmented (Tiff n°83), gabor param 0.92, fill param 8, score: 0.1424
# CNV_toutValid,CNV1: Tiff CNV022_016_t25 segmented (Tiff n°84), gabor param 0.92, fill param 8, score: 0.1101
# CNV_toutValid,CNV1: Tiff CNV022_077_t25 segmented (Tiff n°85), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV022_077_t47 segmented (Tiff n°86), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV022_077_t48 segmented (Tiff n°87), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV022_077_t49 segmented (Tiff n°88), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV026_117_t41 segmented (Tiff n°89), gabor param 0.92, fill param 8, score: 0.2763
# CNV_toutValid,CNV1: Tiff CNV026_119_t41 segmented (Tiff n°90), gabor param 0.92, fill param 8, score: 0.0945
# CNV_toutValid,CNV1: Tiff CNV026_128_t41 segmented (Tiff n°91), gabor param 0.92, fill param 8, score: 0.2723
# CNV_toutValid,CNV1: Tiff CNV026_136_t41 segmented (Tiff n°92), gabor param 0.92, fill param 8, score: 0.6304
# CNV_toutValid,CNV1: Tiff CNV026_138_t41 segmented (Tiff n°93), gabor param 0.92, fill param 8, score: 0.4299
# CNV_toutValid,CNV1: Tiff CNV026_141_t41 segmented (Tiff n°94), gabor param 0.92, fill param 8, score: 0.5035
# CNV_toutValid,CNV1: Tiff CNV028_38_t41 segmented (Tiff n°95), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV028_40_t41 segmented (Tiff n°96), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV028_80_t41 segmented (Tiff n°97), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV028_82_t41 segmented (Tiff n°98), gabor param 0.92, fill param 8, score: 0.1296
# CNV_toutValid,CNV1: Tiff CNV047_20220520_039_t41 segmented (Tiff n°99), gabor param 0.92, fill param 8, score: 0.5125
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0001 segmented (Tiff n°100), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0002 segmented (Tiff n°101), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0003 segmented (Tiff n°102), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0004 segmented (Tiff n°103), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0005 segmented (Tiff n°104), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0006 segmented (Tiff n°105), gabor param 0.92, fill param 8, score: 0.4476
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0007 segmented (Tiff n°106), gabor param 0.92, fill param 8, score: 0.442
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0008 segmented (Tiff n°107), gabor param 0.92, fill param 8, score: 0.4449
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0009 segmented (Tiff n°108), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0010 segmented (Tiff n°109), gabor param 0.92, fill param 8, score: 0.4489
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0011 segmented (Tiff n°110), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0012 segmented (Tiff n°111), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0013 segmented (Tiff n°112), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0014 segmented (Tiff n°113), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0015 segmented (Tiff n°114), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0016 segmented (Tiff n°115), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0017 segmented (Tiff n°116), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0018 segmented (Tiff n°117), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0019 segmented (Tiff n°118), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0020 segmented (Tiff n°119), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0021 segmented (Tiff n°120), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0022 segmented (Tiff n°121), gabor param 0.92, fill param 8, score: 0.4084
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0023 segmented (Tiff n°122), gabor param 0.92, fill param 8, score: 0.3913
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0024 segmented (Tiff n°123), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0025 segmented (Tiff n°124), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0026 segmented (Tiff n°125), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0027 segmented (Tiff n°126), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0028 segmented (Tiff n°127), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0029 segmented (Tiff n°128), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0031 segmented (Tiff n°129), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0032 segmented (Tiff n°130), gabor param 0.92, fill param 8, score: 0.3674
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0033 segmented (Tiff n°131), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0034 segmented (Tiff n°132), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0035 segmented (Tiff n°133), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0036 segmented (Tiff n°134), gabor param 0.92, fill param 8, score: 0.4327
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0037 segmented (Tiff n°135), gabor param 0.92, fill param 8, score: 0.3823
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0038 segmented (Tiff n°136), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0039 segmented (Tiff n°137), gabor param 0.92, fill param 8, score: 0.3802
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0040 segmented (Tiff n°138), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0041 segmented (Tiff n°139), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0042 segmented (Tiff n°140), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0043 segmented (Tiff n°141), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0044 segmented (Tiff n°142), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0045 segmented (Tiff n°143), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0046 segmented (Tiff n°144), gabor param 0.92, fill param 8, score: 0.3477
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0047 segmented (Tiff n°145), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0048 segmented (Tiff n°146), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0049 segmented (Tiff n°147), gabor param 0.92, fill param 8, score: 0.2899
# CNV_toutValid,CNV1: Tiff CNV053_20220623_286_t49 segmented (Tiff n°148), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV062_096_t48 segmented (Tiff n°149), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV062_119_t48 segmented (Tiff n°150), gabor param 0.92, fill param 8, score: 0.0972
# CNV_toutValid,CNV1: Tiff CNV062_208_t48 segmented (Tiff n°151), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV062_211_t19 segmented (Tiff n°152), gabor param 0.92, fill param 8, score: 0.0
# CNV_toutValid,CNV1: Tiff CNV062_211_t48 segmented (Tiff n°153), gabor param 0.92, fill param 8, score: 0.26
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [19], line 9
#       7 dice_score_hyperparameters = list(map(lambda x: [x[0],x[1],np.array(list(create_masks(file_dir,image_files_name,mask_files_name,gabor_parameter=x[0],fill_cells=x[1],save_predicted_mask=False).values())).mean() ] , hyperparameter_candidates))
#       8 df_dice_scores=pd.DataFrame(dice_score_hyperparameters)
# ----> 9 df_dice_scores.columns = ['gabor_param', 'fill_param', 'Min_pixels', 'Dice scores']
#      10 df_dice_scores
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:5915, in NDFrame.__setattr__(self, name, value)
#    5913 try:
#    5914     object.__getattribute__(self, name)
# -> 5915     return object.__setattr__(self, name, value)
#    5916 except AttributeError:
#    5917     pass
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:823, in NDFrame._set_axis(self, axis, labels)
#     821 def _set_axis(self, axis: int, labels: AnyArrayLike | list) -> None:
#     822     labels = ensure_index(labels)
# --> 823     self._mgr.set_axis(axis, labels)
#     824     self._clear_item_cache()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/internals/managers.py:230, in BaseBlockManager.set_axis(self, axis, new_labels)
#     228 def set_axis(self, axis: int, new_labels: Index) -> None:
#     229     # Caller is responsible for ensuring we have an Index object.
# --> 230     self._validate_set_axis(axis, new_labels)
#     231     self.axes[axis] = new_labels
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/internals/base.py:70, in DataManager._validate_set_axis(self, axis, new_labels)
#      67     pass
#      69 elif new_len != old_len:
# ---> 70     raise ValueError(
#      71         f"Length mismatch: Expected axis has {old_len} elements, new "
#      72         f"values have {new_len} elements"
#      73     )
#
# ValueError: Length mismatch: Expected axis has 3 elements, new values have 4 elements

# %%
# after having tuned the gabor and fill parameter, we are going to tune the number of pixels threshold (every mask below that number of pixels is removed) 

hyperparameter_candidates = [3700,3800,3900,4000,4100]
dice_score_pixels_nb = list(map(lambda x: [0.785,8,x,np.array(list(create_masks(file_dir,image_files_name,mask_files_name,gabor_parameter=0.785,fill_cells=8, ratio_small_object_thresh = x/(1920*1440) ,save_predicted_mask=False).values())).mean() ] , hyperparameter_candidates))
dice_score_pixels_nb=pd.DataFrame(dice_score_pixels_nb)
dice_score_pixels_nb.columns = ['gabor_param', 'fill_param', 'Min_pixels', 'Dice scores']
dice_score_pixels_nb
# Out:
# CNV_toutValid,CNV1: Tiff CNV006_20210430_782_t8 segmented (Tiff n°1), gabor param 0.785, fill param 8, score: 0.8516
# CNV_toutValid,CNV1: Tiff CNV006_20210430_787_t8 segmented (Tiff n°2), gabor param 0.785, fill param 8, score: 0.7779
# CNV_toutValid,CNV1: Tiff CNV006_20210430_791_t8 segmented (Tiff n°3), gabor param 0.785, fill param 8, score: 0.8568
# CNV_toutValid,CNV1: Tiff CNV006_20210430_793_t8 segmented (Tiff n°4), gabor param 0.785, fill param 8, score: 0.7054
# CNV_toutValid,CNV1: Tiff CNV010_20210606_065_t1 segmented (Tiff n°5), gabor param 0.785, fill param 8, score: 0.8922
# CNV_toutValid,CNV1: Tiff CNV010_20210606_065_t25 segmented (Tiff n°6), gabor param 0.785, fill param 8, score: 0.847
# CNV_toutValid,CNV1: Tiff CNV010_20210606_066_t1 segmented (Tiff n°7), gabor param 0.785, fill param 8, score: 0.8374
# CNV_toutValid,CNV1: Tiff CNV010_20210606_066_t24 segmented (Tiff n°8), gabor param 0.785, fill param 8, score: 0.9021
# CNV_toutValid,CNV1: Tiff CNV010_20210606_067_t1 segmented (Tiff n°9), gabor param 0.785, fill param 8, score: 0.9201
# CNV_toutValid,CNV1: Tiff CNV010_20210606_067_t25 segmented (Tiff n°10), gabor param 0.785, fill param 8, score: 0.7082
# CNV_toutValid,CNV1: Tiff CNV010_20210606_072_t1 segmented (Tiff n°11), gabor param 0.785, fill param 8, score: 0.8065
# CNV_toutValid,CNV1: Tiff CNV010_20210606_072_t25 segmented (Tiff n°12), gabor param 0.785, fill param 8, score: 0.769
# CNV_toutValid,CNV1: Tiff CNV010_20210606_095_t7 segmented (Tiff n°13), gabor param 0.785, fill param 8, score: 0.8897
# CNV_toutValid,CNV1: Tiff CNV010_20210606_095_t31 segmented (Tiff n°14), gabor param 0.785, fill param 8, score: 0.8928
# CNV_toutValid,CNV1: Tiff CNV010_20210606_095_t49 segmented (Tiff n°15), gabor param 0.785, fill param 8, score: 0.912
# CNV_toutValid,CNV1: Tiff CNV010_20210606_111_t31 segmented (Tiff n°16), gabor param 0.785, fill param 8, score: 0.8524
# CNV_toutValid,CNV1: Tiff CNV010_20210606_111_t49 segmented (Tiff n°17), gabor param 0.785, fill param 8, score: 0.8698
# CNV_toutValid,CNV1: Tiff CNV010_20210606_137_t7 segmented (Tiff n°18), gabor param 0.785, fill param 8, score: 0.8885
# CNV_toutValid,CNV1: Tiff CNV010_20210606_137_t31 segmented (Tiff n°19), gabor param 0.785, fill param 8, score: 0.794
# CNV_toutValid,CNV1: Tiff CNV010_20210606_137_t49 segmented (Tiff n°20), gabor param 0.785, fill param 8, score: 0.8788
# CNV_toutValid,CNV1: Tiff CNV010_20210606_156_t7 segmented (Tiff n°21), gabor param 0.785, fill param 8, score: 0.8316
# CNV_toutValid,CNV1: Tiff CNV010_20210606_156_t31 segmented (Tiff n°22), gabor param 0.785, fill param 8, score: 0.7775
# CNV_toutValid,CNV1: Tiff CNV010_20210606_156_t49 segmented (Tiff n°23), gabor param 0.785, fill param 8, score: 0.6623
# CNV_toutValid,CNV1: Tiff CNV011_20210612_205_t1 segmented (Tiff n°24), gabor param 0.785, fill param 8, score: 0.7882
# CNV_toutValid,CNV1: Tiff CNV011_20210612_205_t25 segmented (Tiff n°25), gabor param 0.785, fill param 8, score: 0.7968
# CNV_toutValid,CNV1: Tiff CNV011_20210612_219_t1 segmented (Tiff n°26), gabor param 0.785, fill param 8, score: 0.8398
# CNV_toutValid,CNV1: Tiff CNV011_20210612_219_t49 segmented (Tiff n°27), gabor param 0.785, fill param 8, score: 0.7967
# CNV_toutValid,CNV1: Tiff CNV011_20210612_221_t1 segmented (Tiff n°28), gabor param 0.785, fill param 8, score: 0.7973
# CNV_toutValid,CNV1: Tiff CNV011_20210612_221_t49 segmented (Tiff n°29), gabor param 0.785, fill param 8, score: 0.7543
# CNV_toutValid,CNV1: Tiff CNV012_20210618_409_t1 segmented (Tiff n°30), gabor param 0.785, fill param 8, score: 0.8859
# CNV_toutValid,CNV1: Tiff CNV012_20210618_409_t49 segmented (Tiff n°31), gabor param 0.785, fill param 8, score: 0.8372
# CNV_toutValid,CNV1: Tiff CNV012_20210618_410_t1 segmented (Tiff n°32), gabor param 0.785, fill param 8, score: 0.882
# CNV_toutValid,CNV1: Tiff CNV012_20210618_410_t49 segmented (Tiff n°33), gabor param 0.785, fill param 8, score: 0.8803
# CNV_toutValid,CNV1: Tiff CNV015_20210717_108_
# CNV_toutValid,CNV1: Tiff CNV015_20210717_128_t25 segmented (Tiff n°69), gabor param 0.785, fill param 8, score: 0.9036
# CNV_toutValid,CNV1: Tiff CNV016_20210804_434_t49 segmented (Tiff n°70), gabor param 0.785, fill param 8, score: 0.7712
# CNV_toutValid,CNV1: Tiff CNV016_20210804_435_t49 segmented (Tiff n°71), gabor param 0.785, fill param 8, score: 0.7131
# CNV_toutValid,CNV1: Tiff CNV016_20210804_440_t49 segmented (Tiff n°72), gabor param 0.785, fill param 8, score: 0.7531
# CNV_toutValid,CNV1: Tiff CNV016_20210804_441_t49 segmented (Tiff n°73), gabor param 0.785, fill param 8, score: 0.6545
# CNV_toutValid,CNV1: Tiff CNV016_20210804_442_t1 segmented (Tiff n°74), gabor param 0.785, fill param 8, score: 0.7827
# CNV_toutValid,CNV1: Tiff CNV016_20210804_442_t25 segmented (Tiff n°75), gabor param 0.785, fill param 8, score: 0.7468
# CNV_toutValid,CNV1: Tiff CNV016_20210804_442_t49 segmented (Tiff n°76), gabor param 0.785, fill param 8, score: 0.7281
# CNV_toutValid,CNV1: Tiff CNV016_20210804_487_t1 segmented (Tiff n°77), gabor param 0.785, fill param 8, score: 0.8868
# CNV_toutValid,CNV1: Tiff CNV016_20210804_487_t25 segmented (Tiff n°78), gabor param 0.785, fill param 8, score: 0.8819
# CNV_toutValid,CNV1: Tiff CNV016_20210804_487_t49 segmented (Tiff n°79), gabor param 0.785, fill param 8, score: 0.7609
# CNV_toutValid,CNV1: Tiff CNV016_20210804_492_t1 segmented (Tiff n°80), gabor param 0.785, fill param 8, score: 0.8866
# CNV_toutValid,CNV1: Tiff CNV016_20210804_492_t25 segmented (Tiff n°81), gabor param 0.785, fill param 8, score: 0.879
# CNV_toutValid,CNV1: Tiff CNV019_20210904_233_t49 segmented (Tiff n°82), gabor param 0.785, fill param 8, score: 0.8281
# CNV_toutValid,CNV1: Tiff CNV022_016_t1 segmented (Tiff n°83), gabor param 0.785, fill param 8, score: 0.8312
# CNV_toutValid,CNV1: Tiff CNV022_016_t25 segmented (Tiff n°84), gabor param 0.785, fill param 8, score: 0.7695
# CNV_toutValid,CNV1: Tiff CNV022_077_t25 segmented (Tiff n°85), gabor param 0.785, fill param 8, score: 0.7557
# CNV_toutValid,CNV1: Tiff CNV022_077_t47 segmented (Tiff n°86), gabor param 0.785, fill param 8, score: 0.6816
# CNV_toutValid,CNV1: Tiff CNV022_077_t48 segmented (Tiff n°87), gabor param 0.785, fill param 8, score: 0.7036
# CNV_toutValid,CNV1: Tiff CNV022_077_t49 segmented (Tiff n°88), gabor param 0.785, fill param 8, score: 0.6736
# CNV_toutValid,CNV1: Tiff CNV026_117_t41 segmented (Tiff n°89), gabor param 0.785, fill param 8, score: 0.6558
# CNV_toutValid,CNV1: Tiff CNV026_119_t41 segmented (Tiff n°90), gabor param 0.785, fill param 8, score: 0.6668
# CNV_toutValid,CNV1: Tiff CNV026_128_t41 segmented (Tiff n°91), gabor param 0.785, fill param 8, score: 0.7111
# CNV_toutValid,CNV1: Tiff CNV026_136_t41 segmented (Tiff n°92), gabor param 0.785, fill param 8, score: 0.8171
# CNV_toutValid,CNV1: Tiff CNV026_138_t41 segmented (Tiff n°93), gabor param 0.785, fill param 8, score: 0.6913
# CNV_toutValid,CNV1: Tiff CNV026_141_t41 segmented (Tiff n°94), gabor param 0.785, fill param 8, score: 0.6077
# CNV_toutValid,CNV1: Tiff CNV028_38_t41 segmented (Tiff n°95), gabor param 0.785, fill param 8, score: 0.6799
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0035 segmented (Tiff n°133), gabor param 0.785, fill param 8, score: 0.9106
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0036 segmented (Tiff n°134), gabor param 0.785, fill param 8, score: 0.8488
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0037 segmented (Tiff n°135), gabor param 0.785, fill param 8, score: 0.867
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0038 segmented (Tiff n°136), gabor param 0.785, fill param 8, score: 0.8776
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0039 segmented (Tiff n°137), gabor param 0.785, fill param 8, score: 0.8943
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0040 segmented (Tiff n°138), gabor param 0.785, fill param 8, score: 0.8692
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0041 segmented (Tiff n°139), gabor param 0.785, fill param 8, score: 0.8749
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0042 segmented (Tiff n°140), gabor param 0.785, fill param 8, score: 0.8637
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0043 segmented (Tiff n°141), gabor param 0.785, fill param 8, score: 0.866
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0044 segmented (Tiff n°142), gabor param 0.785, fill param 8, score: 0.8697
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0045 segmented (Tiff n°143), gabor param 0.785, fill param 8, score: 0.8766
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0046 segmented (Tiff n°144), gabor param 0.785, fill param 8, score: 0.8792
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0047 segmented (Tiff n°145), gabor param 0.785, fill param 8, score: 0.8624
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0048 segmented (Tiff n°146), gabor param 0.785, fill param 8, score: 0.8775
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0049 segmented (Tiff n°147), gabor param 0.785, fill param 8, score: 0.9035
# CNV_toutValid,CNV1: Tiff CNV053_20220623_286_t49 segmented (Tiff n°148), gabor param 0.785, fill param 8, score: 0.8092
# CNV_toutValid,CNV1: Tiff CNV062_096_t48 segmented (Tiff n°149), gabor param 0.785, fill param 8, score: 0.704
# CNV_toutValid,CNV1: Tiff CNV062_119_t48 segmented (Tiff n°150), gabor param 0.785, fill param 8, score: 0.6018
# CNV_toutValid,CNV1: Tiff CNV062_208_t48 segmented (Tiff n°151), gabor param 0.785, fill param 8, score: 0.8164
# CNV_toutValid,CNV1: Tiff CNV062_211_t19 segmented (Tiff n°152), gabor param 0.785, fill param 8, score: 0.8461
# CNV_toutValid,CNV1: Tiff CNV062_211_t48 segmented (Tiff n°153), gabor param 0.785, fill param 8, score: 0.8524
# CNV_toutValid,CNV1: Tiff CNV006_20210430_782_t8 segmented (Tiff n°1), gabor param 0.785, fill param 8, score: 0.8516
# CNV_toutValid,CNV1: Tiff CNV006_20210430_787_t8 segmented (Tiff n°2), gabor param 0.785, fill param 8, score: 0.7779
# CNV_toutValid,CNV1: Tiff CNV006_20210430_791_t8 segmented (Tiff n°3), gabor param 0.785, fill param 8, score: 0.8568
# CNV_toutValid,CNV1: Tiff CNV006_20210430_793_t8 segmented (Tiff n°4), gabor param 0.785, fill param 8, score: 0.7054
# CNV_toutValid,CNV1: Tiff CNV010_20210606_065_t1 segmented (Tiff n°5), gabor param 0.785, fill param 8, score: 0.8922
# CNV_toutValid,CNV1: Tiff CNV010_20210606_065_t25 segmented (Tiff n°6), gabor param 0.785, fill param 8, score: 0.847
# CNV_toutValid,CNV1: Tiff CNV010_20210606_066_t1 segmented (Tiff n°7), gabor param 0.785, fill param 8, score: 0.8374
# CNV_toutValid,CNV1: Tiff CNV010_20210606_066_t24 segmented (Tiff n°8), gabor param 0.785, fill param 8, score: 0.9021
# CNV_toutValid,CNV1: Tiff CNV010_20210606_067_t1 segmented (Tiff n°9), gabor param 0.785, fill param 8, score: 0.9201
# CNV_toutValid,CNV1: Tiff CNV010_20210606_067_t25 segmented (Tiff n°10), gabor param 0.785, fill param 8, score: 0.7082
# CNV_toutValid,CNV1: Tiff CNV010_20210606_072_t1 segmented (Tiff n°11), gabor param 0.785, fill param 8, score: 0.8065
# CNV_toutValid,CNV1: Tiff CNV010_20210606_072_t25 segmented (Tiff n°12), gabor param 0.785, fill param 8, score: 0.769
# CNV_toutValid,CNV1: Tiff CNV010_20210606_095_t7 segmented (Tiff n°13), gabor param 0.785, fill param 8, score: 0.8897
# CNV_toutValid,CNV1: Tiff CNV010_20210606_095_t31 segmented (Tiff n°14), gabor param 0.785, fill param 8, score: 0.8928
# CNV_toutValid,CNV1: Tiff CNV010_20210606_095_t49 segmented (Tiff n°15), gabor param 0.785, fill param 8, score: 0.912
# CNV_toutValid,CNV1: Tiff CNV010_20210606_111_t31 segmented (Tiff n°16), gabor param 0.785, fill param 8, score: 0.8524
# CNV_toutValid,CNV1: Tiff CNV010_20210606_111_t49 segmented (Tiff n°17), gabor param 0.785, fill param 8, score: 0.8698
# CNV_toutValid,CNV1: Tiff CNV010_20210606_137_t7 segmented (Tiff n°18), gabor param 0.785, fill param 8, score: 0.8885
# CNV_toutValid,CNV1: Tiff CNV010_20210606_137_t31 segmented (Tiff n°19), gabor param 0.785, fill param 8, score: 0.794
# CNV_toutValid,CNV1: Tiff CNV010_20210606_137_t49 segmented (Tiff n°20), gabor param 0.785, fill param 8, score: 0.8788
# CNV_toutValid,CNV1: Tiff CNV010_20210606_156_t7 segmented (Tiff n°21), gabor param 0.785, fill param 8, score: 0.8316
# CNV_toutValid,CNV1: Tiff CNV010_20210606_156_t31 segmented (Tiff n°22), gabor param 0.785, fill param 8, score: 0.7775
# CNV_toutValid,CNV1: Tiff CNV010_20210606_156_t49 segmented (Tiff n°23), gabor param 0.785, fill param 8, score: 0.6623
# CNV_toutValid,CNV1: Tiff CNV011_20210612_205_t1 segmented (Tiff n°24), gabor param 0.785, fill param 8, score: 0.7882
# CNV_toutValid,CNV1: Tiff CNV011_20210612_205_t25 segmented (Tiff n°25), gabor param 0.785, fill param 8, score: 0.7968
# CNV_toutValid,CNV1: Tiff CNV011_20210612_219_t1 segmented (Tiff n°26), gabor param 0.785, fill param 8, score: 0.8398
# CNV_toutValid,CNV1: Tiff CNV011_20210612_219_t49 segmented (Tiff n°27), gabor param 0.785, fill param 8, score: 0.8407
# CNV_toutValid,CNV1: Tiff CNV011_20210612_221_t1 segmented (Tiff n°28), gabor param 0.785, fill param 8, score: 0.7973
# CNV_toutValid,CNV1: Tiff CNV011_20210612_221_t49 segmented (Tiff n°29), gabor param 0.785, fill param 8, score: 0.7543
# CNV_toutValid,CNV1: Tiff CNV012_20210618_409_t1 segmented (Tiff n°30), gabor param 0.785, fill param 8, score: 0.8859
# CNV_toutValid,CNV1: Tiff CNV012_20210618_409_t49 segmented (Tiff n°31), gabor param 0.785, fill param 8, score: 0.8372
# CNV_toutValid,CNV1: Tiff CNV012_20210618_410_t1 segmented (Tiff n°32), gabor param 0.785, fill param 8, score: 0.882
# CNV_toutValid,CNV1: Tiff CNV012_20210618_410_t49 segmented (Tiff n°33), gabor param 0.785, fill param 8, score: 0.8803
# CNV_toutValid,CNV1: Tiff CNV015_20210717_108_
# CNV_toutValid,CNV1: Tiff CNV015_20210717_128_t1 segmented (Tiff n°67), gabor param 0.785, fill param 8, score: 0.7738
# CNV_toutValid,CNV1: Tiff CNV015_20210717_128_t13 segmented (Tiff n°68), gabor param 0.785, fill param 8, score: 0.8659
# CNV_toutValid,CNV1: Tiff CNV015_20210717_128_t25 segmented (Tiff n°69), gabor param 0.785, fill param 8, score: 0.9036
# CNV_toutValid,CNV1: Tiff CNV016_20210804_434_t49 segmented (Tiff n°70), gabor param 0.785, fill param 8, score: 0.7712
# CNV_toutValid,CNV1: Tiff CNV016_20210804_435_t49 segmented (Tiff n°71), gabor param 0.785, fill param 8, score: 0.7131
# CNV_toutValid,CNV1: Tiff CNV016_20210804_440_t49 segmented (Tiff n°72), gabor param 0.785, fill param 8, score: 0.7531
# CNV_toutValid,CNV1: Tiff CNV016_20210804_441_t49 segmented (Tiff n°73), gabor param 0.785, fill param 8, score: 0.6545
# CNV_toutValid,CNV1: Tiff CNV016_20210804_442_t1 segmented (Tiff n°74), gabor param 0.785, fill param 8, score: 0.7827
# CNV_toutValid,CNV1: Tiff CNV016_20210804_442_t25 segmented (Tiff n°75), gabor param 0.785, fill param 8, score: 0.7468
# CNV_toutValid,CNV1: Tiff CNV016_20210804_442_t49 segmented (Tiff n°76), gabor param 0.785, fill param 8, score: 0.6949
# CNV_toutValid,CNV1: Tiff CNV016_20210804_487_t1 segmented (Tiff n°77), gabor param 0.785, fill param 8, score: 0.8868
# CNV_toutValid,CNV1: Tiff CNV016_20210804_487_t25 segmented (Tiff n°78), gabor param 0.785, fill param 8, score: 0.8819
# CNV_toutValid,CNV1: Tiff CNV016_20210804_487_t49 segmented (Tiff n°79), gabor param 0.785, fill param 8, score: 0.7609
# CNV_toutValid,CNV1: Tiff CNV016_20210804_492_t1 segmented (Tiff n°80), gabor param 0.785, fill param 8, score: 0.8866
# CNV_toutValid,CNV1: Tiff CNV016_20210804_492_t25 segmented (Tiff n°81), gabor param 0.785, fill param 8, score: 0.879
# CNV_toutValid,CNV1: Tiff CNV019_20210904_233_t49 segmented (Tiff n°82), gabor param 0.785, fill param 8, score: 0.8281
# CNV_toutValid,CNV1: Tiff CNV022_016_t1 segmented (Tiff n°83), gabor param 0.785, fill param 8, score: 0.8312
# CNV_toutValid,CNV1: Tiff CNV022_016_t25 segmented (Tiff n°84), gabor param 0.785, fill param 8, score: 0.7695
# CNV_toutValid,CNV1: Tiff CNV022_077_t25 segmented (Tiff n°85), gabor param 0.785, fill param 8, score: 0.7557
# CNV_toutValid,CNV1: Tiff CNV022_077_t47 segmented (Tiff n°86), gabor param 0.785, fill param 8, score: 0.6816
# CNV_toutValid,CNV1: Tiff CNV022_077_t48 segmented (Tiff n°87), gabor param 0.785, fill param 8, score: 0.7036
# CNV_toutValid,CNV1: Tiff CNV022_077_t49 segmented (Tiff n°88), gabor param 0.785, fill param 8, score: 0.6736
# CNV_toutValid,CNV1: Tiff CNV026_117_t41 segmented (Tiff n°89), gabor param 0.785, fill param 8, score: 0.6369
# CNV_toutValid,CNV1: Tiff CNV026_119_t41 segmented (Tiff n°90), gabor param 0.785, fill param 8, score: 0.6668
# CNV_toutValid,CNV1: Tiff CNV026_128_t41 segmented (Tiff n°91), gabor param 0.785, fill param 8, score: 0.7111
# CNV_toutValid,CNV1: Tiff CNV026_136_t41 segmented (Tiff n°92), gabor param 0.785, fill param 8, score: 0.8171
# CNV_toutValid,CNV1: Tiff CNV026_138_t41 segmented (Tiff n°93), gabor param 0.785, fill param 8, score: 0.6913
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0032 segmented (Tiff n°130), gabor param 0.785, fill param 8, score: 0.8725
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0033 segmented (Tiff n°131), gabor param 0.785, fill param 8, score: 0.8702
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0034 segmented (Tiff n°132), gabor param 0.785, fill param 8, score: 0.8486
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0035 segmented (Tiff n°133), gabor param 0.785, fill param 8, score: 0.9106
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0036 segmented (Tiff n°134), gabor param 0.785, fill param 8, score: 0.8488
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0037 segmented (Tiff n°135), gabor param 0.785, fill param 8, score: 0.867
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0038 segmented (Tiff n°136), gabor param 0.785, fill param 8, score: 0.8776
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0039 segmented (Tiff n°137), gabor param 0.785, fill param 8, score: 0.8943
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0040 segmented (Tiff n°138), gabor param 0.785, fill param 8, score: 0.8692
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0041 segmented (Tiff n°139), gabor param 0.785, fill param 8, score: 0.8749
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0042 segmented (Tiff n°140), gabor param 0.785, fill param 8, score: 0.8637
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0043 segmented (Tiff n°141), gabor param 0.785, fill param 8, score: 0.866
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0044 segmented (Tiff n°142), gabor param 0.785, fill param 8, score: 0.8697
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0045 segmented (Tiff n°143), gabor param 0.785, fill param 8, score: 0.8766
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0046 segmented (Tiff n°144), gabor param 0.785, fill param 8, score: 0.8792
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0047 segmented (Tiff n°145), gabor param 0.785, fill param 8, score: 0.8624
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0048 segmented (Tiff n°146), gabor param 0.785, fill param 8, score: 0.8775
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0049 segmented (Tiff n°147), gabor param 0.785, fill param 8, score: 0.9035
# CNV_toutValid,CNV1: Tiff CNV053_20220623_286_t49 segmented (Tiff n°148), gabor param 0.785, fill param 8, score: 0.8092
# CNV_toutValid,CNV1: Tiff CNV062_096_t48 segmented (Tiff n°149), gabor param 0.785, fill param 8, score: 0.704
# CNV_toutValid,CNV1: Tiff CNV062_119_t48 segmented (Tiff n°150), gabor param 0.785, fill param 8, score: 0.6018
# CNV_toutValid,CNV1: Tiff CNV062_208_t48 segmented (Tiff n°151), gabor param 0.785, fill param 8, score: 0.8164
# CNV_toutValid,CNV1: Tiff CNV062_211_t19 segmented (Tiff n°152), gabor param 0.785, fill param 8, score: 0.8461
# CNV_toutValid,CNV1: Tiff CNV062_211_t48 segmented (Tiff n°153), gabor param 0.785, fill param 8, score: 0.8524
# CNV_toutValid,CNV1: Tiff CNV006_20210430_782_t8 segmented (Tiff n°1), gabor param 0.785, fill param 8, score: 0.8516
# CNV_toutValid,CNV1: Tiff CNV006_20210430_787_t8 segmented (Tiff n°2), gabor param 0.785, fill param 8, score: 0.7779
# CNV_toutValid,CNV1: Tiff CNV006_20210430_791_t8 segmented (Tiff n°3), gabor param 0.785, fill param 8, score: 0.8568
# CNV_toutValid,CNV1: Tiff CNV006_20210430_793_t8 segmented (Tiff n°4), gabor param 0.785, fill param 8, score: 0.7054
# CNV_toutValid,CNV1: Tiff CNV010_20210606_065_t1 segmented (Tiff n°5), gabor param 0.785, fill param 8, score: 0.8922
# CNV_toutValid,CNV1: Tiff CNV010_20210606_065_t25 segmented (Tiff n°6), gabor param 0.785, fill param 8, score: 0.847
# CNV_toutValid,CNV1: Tiff CNV010_20210606_066_t1 segmented (Tiff n°7), gabor param 0.785, fill param 8, score: 0.8374
# CNV_toutValid,CNV1: Tiff CNV010_20210606_066_t24 segmented (Tiff n°8), gabor param 0.785, fill param 8, score: 0.9021
# CNV_toutValid,CNV1: Tiff CNV010_20210606_067_t1 segmented (Tiff n°9), gabor param 0.785, fill param 8, score: 0.9201
# CNV_toutValid,CNV1: Tiff CNV010_20210606_067_t25 segmented (Tiff n°10), gabor param 0.785, fill param 8, score: 0.7082
# CNV_toutValid,CNV1: Tiff CNV010_20210606_072_t1 segmented (Tiff n°11), gabor param 0.785, fill param 8, score: 0.8065
# CNV_toutValid,CNV1: Tiff CNV010_20210606_072_t25 segmented (Tiff n°12), gabor param 0.785, fill param 8, score: 0.769
# CNV_toutValid,CNV1: Tiff CNV010_20210606_095_t7 segmented (Tiff n°13), gabor param 0.785, fill param 8, score: 0.8897
# CNV_toutValid,CNV1: Tiff CNV010_20210606_095_t31 segmented (Tiff n°14), gabor param 0.785, fill param 8, score: 0.8928
# CNV_toutValid,CNV1: Tiff CNV010_20210606_095_t49 segmented (Tiff n°15), gabor param 0.785, fill param 8, score: 0.912
# CNV_toutValid,CNV1: Tiff CNV010_20210606_111_t31 segmented (Tiff n°16), gabor param 0.785, fill param 8, score: 0.8524
# CNV_toutValid,CNV1: Tiff CNV010_20210606_111_t49 segmented (Tiff n°17), gabor param 0.785, fill param 8, score: 0.8698
# CNV_toutValid,CNV1: Tiff CNV010_20210606_137_t7 segmented (Tiff n°18), gabor param 0.785, fill param 8, score: 0.8885
# CNV_toutValid,CNV1: Tiff CNV010_20210606_137_t31 segmented (Tiff n°19), gabor param 0.785, fill param 8, score: 0.794
# CNV_toutValid,CNV1: Tiff CNV010_20210606_137_t49 segmented (Tiff n°20), gabor param 0.785, fill param 8, score: 0.8788
# CNV_toutValid,CNV1: Tiff CNV010_20210606_156_t7 segmented (Tiff n°21), gabor param 0.785, fill param 8, score: 0.8316
# CNV_toutValid,CNV1: Tiff CNV010_20210606_156_t31 segmented (Tiff n°22), gabor param 0.785, fill param 8, score: 0.7775
# CNV_toutValid,CNV1: Tiff CNV010_20210606_156_t49 segmented (Tiff n°23), gabor param 0.785, fill param 8, score: 0.6442
# CNV_toutValid,CNV1: Tiff CNV011_20210612_205_t1 segmented (Tiff n°24), gabor param 0.785, fill param 8, score: 0.7882
# CNV_toutValid,CNV1: Tiff CNV011_20210612_205_t25 segmented (Tiff n°25), gabor param 0.785, fill param 8, score: 0.7968
# CNV_toutValid,CNV1: Tiff CNV011_20210612_219_t1 segmented (Tiff n°26), gabor param 0.785, fill param 8, score: 0.8398
# CNV_toutValid,CNV1: Tiff CNV011_20210612_219_t49 segmented (Tiff n°27), gabor param 0.785, fill param 8, score: 0.8407
# CNV_toutValid,CNV1: Tiff CNV011_20210612_221_t1 segmented (Tiff n°28), gabor param 0.785, fill param 8, score: 0.7687
# CNV_toutValid,CNV1: Tiff CNV011_20210612_221_t49 segmented (Tiff n°29), gabor param 0.785, fill param 8, score: 0.7543
# CNV_toutValid,CNV1: Tiff CNV012_20210618_409_t1 segmented (Tiff n°30), gabor param 0.785, fill param 8, score: 0.8859
# CNV_toutValid,CNV1: Tiff CNV012_20210618_409_t49 segmented (Tiff n°31), gabor param 0.785, fill param 8, score: 0.8372
# CNV_toutValid,CNV1: Tiff CNV012_20210618_410_t1 segmented (Tiff n°32), gabor param 0.785, fill param 8, score: 0.882
# CNV_toutValid,CNV1: Tiff CNV012_20210618_410_t49 segmented (Tiff n°33), gabor param 0.785, fill param 8, score: 0.8718
# CNV_toutValid,CNV1: Tiff CNV015_20210717_108_t1 segmented (Tiff n°34), gabor param 0.785, fill param 8, score: 0.8486
# CNV_toutValid,CNV1: Tiff CNV015_20210717_108_t13 segmented (Tiff n°35), gabor param 0.785, fill param 8, score: 0.9048
# CNV_toutValid,CNV1: Tiff CNV015_20210717_108_t23 segmented (Tiff n°36), gabor param 0.785, fill param 8, score: 0.903
# CNV_toutValid,CNV1: Tiff CNV015_20210717_108_t24 segmented (Tiff n°37), gabor param 0.785, fill param 8, score: 0.8832
# CNV_toutValid,CNV1: Tiff CNV015_20210717_108_t25 segmented (Tiff n°38), gabor param 0.785, fill param 8, score: 0.8978
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0001 segmented (Tiff n°39), gabor param 0.785, fill param 8, score: 0.8094
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0002 segmented (Tiff n°40), gabor param 0.785, fill param 8, score: 0.8063
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0003 segmented (Tiff n°41), gabor param 0.785, fill param 8, score: 0.8335
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0004 segmented (Tiff n°42), gabor param 0.785, fill param 8, score: 0.8016
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0005 segmented (Tiff n°43), gabor param 0.785, fill param 8, score: 0.8465
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0007 segmented (Tiff n°44), gabor param 0.785, fill param 8, score: 0.847
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0008 segmented (Tiff n°45), gabor param 0.785, fill param 8, score: 0.8544
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0009 segmented (Tiff n°46), gabor param 0.785, fill param 8, score: 0.857
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0010 segmented (Tiff n°47), gabor param 0.785, fill param 8, score: 0.8242
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0011 segmented (Tiff n°48), gabor param 0.785, fill param 8, score: 0.8157
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0012 segmented (Tiff n°49), gabor param 0.785, fill param 8, score: 0.8126
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0013 segmented (Tiff n°50), gabor param 0.785, fill param 8, score: 0.8265
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0014 segmented (Tiff n°51), gabor param 0.785, fill param 8, score: 0.8147
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0015 segmented (Tiff n°52), gabor param 0.785, fill param 8, score: 0.8479
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0016 segmented (Tiff n°53), gabor param 0.785, fill param 8, score: 0.8444
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0017 segmented (Tiff n°54), gabor param 0.785, fill param 8, score: 0.8107
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0018 segmented (Tiff n°55), gabor param 0.785, fill param 8, score: 0.8363
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0020 segmented (Tiff n°56), gabor param 0.785, fill param 8, score: 0.807
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0021 segmented (Tiff n°57), gabor param 0.785, fill param 8, score: 0.8295
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0022 segmented (Tiff n°58), gabor param 0.785, fill param 8, score: 0.8266
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0023 segmented (Tiff n°59), gabor param 0.785, fill param 8, score: 0.7936
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0024 segmented (Tiff n°60), gabor param 0.785, fill param 8, score: 0.8376
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0025 segmented (Tiff n°61), gabor param 0.785, fill param 8, score: 0.8025
# CNV_toutValid,CNV1: Tiff CNV015_20210717_118_t1 segmented (Tiff n°62), gabor param 0.785, fill param 8, score: 0.833
# CNV_toutValid,CNV1: Tiff CNV015_20210717_118_t13 segmented (Tiff n°63), gabor param 0.785, fill param 8, score: 0.8116
# CNV_toutValid,CNV1: Tiff CNV015_20210717_118_t25 segmented (Tiff n°64), gabor param 0.785, fill param 8, score: 0.8028
# CNV_toutValid,CNV1: Tiff CNV015_20210717_125_t13 segmented (Tiff n°65), gabor param 0.785, fill param 8, score: 0.8292
# CNV_toutValid,CNV1: Tiff CNV015_20210717_125_t25 segmented (Tiff n°66), gabor param 0.785, fill param 8, score: 0.8466
# CNV_toutValid,CNV1: Tiff CNV015_20210717_128_t1 segmented (Tiff n°67), gabor param 0.785, fill param 8, score: 0.7738
# CNV_toutValid,CNV1: Tiff CNV015_20210717_128_t13 segmented (Tiff n°68), gabor param 0.785, fill param 8, score: 0.8659
# CNV_toutValid,CNV1: Tiff CNV015_20210717_128_t25 segmented (Tiff n°69), gabor param 0.785, fill param 8, score: 0.9036
# CNV_toutValid,CNV1: Tiff CNV016_20210804_434_t49 segmented (Tiff n°70), gabor param 0.785, fill param 8, score: 0.7712
# CNV_toutValid,CNV1: Tiff CNV016_20210804_435_t49 segmented (Tiff n°71), gabor param 0.785, fill param 8, score: 0.7131
# CNV_toutValid,CNV1: Tiff CNV016_20210804_440_t49 segmented (Tiff n°72), gabor param 0.785, fill param 8, score: 0.7359
# CNV_toutValid,CNV1: Tiff CNV016_20210804_441_t49 segmented (Tiff n°73), gabor param 0.785, fill param 8, score: 0.6545
# CNV_toutValid,CNV1: Tiff CNV016_20210804_442_t1 segmented (Tiff n°74), gabor param 0.785, fill param 8, score: 0.7827
# CNV_toutValid,CNV1: Tiff CNV016_20210804_442_t25 segmented (Tiff n°75), gabor param 0.785, fill param 8, score: 0.7468
# CNV_toutValid,CNV1: Tiff CNV016_20210804_442_t49 segmented (Tiff n°76), gabor param 0.785, fill param 8, score: 0.6949
# CNV_toutValid,CNV1: Tiff CNV016_20210804_487_t1 segmented (Tiff n°77), gabor param 0.785, fill param 8, score: 0.8868
# CNV_toutValid,CNV1: Tiff CNV016_20210804_487_t25 segmented (Tiff n°78), gabor param 0.785, fill param 8, score: 0.8819
# CNV_toutValid,CNV1: Tiff CNV016_20210804_487_t49 segmented (Tiff n°79), gabor param 0.785, fill param 8, score: 0.7609
# CNV_toutValid,CNV1: Tiff CNV016_20210804_492_t1 segmented (Tiff n°80), gabor param 0.785, fill param 8, score: 0.8866
# CNV_toutValid,CNV1: Tiff CNV016_20210804_492_t25 segmented (Tiff n°81), gabor param 0.785, fill param 8, score: 0.879
# CNV_toutValid,CNV1: Tiff CNV019_20210904_233_t49 segmented (Tiff n°82), gabor param 0.785, fill param 8, score: 0.8281
# CNV_toutValid,CNV1: Tiff CNV022_016_t1 segmented (Tiff n°83), gabor param 0.785, fill param 8, score: 0.8312
# CNV_toutValid,CNV1: Tiff CNV022_016_t25 segmented (Tiff n°84), gabor param 0.785, fill param 8, score: 0.7695
# CNV_toutValid,CNV1: Tiff CNV022_077_t25 segmented (Tiff n°85), gabor param 0.785, fill param 8, score: 0.7557
# CNV_toutValid,CNV1: Tiff CNV022_077_t47 segmented (Tiff n°86), gabor param 0.785, fill param 8, score: 0.6816
# CNV_toutValid,CNV1: Tiff CNV022_077_t48 segmented (Tiff n°87), gabor param 0.785, fill param 8, score: 0.7036
# CNV_toutValid,CNV1: Tiff CNV022_077_t49 segmented (Tiff n°88), gabor param 0.785, fill param 8, score: 0.6736
# CNV_toutValid,CNV1: Tiff CNV026_117_t41 segmented (Tiff n°89), gabor param 0.785, fill param 8, score: 0.6369
# CNV_toutValid,CNV1: Tiff CNV026_119_t41 segmented (Tiff n°90), gabor param 0.785, fill param 8, score: 0.6668
# CNV_toutValid,CNV1: Tiff CNV026_128_t41 segmented (Tiff n°91), gabor param 0.785, fill param 8, score: 0.7111
# CNV_toutValid,CNV1: Tiff CNV026_136_t41 segmented (Tiff n°92), gabor param 0.785, fill param 8, score: 0.8428
# CNV_toutValid,CNV1: Tiff CNV026_138_t41 segmented (Tiff n°93), gabor param 0.785, fill param 8, score: 0.6913
# CNV_toutValid,CNV1: Tiff CNV026_141_t41 segmented (Tiff n°94), gabor param 0.785, fill param 8, score: 0.6077
# CNV_toutValid,CNV1: Tiff CNV028_38_t41 segmented (Tiff n°95), gabor param 0.785, fill param 8, score: 0.6799
# CNV_toutValid,CNV1: Tiff CNV028_40_t41 segmented (Tiff n°96), gabor param 0.785, fill param 8, score: 0.7275
# CNV_toutValid,CNV1: Tiff CNV028_80_t41 segmented (Tiff n°97), gabor param 0.785, fill param 8, score: 0.8245
# CNV_toutValid,CNV1: Tiff CNV028_82_t41 segmented (Tiff n°98), gabor param 0.785, fill param 8, score: 0.6377
# CNV_toutValid,CNV1: Tiff CNV047_20220520_039_t41 segmented (Tiff n°99), gabor param 0.785, fill param 8, score: 0.7657
# ...
# CNV_toutValid,CNV1: Tiff CNV010_20210606_156_t31 segmented (Tiff n°22), gabor param 0.785, fill param 8, score: 0.7775
# CNV_toutValid,CNV1: Tiff CNV010_20210606_156_t49 segmented (Tiff n°23), gabor param 0.785, fill param 8, score: 0.6442
# CNV_toutValid,CNV1: Tiff CNV011_20210612_205_t1 segmented (Tiff n°24), gabor param 0.785, fill param 8, score: 0.7336
# CNV_toutValid,CNV1: Tiff CNV011_20210612_205_t25 segmented (Tiff n°25), gabor param 0.785, fill param 8, score: 0.7968
# CNV_toutValid,CNV1: Tiff CNV011_20210612_219_t1 segmented (Tiff n°26), gabor param 0.785, fill param 8, score: 0.8398
# CNV_toutValid,CNV1: Tiff CNV011_20210612_219_t49 segmented (Tiff n°27), gabor param 0.785, fill param 8, score: 0.8407
# CNV_toutValid,CNV1: Tiff CNV011_20210612_221_t1 segmented (Tiff n°28), gabor param 0.785, fill param 8, score: 0.7687
# CNV_toutValid,CNV1: Tiff CNV011_20210612_221_t49 segmented (Tiff n°29), gabor param 0.785, fill param 8, score: 0.7543
# CNV_toutValid,CNV1: Tiff CNV012_20210618_409_t1 segmented (Tiff n°30), gabor param 0.785, fill param 8, score: 0.8859
# CNV_toutValid,CNV1: Tiff CNV012_20210618_409_t49 segmented (Tiff n°31), gabor param 0.785, fill param 8, score: 0.8614
# CNV_toutValid,CNV1: Tiff CNV012_20210618_410_t1 segmented (Tiff n°32), gabor param 0.785, fill param 8, score: 0.882
# CNV_toutValid,CNV1: Tiff CNV012_20210618_410_t49 segmented (Tiff n°33), gabor param 0.785, fill param 8, score: 0.8718
# CNV_toutValid,CNV1: Tiff CNV015_20210717_108_t1 segmented (Tiff n°34), gabor param 0.785, fill param 8, score: 0.8486
# CNV_toutValid,CNV1: Tiff CNV015_20210717_108_t13 segmented (Tiff n°35), gabor param 0.785, fill param 8, score: 0.8836
# CNV_toutValid,CNV1: Tiff CNV015_20210717_108_t23 segmented (Tiff n°36), gabor param 0.785, fill param 8, score: 0.903
# CNV_toutValid,CNV1: Tiff CNV015_20210717_108_t24 segmented (Tiff n°37), gabor param 0.785, fill param 8, score: 0.8832
# CNV_toutValid,CNV1: Tiff CNV015_20210717_108_t25 segmented (Tiff n°38), gabor param 0.785, fill param 8, score: 0.8978
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0001 segmented (Tiff n°39), gabor param 0.785, fill param 8, score: 0.8094
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0002 segmented (Tiff n°40), gabor param 0.785, fill param 8, score: 0.8405
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0003 segmented (Tiff n°41), gabor param 0.785, fill param 8, score: 0.8335
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0004 segmented (Tiff n°42), gabor param 0.785, fill param 8, score: 0.8016
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0005 segmented (Tiff n°43), gabor param 0.785, fill param 8, score: 0.8465
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0007 segmented (Tiff n°44), gabor param 0.785, fill param 8, score: 0.847
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0008 segmented (Tiff n°45), gabor param 0.785, fill param 8, score: 0.8544
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0009 segmented (Tiff n°46), gabor param 0.785, fill param 8, score: 0.857
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0010 segmented (Tiff n°47), gabor param 0.785, fill param 8, score: 0.8242
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0011 segmented (Tiff n°48), gabor param 0.785, fill param 8, score: 0.8449
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0012 segmented (Tiff n°49), gabor param 0.785, fill param 8, score: 0.8126
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0013 segmented (Tiff n°50), gabor param 0.785, fill param 8, score: 0.8265
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0014 segmented (Tiff n°51), gabor param 0.785, fill param 8, score: 0.8147
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0015 segmented (Tiff n°52), gabor param 0.785, fill param 8, score: 0.8479
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0016 segmented (Tiff n°53), gabor param 0.785, fill param 8, score: 0.8148
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0017 segmented (Tiff n°54), gabor param 0.785, fill param 8, score: 0.8107
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0018 segmented (Tiff n°55), gabor param 0.785, fill param 8, score: 0.8076
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0020 segmented (Tiff n°56), gabor param 0.785, fill param 8, score: 0.807
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0021 segmented (Tiff n°57), gabor param 0.785, fill param 8, score: 0.8021
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0022 segmented (Tiff n°58), gabor param 0.785, fill param 8, score: 0.8266
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0023 segmented (Tiff n°59), gabor param 0.785, fill param 8, score: 0.7936
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0024 segmented (Tiff n°60), gabor param 0.785, fill param 8, score: 0.8376
# CNV_toutValid,CNV1: Tiff CNV015_20210717_110_25-0025 segmented (Tiff n°61), gabor param 0.785, fill param 8, score: 0.8025
# CNV_toutValid,CNV1: Tiff CNV015_20210717_118_t1 segmented (Tiff n°62), gabor param 0.785, fill param 8, score: 0.833
# CNV_toutValid,CNV1: Tiff CNV015_20210717_118_t13 segmented (Tiff n°63), gabor param 0.785, fill param 8, score: 0.8116
# CNV_toutValid,CNV1: Tiff CNV015_20210717_118_t25 segmented (Tiff n°64), gabor param 0.785, fill param 8, score: 0.8028
# CNV_toutValid,CNV1: Tiff CNV015_20210717_125_t13 segmented (Tiff n°65), gabor param 0.785, fill param 8, score: 0.8292
# CNV_toutValid,CNV1: Tiff CNV015_20210717_125_t25 segmented (Tiff n°66), gabor param 0.785, fill param 8, score: 0.8466
# CNV_toutValid,CNV1: Tiff CNV015_20210717_128_t1 segmented (Tiff n°67), gabor param 0.785, fill param 8, score: 0.7738
# CNV_toutValid,CNV1: Tiff CNV015_20210717_128_t13 segmented (Tiff n°68), gabor param 0.785, fill param 8, score: 0.8659
# CNV_toutValid,CNV1: Tiff CNV015_20210717_128_t25 segmented (Tiff n°69), gabor param 0.785, fill param 8, score: 0.9036
# CNV_toutValid,CNV1: Tiff CNV016_20210804_434_t49 segmented (Tiff n°70), gabor param 0.785, fill param 8, score: 0.7712
# CNV_toutValid,CNV1: Tiff CNV016_20210804_435_t49 segmented (Tiff n°71), gabor param 0.785, fill param 8, score: 0.7131
# CNV_toutValid,CNV1: Tiff CNV016_20210804_440_t49 segmented (Tiff n°72), gabor param 0.785, fill param 8, score: 0.7359
# CNV_toutValid,CNV1: Tiff CNV016_20210804_441_t49 segmented (Tiff n°73), gabor param 0.785, fill param 8, score: 0.6545
# CNV_toutValid,CNV1: Tiff CNV016_20210804_442_t1 segmented (Tiff n°74), gabor param 0.785, fill param 8, score: 0.7827
# CNV_toutValid,CNV1: Tiff CNV016_20210804_442_t25 segmented (Tiff n°75), gabor param 0.785, fill param 8, score: 0.7468
# CNV_toutValid,CNV1: Tiff CNV016_20210804_442_t49 segmented (Tiff n°76), gabor param 0.785, fill param 8, score: 0.6949
# CNV_toutValid,CNV1: Tiff CNV016_20210804_487_t1 segmented (Tiff n°77), gabor param 0.785, fill param 8, score: 0.8868
# CNV_toutValid,CNV1: Tiff CNV016_20210804_487_t25 segmented (Tiff n°78), gabor param 0.785, fill param 8, score: 0.8819
# CNV_toutValid,CNV1: Tiff CNV016_20210804_487_t49 segmented (Tiff n°79), gabor param 0.785, fill param 8, score: 0.7609
# CNV_toutValid,CNV1: Tiff CNV016_20210804_492_t1 segmented (Tiff n°80), gabor param 0.785, fill param 8, score: 0.8866
# CNV_toutValid,CNV1: Tiff CNV016_20210804_492_t25 segmented (Tiff n°81), gabor param 0.785, fill param 8, score: 0.879
# CNV_toutValid,CNV1: Tiff CNV019_20210904_233_t49 segmented (Tiff n°82), gabor param 0.785, fill param 8, score: 0.8281
# CNV_toutValid,CNV1: Tiff CNV022_016_t1 segmented (Tiff n°83), gabor param 0.785, fill param 8, score: 0.8312
# CNV_toutValid,CNV1: Tiff CNV022_016_t25 segmented (Tiff n°84), gabor param 0.785, fill param 8, score: 0.7695
# CNV_toutValid,CNV1: Tiff CNV022_077_t25 segmented (Tiff n°85), gabor param 0.785, fill param 8, score: 0.7557
# CNV_toutValid,CNV1: Tiff CNV022_077_t47 segmented (Tiff n°86), gabor param 0.785, fill param 8, score: 0.6816
# CNV_toutValid,CNV1: Tiff CNV022_077_t48 segmented (Tiff n°87), gabor param 0.785, fill param 8, score: 0.7036
# CNV_toutValid,CNV1: Tiff CNV022_077_t49 segmented (Tiff n°88), gabor param 0.785, fill param 8, score: 0.6736
# CNV_toutValid,CNV1: Tiff CNV026_117_t41 segmented (Tiff n°89), gabor param 0.785, fill param 8, score: 0.6174
# CNV_toutValid,CNV1: Tiff CNV026_119_t41 segmented (Tiff n°90), gabor param 0.785, fill param 8, score: 0.6867
# CNV_toutValid,CNV1: Tiff CNV026_128_t41 segmented (Tiff n°91), gabor param 0.785, fill param 8, score: 0.7111
# CNV_toutValid,CNV1: Tiff CNV026_136_t41 segmented (Tiff n°92), gabor param 0.785, fill param 8, score: 0.8428
# CNV_toutValid,CNV1: Tiff CNV026_138_t41 segmented (Tiff n°93), gabor param 0.785, fill param 8, score: 0.703
# CNV_toutValid,CNV1: Tiff CNV026_141_t41 segmented (Tiff n°94), gabor param 0.785, fill param 8, score: 0.5844
# CNV_toutValid,CNV1: Tiff CNV028_38_t41 segmented (Tiff n°95), gabor param 0.785, fill param 8, score: 0.645
# CNV_toutValid,CNV1: Tiff CNV028_40_t41 segmented (Tiff n°96), gabor param 0.785, fill param 8, score: 0.7275
# CNV_toutValid,CNV1: Tiff CNV028_80_t41 segmented (Tiff n°97), gabor param 0.785, fill param 8, score: 0.8245
# CNV_toutValid,CNV1: Tiff CNV028_82_t41 segmented (Tiff n°98), gabor param 0.785, fill param 8, score: 0.6377
# CNV_toutValid,CNV1: Tiff CNV047_20220520_039_t41 segmented (Tiff n°99), gabor param 0.785, fill param 8, score: 0.7657
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0037 segmented (Tiff n°135), gabor param 0.785, fill param 8, score: 0.867
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0038 segmented (Tiff n°136), gabor param 0.785, fill param 8, score: 0.8776
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0039 segmented (Tiff n°137), gabor param 0.785, fill param 8, score: 0.8943
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0040 segmented (Tiff n°138), gabor param 0.785, fill param 8, score: 0.8692
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0041 segmented (Tiff n°139), gabor param 0.785, fill param 8, score: 0.8749
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0042 segmented (Tiff n°140), gabor param 0.785, fill param 8, score: 0.8637
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0043 segmented (Tiff n°141), gabor param 0.785, fill param 8, score: 0.866
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0044 segmented (Tiff n°142), gabor param 0.785, fill param 8, score: 0.8697
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0045 segmented (Tiff n°143), gabor param 0.785, fill param 8, score: 0.8766
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0046 segmented (Tiff n°144), gabor param 0.785, fill param 8, score: 0.8792
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0047 segmented (Tiff n°145), gabor param 0.785, fill param 8, score: 0.8624
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0048 segmented (Tiff n°146), gabor param 0.785, fill param 8, score: 0.8775
# CNV_toutValid,CNV1: Tiff CNV049_20220610_200-0049 segmented (Tiff n°147), gabor param 0.785, fill param 8, score: 0.9035
# CNV_toutValid,CNV1: Tiff CNV053_20220623_286_t49 segmented (Tiff n°148), gabor param 0.785, fill param 8, score: 0.8092
# CNV_toutValid,CNV1: Tiff CNV062_096_t48 segmented (Tiff n°149), gabor param 0.785, fill param 8, score: 0.704
# CNV_toutValid,CNV1: Tiff CNV062_119_t48 segmented (Tiff n°150), gabor param 0.785, fill param 8, score: 0.6018
# CNV_toutValid,CNV1: Tiff CNV062_208_t48 segmented (Tiff n°151), gabor param 0.785, fill param 8, score: 0.8164
# CNV_toutValid,CNV1: Tiff CNV062_211_t19 segmented (Tiff n°152), gabor param 0.785, fill param 8, score: 0.8461
# CNV_toutValid,CNV1: Tiff CNV062_211_t48 segmented (Tiff n°153), gabor param 0.785, fill param 8, score: 0.8524
#    gabor_param  fill_param  Min_pixels  Dice scores
# 0        0.785           8        3700     0.831216
# 1        0.785           8        3800     0.830872
# 2        0.785           8        3900     0.830646
# 3        0.785           8        4000     0.830094
# 4        0.785           8        4100     0.829443

# %% [markdown]
# ## Predict on Test set with best hyperparameters

# %%
file_dir = '/Users/aaronmamann/Desktop/Cleaned_Datasets_Clemence/Validation/test' # change this into your own path
image_files_name = 'Source images'
mask_files_name = 'Masks'
dice_scores = np.array(list(create_masks(file_dir,image_files_name,mask_files_name,gabor_parameter=0.78,fill_cells=5,thresh_small_objects=3700,save_predicted_mask=True,compute_score=True).values()))

print('The mean of all the dice scores on the test set is :')
print(dice_scores.mean())
print ('The standard deviation of all the dice scores on the test set is')
print(dice_scores.std())
# Out:
# /Users/aaronmamann/miniforge3/envs/migrationpytorch/lib/python3.9/site-packages/skimage/util/dtype.py:541: UserWarning: Downcasting uint16 to uint8 without scaling because max value 255 fits in uint8
#   return _convert(image, np.uint8, force_copy)
# /var/folders/z5/z6s0xgdd01xc3rwwp0fs0yxc0000gn/T/ipykernel_12406/2364216888.py:87: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   tiff.imsave("".join([type_dir,'/masks_predicted/',os.path.basename(sequence)]),predicted_mask)
# CNV_mutiples: Tiff CNV010_20210606_066_t24 segmented (Tiff n°1), gabor param 0.78, fill param 5, score: 0.9027
# CNV_mutiples: Tiff CNV010_20210606_072_t1 segmented (Tiff n°2), gabor param 0.78, fill param 5, score: 0.8157
# CNV_mutiples: Tiff CNV010_20210606_072_t25 segmented (Tiff n°3), gabor param 0.78, fill param 5, score: 0.6241
# CNV_mutiples: Tiff CNV010_20210606_095_t7 segmented (Tiff n°4), gabor param 0.78, fill param 5, score: 0.8922
# CNV_mutiples: Tiff CNV011_20210612_205_t25 segmented (Tiff n°5), gabor param 0.78, fill param 5, score: 0.8
# CNV_mutiples: Tiff CNV015_20210717_108_t22 segmented (Tiff n°6), gabor param 0.78, fill param 5, score: 0.8843
# CNV_mutiples: Tiff CNV015_20210717_108_t25 segmented (Tiff n°7), gabor param 0.78, fill param 5, score: 0.8991
# CNV_mutiples: Tiff CNV015_20210717_110_25-0008 segmented (Tiff n°8), gabor param 0.78, fill param 5, score: 0.8572
# CNV_mutiples: Tiff CNV015_20210717_110_25-0011 segmented (Tiff n°9), gabor param 0.78, fill param 5, score: 0.8184
# CNV_mutiples: Tiff CNV015_20210717_110_25-0012 segmented (Tiff n°10), gabor param 0.78, fill param 5, score: 0.8135
# CNV_mutiples: Tiff CNV015_20210717_110_25-0013 segmented (Tiff n°11), gabor param 0.78, fill param 5, score: 0.8279
# CNV_mutiples: Tiff CNV015_20210717_110_25-0019 segmented (Tiff n°12), gabor param 0.78, fill param 5, score: 0.8109
# CNV_mutiples: Tiff CNV015_20210717_110_25-0025 segmented (Tiff n°13), gabor param 0.78, fill param 5, score: 0.7972
# CNV_mutiples: Tiff CNV015_20210717_118_t13 segmented (Tiff n°14), gabor param 0.78, fill param 5, score: 0.8149
# CNV_mutiples: Tiff CNV015_20210717_125_t1 segmented (Tiff n°15), gabor param 0.78, fill param 5, score: 0.8892
# CNV_mutiples: Tiff CNV015_20210717_128_t1 segmented (Tiff n°16), gabor param 0.78, fill param 5, score: 0.7764
# CNV_mutiples: Tiff CNV015_20210717_128_t13 segmented (Tiff n°17), gabor param 0.78, fill param 5, score: 0.8651
# CNV_mutiples: Tiff CNV016_20210804_442_t25 segmented (Tiff n°18), gabor param 0.78, fill param 5, score: 0.7545
# CNV_mutiples: Tiff CNV016_20210804_442_t49 segmented (Tiff n°19), gabor param 0.78, fill param 5, score: 0.7288
# CNV_mutiples: Tiff CNV016_20210804_487_t1 segmented (Tiff n°20), gabor param 0.78, fill param 5, score: 0.8918
# CNV_mutiples: Tiff CNV016_20210804_487_t25 segmented (Tiff n°21), gabor param 0.78, fill param 5, score: 0.8837
# CNV_mutiples: Tiff CNV016_20210804_487_t49 segmented (Tiff n°22), gabor param 0.78, fill param 5, score: 0.767
# CNV_mutiples: Tiff CNV016_20210804_492_t1 segmented (Tiff n°23), gabor param 0.78, fill param 5, score: 0.8915
# CNV_mutiples: Tiff CNV016_20210804_492_t25 segmented (Tiff n°24), gabor param 0.78, fill param 5, score: 0.8811
# CNV_mutiples: Tiff CNV019_20210904_233_t49 segmented (Tiff n°25), gabor param 0.78, fill param 5, score: 0.8306
# CNV_mutiples: Tiff CNV022_016_t1 segmented (Tiff n°26), gabor param 0.78, fill param 5, score: 0.8247
# CNV_mutiples: Tiff CNV022_016_t25 segmented (Tiff n°27), gabor param 0.78, fill param 5, score: 0.7661
# CNV_mutiples: Tiff CNV022_077_t48 segmented (Tiff n°28), gabor param 0.78, fill param 5, score: 0.6872
# CNV_mutiples: Tiff CNV026_119_t41 segmented (Tiff n°29), gabor param 0.78, fill param 5, score: 0.6763
# CNV_mutiples: Tiff CNV026_128_t41 segmented (Tiff n°30), gabor param 0.78, fill param 5, score: 0.7214
# CNV_mutiples: Tiff CNV028_82_t41 segmented (Tiff n°31), gabor param 0.78, fill param 5, score: 0.6396
# CNV_mutiples: Tiff CNV049_20220610_200-0001 segmented (Tiff n°32), gabor param 0.78, fill param 5, score: 0.8991
# CNV_mutiples: Tiff CNV049_20220610_200-0002 segmented (Tiff n°33), gabor param 0.78, fill param 5, score: 0.8992
# CNV_mutiples: Tiff CNV049_20220610_200-0004 segmented (Tiff n°34), gabor param 0.78, fill param 5, score: 0.9046
# CNV_mutiples: Tiff CNV049_20220610_200-0009 segmented (Tiff n°35), gabor param 0.78, fill param 5, score: 0.9183
# CNV_mutiples: Tiff CNV049_20220610_200-0012 segmented (Tiff n°36), gabor param 0.78, fill param 5, score: 0.9075
# CNV_mutiples: Tiff CNV049_20220610_200-0014 segmented (Tiff n°37), gabor param 0.78, fill param 5, score: 0.9115
# CNV_mutiples: Tiff CNV049_20220610_200-0015 segmented (Tiff n°38), gabor param 0.78, fill param 5, score: 0.9292
# CNV_mutiples: Tiff CNV049_20220610_200-0017 segmented (Tiff n°39), gabor param 0.78, fill param 5, score: 0.8988
# CNV_mutiples: Tiff CNV049_20220610_200-0018 segmented (Tiff n°40), gabor param 0.78, fill param 5, score: 0.9049
# CNV_mutiples: Tiff CNV049_20220610_200-0035 segmented (Tiff n°41), gabor param 0.78, fill param 5, score: 0.9139
# CNV_mutiples: Tiff CNV049_20220610_200-0041 segmented (Tiff n°42), gabor param 0.78, fill param 5, score: 0.8777
# CNV_mutiples: Tiff CNV049_20220610_200-0042 segmented (Tiff n°43), gabor param 0.78, fill param 5, score: 0.8665
# CNV_mutiples: Tiff CNV049_20220610_200-0044 segmented (Tiff n°44), gabor param 0.78, fill param 5, score: 0.8693
# CNV_mutiples: Tiff CNV049_20220610_200-0047 segmented (Tiff n°45), gabor param 0.78, fill param 5, score: 0.8648
# CNV_mutiples: Tiff CNV049_20220610_200-0048 segmented (Tiff n°46), gabor param 0.78, fill param 5, score: 0.88
# CNV_mutiples: Tiff CNV062_096_t48 segmented (Tiff n°47), gabor param 0.78, fill param 5, score: 0.7012
# CNV_mutiples: Tiff CNV062_119_t48 segmented (Tiff n°48), gabor param 0.78, fill param 5, score: 0.5848
# The mean of all the dice scores on the test set is :
# 0.8284164493282636
# The standard deviation of all the dice scores on the test set is
# 0.08517784348507236
