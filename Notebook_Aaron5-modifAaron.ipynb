# %% [markdown]
# # Notebook on segmentation of cluster of cells
#
# Author : Aaron MAMANN

# %% [markdown]
# ## Libraries

# %%
import os
import PIL
from PIL import Image, ImageOps, ImageEnhance, __version__ as PILLOW_VERSION
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
import re
import random
from natsort import natsorted
import glob
from skimage import img_as_ubyte
import skimage 
from skimage.transform import rescale, resize, downscale_local_mean
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision 
from torchvision import transforms
#from torchmetrics import Dice 
from scipy.spatial import distance 
import shutil
#import cv2
import csv
from skimage.measure import label, regionprops, regionprops_table
import tifffile
import tifffile as tiff
from pathlib import Path
from tqdm.notebook import tqdm

# %%
import torch
from torchmetrics import JaccardIndex

preds  = torch.tensor([0, 0, 1, 0])
target = torch.tensor([1, 1, 1, 0])

Jac=JaccardIndex(task="binary",average='none',num_classes=2)
Jac(preds, target)
#dice = Dice(average=None,num_classes=2)
# Out:
# tensor(0.3333)

# %% [markdown]
# ## Main Function : Galbor Filter with specific Preprocessing and PostProcessing Functions

# %%
def create_masks(file_dir,image_files_name,mask_files_name,gabor_parameter,fill_cells,experiment_name='CNV',save_predicted_mask=True,compute_score=True,ratio_first_thresh=300/(1920*1440),ratio_small_object_thresh=3700/(1920*1440),ratio_thresh_big_objects=30000/(1920*1440),ratio_canal_diameter=100/1440 ):

    experiment_types_dir = [  "".join([file_dir,'/',f]) for f in natsorted(os.listdir(file_dir)) if experiment_name in f]  
    
    if compute_score : 
        score_experiment=dict()
    
    for type_dir in experiment_types_dir:
        l=0
        conditions_experiment= [  f for f in natsorted(os.listdir(type_dir) ) if experiment_name in f]    
        for condition in conditions_experiment : 
            sequences=[ "".join([type_dir,'/',condition,'/',image_files_name,'/',f]) for f in  natsorted(os.listdir( "".join([type_dir,'/',condition,'/',image_files_name]) )) if experiment_name in f]
            if save_predicted_mask :         
                Path("".join([type_dir,'/',condition,'/masks_predicted/'])).mkdir(parents=True, exist_ok=True)
                                              
            for sequence in sequences:
          
                images_in_tiff = tifffile.imread(sequence)              
                if np.ndim(images_in_tiff)==2 :
                    images_in_tiff = np.expand_dims(images_in_tiff, axis=0)
                nb_images_in_tiff = len(images_in_tiff)
                predicted_mask=list()
            
                if compute_score : 
                    masks_in_tiff = tifffile.imread( "".join([type_dir,'/',condition,'/',mask_files_name,'/',os.path.basename(sequence).replace(".tif", "_mask.tif") ]) )
                    if np.ndim(masks_in_tiff)==2 :
                        masks_in_tiff = np.expand_dims(masks_in_tiff, axis=0)
                    score_sequence=0
            
                j=0         
                for index_one_image in range(nb_images_in_tiff): 
                    nb_pixels=images_in_tiff[index_one_image].shape[0]*images_in_tiff[index_one_image].shape[1]
                    nb_vertical_pixels=images_in_tiff[index_one_image].shape[0]
                    thresh_small_objects=ratio_small_object_thresh*nb_pixels
                    first_thresh=ratio_first_thresh*nb_pixels
                    im_original=skimage.morphology.remove_small_objects(scipy.ndimage.binary_fill_holes(skimage.morphology.binary_closing(skimage.morphology.remove_small_objects(scipy.ndimage.binary_fill_holes(skimage.filters.gabor(img_as_ubyte(skimage.exposure.rescale_intensity(images_in_tiff[index_one_image])),gabor_parameter)[1]),min_size=first_thresh, connectivity=1),footprint=np.ones((fill_cells,fill_cells)))),min_size=thresh_small_objects,connectivity=1)
                    im_original = img_as_ubyte(im_original)
                    labeled_im = label(im_original)

                    canal_diameter=ratio_canal_diameter*nb_vertical_pixels 
                    props = regionprops(labeled_im)
                    for i in range(len(props)) :
                        if abs(props[i].bbox[2]-props[i].bbox[0])>canal_diameter :
                            im_original[props[i].bbox[0]:props[i].bbox[2]+1,props[i].bbox[1]:props[i].bbox[3]+1] = 0
        
                    im_original=img_as_ubyte(skimage.morphology.remove_small_objects(np.array(im_original,dtype=bool),min_size=thresh_small_objects,connectivity=1))
                    new_image=img_as_ubyte(np.pad(im_original, (50, 50),'constant',constant_values=255))  
                    thresh_big_objects=ratio_thresh_big_objects*nb_pixels 
                    im_big_objects=img_as_ubyte(skimage.morphology.remove_small_objects(np.array(np.pad(im_original, (50, 50), 'constant', constant_values=255),dtype=bool),min_size=thresh_big_objects)) 
                    new_image = new_image - im_big_objects
                    shape_im = new_image.shape
                    new_image=new_image[50:shape_im[0]-50,50:shape_im[1]-50]   
                    if compute_score : 
                        true_mask = img_as_ubyte(masks_in_tiff[index_one_image])
                        #dice = Dice(average=None,num_classes=2)
                        #dice = Dice(average=None)
                        #dice = Dice()
                        Jac=JaccardIndex(task="binary",average='none',num_classes=2)
                        score_sequence = score_sequence + Jac(torch.where(torch.from_numpy(new_image)> 0, 1, 0), torch.where(torch.from_numpy(true_mask)> 0, 1, 0)).numpy()    
                                                                         
                    if j==0:
                        predicted_mask=[np.array(new_image, dtype=np.uint16)]                 
                    else:
                        predicted_mask=np.append(predicted_mask,[np.array(new_image, dtype=np.uint16)],axis=0)
                    j=j+1
                 
                if save_predicted_mask :       
                    tiff.imsave("".join([type_dir,'/',condition,'/masks_predicted/',os.path.basename(sequence)]),predicted_mask)
            
                if compute_score : 
                    score_sequence = score_sequence/nb_images_in_tiff
                    score_experiment[sequence] = score_sequence
                l=l+1
                if compute_score : 
                    print("".join([os.path.basename(type_dir),',',condition,': Tiff ',str(os.path.basename(sequence).replace(".tif", " ")),'segmented (Tiff n°', str(l) ,'), gabor param ',str(gabor_parameter), ', fill param ', str(fill_cells), ', score: ', str(round(score_sequence, 4)) ]))        
    if compute_score : 
        return score_experiment

# %%
# Clémence you have to simulate that, the following part is the training and the test which allowed to find the value of gabor parameter (equal to 0.78)
# and the value of the fill cell parameter (equal to 5) 

file_dir='/Users/aaronmamann/Desktop/Cleaned_Datasets_Clemence/DT2' # change this into your own path
image_files_name = 'Source images'
mask_files_name = 'Masks'

create_masks(file_dir,image_files_name,mask_files_name,gabor_parameter=0.78,fill_cells=5,save_predicted_mask=True,compute_score=True)
# Out:
# /var/folders/z5/z6s0xgdd01xc3rwwp0fs0yxc0000gn/T/ipykernel_94786/2179804567.py:65: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   tiff.imsave("".join([type_dir,'/',condition,'/masks_predicted/',os.path.basename(sequence)]),predicted_mask)
# CNV1,CNV1_Coll_Ct: Tiff CNV006_20210430_782_t8 segmented (Tiff n°1), gabor param 0.78, fill param 5, score: 0.8529
# CNV1,CNV1_Coll_Ct: Tiff CNV006_20210430_787_t8 segmented (Tiff n°2), gabor param 0.78, fill param 5, score: 0.7381
# CNV1,CNV1_Coll_Ct: Tiff CNV006_20210430_791_t8 segmented (Tiff n°3), gabor param 0.78, fill param 5, score: 0.856
# CNV1,CNV1_Coll_Ct: Tiff CNV006_20210430_793_t8 segmented (Tiff n°4), gabor param 0.78, fill param 5, score: 0.8054
# CNV1,CNV1_Coll_Ct: Tiff CNV010_20210606_065_t1 segmented (Tiff n°5), gabor param 0.78, fill param 5, score: 0.8955
# CNV1,CNV1_Coll_Ct: Tiff CNV010_20210606_065_t25 segmented (Tiff n°6), gabor param 0.78, fill param 5, score: 0.848
# CNV1,CNV1_Coll_Ct: Tiff CNV010_20210606_066_t1 segmented (Tiff n°7), gabor param 0.78, fill param 5, score: 0.8395
# CNV1,CNV1_Coll_Ct: Tiff CNV010_20210606_066_t24 segmented (Tiff n°8), gabor param 0.78, fill param 5, score: 0.9027
# CNV1,CNV1_Coll_Ct: Tiff CNV010_20210606_067_t1 segmented (Tiff n°9), gabor param 0.78, fill param 5, score: 0.9203
# CNV1,CNV1_Coll_Ct: Tiff CNV010_20210606_067_t25 segmented (Tiff n°10), gabor param 0.78, fill param 5, score: 0.7062
# CNV1,CNV1_Coll_Ct: Tiff CNV010_20210606_072_t1 segmented (Tiff n°11), gabor param 0.78, fill param 5, score: 0.8157
# CNV1,CNV1_Coll_Ct: Tiff CNV010_20210606_072_t25 segmented (Tiff n°12), gabor param 0.78, fill param 5, score: 0.6241
# CNV1,CNV1_Coll_Ct: Tiff CNV010_20210606_095_t7 segmented (Tiff n°13), gabor param 0.78, fill param 5, score: 0.8922
# CNV1,CNV1_Coll_Ct: Tiff CNV010_20210606_095_t31 segmented (Tiff n°14), gabor param 0.78, fill param 5, score: 0.8971
# CNV1,CNV1_Coll_Ct: Tiff CNV010_20210606_095_t49 segmented (Tiff n°15), gabor param 0.78, fill param 5, score: 0.914
# CNV1,CNV1_Coll_Ct: Tiff CNV010_20210606_111_t31 segmented (Tiff n°16), gabor param 0.78, fill param 5, score: 0.8533
# CNV1,CNV1_Coll_Ct: Tiff CNV010_20210606_111_t49 segmented (Tiff n°17), gabor param 0.78, fill param 5, score: 0.882
# CNV1,CNV1_Coll_Ct: Tiff CNV010_20210606_137_t7 segmented (Tiff n°18), gabor param 0.78, fill param 5, score: 0.8861
# CNV1,CNV1_Coll_Ct: Tiff CNV010_20210606_137_t31 segmented (Tiff n°19), gabor param 0.78, fill param 5, score: 0.7819
# CNV1,CNV1_Coll_Ct: Tiff CNV010_20210606_137_t49 segmented (Tiff n°20), gabor param 0.78, fill param 5, score: 0.8794
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/aaronmamann/Documents/Maria_Project/Notebook_Aaron5.ipynb Cellule 6 in <cell line: 8>()
#       <a href='vscode-notebook-cell:/Users/aaronmamann/Documents/Maria_Project/Notebook_Aaron5.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> image_files_name = 'Source images'
#       <a href='vscode-notebook-cell:/Users/aaronmamann/Documents/Maria_Project/Notebook_Aaron5.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a> mask_files_name = 'Masks'
# ----> <a href='vscode-notebook-cell:/Users/aaronmamann/Documents/Maria_Project/Notebook_Aaron5.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a> create_masks(file_dir,image_files_name,mask_files_name,gabor_parameter=0.78,fill_cells=5,save_predicted_mask=True,compute_score=True)
#
# /Users/aaronmamann/Documents/Maria_Project/Notebook_Aaron5.ipynb Cellule 6 in create_masks(file_dir, image_files_name, mask_files_name, gabor_parameter, fill_cells, experiment_name, save_predicted_mask, compute_score, ratio_first_thresh, ratio_small_object_thresh, ratio_thresh_big_objects, ratio_canal_diameter)
#      <a href='vscode-notebook-cell:/Users/aaronmamann/Documents/Maria_Project/Notebook_Aaron5.ipynb#W5sZmlsZQ%3D%3D?line=33'>34</a> thresh_small_objects=ratio_small_object_thresh*nb_pixels
#      <a href='vscode-notebook-cell:/Users/aaronmamann/Documents/Maria_Project/Notebook_Aaron5.ipynb#W5sZmlsZQ%3D%3D?line=34'>35</a> first_thresh=ratio_first_thresh*nb_pixels
# ---> <a href='vscode-notebook-cell:/Users/aaronmamann/Documents/Maria_Project/Notebook_Aaron5.ipynb#W5sZmlsZQ%3D%3D?line=35'>36</a> im_original=skimage.morphology.remove_small_objects(scipy.ndimage.binary_fill_holes(skimage.morphology.binary_closing(skimage.morphology.remove_small_objects(scipy.ndimage.binary_fill_holes(skimage.filters.gabor(img_as_ubyte(skimage.exposure.rescale_intensity(images_in_tiff[index_one_image])),gabor_parameter)[1]),min_size=first_thresh, connectivity=1),footprint=np.ones((fill_cells,fill_cells)))),min_size=thresh_small_objects,connectivity=1)
#      <a href='vscode-notebook-cell:/Users/aaronmamann/Documents/Maria_Project/Notebook_Aaron5.ipynb#W5sZmlsZQ%3D%3D?line=36'>37</a> im_original = img_as_ubyte(im_original)
#      <a href='vscode-notebook-cell:/Users/aaronmamann/Documents/Maria_Project/Notebook_Aaron5.ipynb#W5sZmlsZQ%3D%3D?line=37'>38</a> labeled_im = label(im_original)
#
# File ~/miniforge3/envs/migrationpytorch/lib/python3.9/site-packages/scipy/ndimage/_morphology.py:1108, in binary_fill_holes(input, structure, output, origin)
#    1106     numpy.logical_not(output, output)
#    1107 else:
# -> 1108     output = binary_dilation(tmp, structure, -1, mask, None, 1,
#    1109                              origin)
#    1110     numpy.logical_not(output, output)
#    1111     return output
#
# File ~/miniforge3/envs/migrationpytorch/lib/python3.9/site-packages/scipy/ndimage/_morphology.py:517, in binary_dilation(input, structure, iterations, mask, output, border_value, origin, brute_force)
#     514     if not structure.shape[ii] & 1:
#     515         origin[ii] -= 1
# --> 517 return _binary_erosion(input, structure, iterations, mask,
#     518                        output, border_value, origin, 1, brute_force)
#
# File ~/miniforge3/envs/migrationpytorch/lib/python3.9/site-packages/scipy/ndimage/_morphology.py:269, in _binary_erosion(input, structure, iterations, mask, output, border_value, origin, invert, brute_force)
#     267     if not structure.flags.contiguous:
#     268         structure = structure.copy()
# --> 269     _nd_image.binary_erosion2(output, structure, mask, iterations - 1,
#     270                               origin, invert, coordinate_list)
#     271 else:
#     272     tmp_in = numpy.empty_like(input, dtype=bool)
#
# KeyboardInterrupt:

# %% [markdown]
# # Allocate randomly .tif file into the training set and the test set

# %%
# This function moves some tif files into a file used for training (tuning the gabor parameter, 
# fill parameter, minimum number of pixels parameter) and into another file used for testing

def create_training_and_test_files_for_each_experiment(file_dir,image_files_name,mask_files_name,experiment_name='CNV'):
                 
    l=0
    sequences=[ "".join([file_dir,'/',image_files_name,'/',f]) for f in  natsorted(os.listdir( "".join([file_dir,'/',image_files_name]) )) if experiment_name in f]
    training_set=random.sample(sequences, k=int(len(sequences)*0.7))
    test_set=list(set(sequences) - set(training_set))
    
    Path("".join([file_dir,'/training/CNV_mutiples/Source images/'])).mkdir(parents=True, exist_ok=True)
    Path("".join([file_dir,'/training/CNV_mutiples/Masks/'])).mkdir(parents=True, exist_ok=True)
    
    for sequence in training_set:
        os.replace(sequence, "".join([file_dir,'/training/CNV_mutiples/Source images/',os.path.basename(sequence)]))
        os.replace( "".join([file_dir,'/',mask_files_name,'/',os.path.basename(sequence).replace(".tif", "_mask.tif") ]), "".join([file_dir,'/training/CNV_mutiples/Masks/',os.path.basename(sequence).replace(".tif", "_mask.tif") ]))
        
    Path("".join([file_dir,'/test/CNV_mutiples/Source images/'])).mkdir(parents=True, exist_ok=True)
    Path("".join([file_dir,'/test/CNV_mutiples/Masks/'])).mkdir(parents=True, exist_ok=True)
    
    for sequence in test_set:
        os.replace(sequence, "".join([file_dir,'/test/CNV_mutiples/Source images/',os.path.basename(sequence)]))
        os.replace( "".join([file_dir,'/',mask_files_name,'/',os.path.basename(sequence).replace(".tif", "_mask.tif") ]), "".join([file_dir,'/test/CNV_mutiples/Masks/',os.path.basename(sequence).replace(".tif", "_mask.tif") ]))
     
    shutil.rmtree("".join([file_dir,'/',image_files_name]) ) 
    shutil.rmtree("".join([file_dir,'/',mask_files_name]) )

# %%
# We execute this function to create a training file (with images and masks) and a test file (with images and masks)

file_dir='/Users/aaronmamann/Desktop/Cleaned_Datasets_Clemence/Validation' # change this into your own path
create_training_and_test_files_for_each_experiment(file_dir=file_dir,image_files_name='Source images',mask_files_name='Masks',experiment_name='CNV')

# %% [markdown]
# ## Tuning hyperparameters (gabor, fill, number pixels for mask) on training set

# %%
file_dir = '/Users/clemence/Documents_Clémence/Analysis/Tracking algorithm/Tracking-seg_Aaron-Gus_CNV/230113-CNV-optimization/training' # change this into your own path
image_files_name = 'Source images'
mask_files_name = 'Masks'

# We are going to tune jointly the gabor parameter and the fill parameter on the training set

hyperparameter_candidates = [[0.76,5],[0.77,5],[0.78,5],[0.79,5],[0.76,10],[0.77,10],[0.78,10],[0.79,10],[0.76,15],[0.77,15],[0.78,15],[0.79,15],[0.76,20],[0.77,20],[0.78,20],[0.79,20] ]
dice_score_hyperparameters = list(map(lambda x: [x[0],x[1],np.array(list(create_masks(file_dir,image_files_name,mask_files_name,gabor_parameter=x[0],fill_cells=x[1],save_predicted_mask=False).values())).mean() ] , hyperparameter_candidates))
df_dice_scores=pd.DataFrame(dice_score_hyperparameters)
#df_dice_scores.columns = ['gabor_param', 'fill_param', 'Min_pixels', 'Dice scores']
df_dice_scores.columns = ['gabor_param', 'fill_param', 'Dice scores']
df_dice_scores
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [5], line 8
#       5 # We are going to tune jointly the gabor parameter and the fill parameter on the training set
#       7 hyperparameter_candidates = [[0.76,5],[0.77,5],[0.78,5],[0.79,5],[0.76,10],[0.77,10],[0.78,10],[0.79,10],[0.76,15],[0.77,15],[0.78,15],[0.79,15],[0.76,20],[0.77,20],[0.78,20],[0.79,20] ]
# ----> 8 dice_score_hyperparameters = list(map(lambda x: [x[0],x[1],np.array(list(create_masks(file_dir,image_files_name,mask_files_name,gabor_parameter=x[0],fill_cells=x[1],save_predicted_mask=False).values())).mean() ] , hyperparameter_candidates))
#       9 df_dice_scores=pd.DataFrame(dice_score_hyperparameters)
#      10 #df_dice_scores.columns = ['gabor_param', 'fill_param', 'Min_pixels', 'Dice scores']
#
# Cell In [5], line 8, in <lambda>(x)
#       5 # We are going to tune jointly the gabor parameter and the fill parameter on the training set
#       7 hyperparameter_candidates = [[0.76,5],[0.77,5],[0.78,5],[0.79,5],[0.76,10],[0.77,10],[0.78,10],[0.79,10],[0.76,15],[0.77,15],[0.78,15],[0.79,15],[0.76,20],[0.77,20],[0.78,20],[0.79,20] ]
# ----> 8 dice_score_hyperparameters = list(map(lambda x: [x[0],x[1],np.array(list(create_masks(file_dir,image_files_name,mask_files_name,gabor_parameter=x[0],fill_cells=x[1],save_predicted_mask=False).values())).mean() ] , hyperparameter_candidates))
#       9 df_dice_scores=pd.DataFrame(dice_score_hyperparameters)
#      10 #df_dice_scores.columns = ['gabor_param', 'fill_param', 'Min_pixels', 'Dice scores']
#
# Cell In [4], line 58, in create_masks(file_dir, image_files_name, mask_files_name, gabor_parameter, fill_cells, experiment_name, save_predicted_mask, compute_score, ratio_first_thresh, ratio_small_object_thresh, ratio_thresh_big_objects, ratio_canal_diameter)
#      54     true_mask = img_as_ubyte(masks_in_tiff[index_one_image])
#      55     #dice = Dice(average=None,num_classes=2)
#      56     #dice = Dice(average=None)
#      57     #dice = Dice()
# ---> 58     Jac=JaccardIndex(task="binary",average='none',num_classes=2)
#      59     score_sequence = score_sequence + Jac(torch.where(torch.from_numpy(new_image)> 0, 1, 0), torch.where(torch.from_numpy(true_mask)> 0, 1, 0)).numpy()
#      61 if j==0:
#
# NameError: name 'JaccardIndex' is not defined

# %%
file_dir = '/Users/clemence/Documents_Clémence/Analysis/Tracking algorithm/Tracking-seg_Aaron-Gus_CNV/230113-CNV-optimization/training' # change this into your own path
image_files_name = 'Source images'
mask_files_name = 'Masks'

# We are going to tune jointly the gabor parameter and the fill parameter on the training set

hyperparameter_candidates = [[0.78,3],[0.785,3],[0.79,3],[0.78,5],[0.785,5],[0.79,5],[0.78,7],[0.785,7],[0.79,7],[0.78,10],[0.785,10],[0.79,10],[0.78,12],[0.785,12],[0.79,12] ]
dice_score_hyperparameters = list(map(lambda x: [x[0],x[1],np.array(list(create_masks(file_dir,image_files_name,mask_files_name,gabor_parameter=x[0],fill_cells=x[1],save_predicted_mask=False).values())).mean() ] , hyperparameter_candidates))
df_dice_scores=pd.DataFrame(dice_score_hyperparameters)
#df_dice_scores.columns = ['gabor_param', 'fill_param', 'Min_pixels', 'Dice scores']
df_dice_scores.columns = ['gabor_param', 'fill_param', 'Dice scores']
df_dice_scores
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/skimage/util/dtype.py:541: UserWarning: Downcasting uint16 to uint8 without scaling because max value 255 fits in uint8
#   return _convert(image, np.uint8, force_copy)
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_782_t8 segmented (Tiff n°1), gabor param 0.78, fill param 3, score: 0.7618
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_787_t8 segmented (Tiff n°2), gabor param 0.78, fill param 3, score: 0.576
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_793_t8 segmented (Tiff n°3), gabor param 0.78, fill param 3, score: 0.6746
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_065_t1 segmented (Tiff n°4), gabor param 0.78, fill param 3, score: 0.8151
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_066_t24 segmented (Tiff n°5), gabor param 0.78, fill param 3, score: 0.823
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_067_t1 segmented (Tiff n°6), gabor param 0.78, fill param 3, score: 0.8531
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_095_t31 segmented (Tiff n°7), gabor param 0.78, fill param 3, score: 0.822
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_095_t49 segmented (Tiff n°8), gabor param 0.78, fill param 3, score: 0.8476
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_111_t31 segmented (Tiff n°9), gabor param 0.78, fill param 3, score: 0.759
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_111_t49 segmented (Tiff n°10), gabor param 0.78, fill param 3, score: 0.7863
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_137_t31 segmented (Tiff n°11), gabor param 0.78, fill param 3, score: 0.6428
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_137_t49 segmented (Tiff n°12), gabor param 0.78, fill param 3, score: 0.7829
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_156_t31 segmented (Tiff n°13), gabor param 0.78, fill param 3, score: 0.5981
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_156_t49 segmented (Tiff n°14), gabor param 0.78, fill param 3, score: 0.4792
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_205_t1 segmented (Tiff n°15), gabor param 0.78, fill param 3, score: 0.6546
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_205_t25 segmented (Tiff n°16), gabor param 0.78, fill param 3, score: 0.667
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_221_t49 segmented (Tiff n°17), gabor param 0.78, fill param 3, score: 0.6163
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_409_t1 segmented (Tiff n°18), gabor param 0.78, fill param 3, score: 0.8252
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_409_t49 segmented (Tiff n°19), gabor param 0.78, fill param 3, score: 0.7288
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_410_t1 segmented (Tiff n°20), gabor param 0.78, fill param 3, score: 0.7962
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_108_t23 segmented (Tiff n°21), gabor param 0.78, fill param 3, score: 0.8226
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_108_t25 segmented (Tiff n°22), gabor param 0.78, fill param 3, score: 0.813
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0001 segmented (Tiff n°23), gabor param 0.78, fill param 3, score: 0.6864
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0002 segmented (Tiff n°24), gabor param 0.78, fill param 3, score: 0.6818
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0003 segmented (Tiff n°25), gabor param 0.78, fill param 3, score: 0.7224
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0004 segmented (Tiff n°26), gabor param 0.78, fill param 3, score: 0.6745
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0007 segmented (Tiff n°27), gabor param 0.78, fill param 3, score: 0.7384
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0008 segmented (Tiff n°28), gabor param 0.78, fill param 3, score: 0.7517
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0010 segmented (Tiff n°29), gabor param 0.78, fill param 3, score: 0.7009
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0011 segmented (Tiff n°30), gabor param 0.78, fill param 3, score: 0.6946
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0012 segmented (Tiff n°31), gabor param 0.78, fill param 3, score: 0.6881
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0014 segmented (Tiff n°32), gabor param 0.78, fill param 3, score: 0.6888
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0015 segmented (Tiff n°33), gabor param 0.78, fill param 3, score: 0.728
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0016 segmented (Tiff n°34), gabor param 0.78, fill param 3, score: 0.7331
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0018 segmented (Tiff n°35), gabor param 0.78, fill param 3, score: 0.6517
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0020 segmented (Tiff n°36), gabor param 0.78, fill param 3, score: 0.6656
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0021 segmented (Tiff n°37), gabor param 0.78, fill param 3, score: 0.6675
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0022 segmented (Tiff n°38), gabor param 0.78, fill param 3, score: 0.6824
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0023 segmented (Tiff n°39), gabor param 0.78, fill param 3, score: 0.6357
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0024 segmented (Tiff n°40), gabor param 0.78, fill param 3, score: 0.7223
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0025 segmented (Tiff n°41), gabor param 0.78, fill param 3, score: 0.6597
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_118_t1 segmented (Tiff n°42), gabor param 0.78, fill param 3, score: 0.7228
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_118_t25 segmented (Tiff n°43), gabor param 0.78, fill param 3, score: 0.6667
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_125_t13 segmented (Tiff n°44), gabor param 0.78, fill param 3, score: 0.7155
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_125_t25 segmented (Tiff n°45), gabor param 0.78, fill param 3, score: 0.7411
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_128_t1 segmented (Tiff n°46), gabor param 0.78, fill param 3, score: 0.6372
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_128_t25 segmented (Tiff n°47), gabor param 0.78, fill param 3, score: 0.8309
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_434_t49 segmented (Tiff n°48), gabor param 0.78, fill param 3, score: 0.6381
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_435_t49 segmented (Tiff n°49), gabor param 0.78, fill param 3, score: 0.5623
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_440_t49 segmented (Tiff n°50), gabor param 0.78, fill param 3, score: 0.6689
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_441_t49 segmented (Tiff n°51), gabor param 0.78, fill param 3, score: 0.4987
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t1 segmented (Tiff n°52), gabor param 0.78, fill param 3, score: 0.6435
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t25 segmented (Tiff n°53), gabor param 0.78, fill param 3, score: 0.6092
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t49 segmented (Tiff n°54), gabor param 0.78, fill param 3, score: 0.5763
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_487_t25 segmented (Tiff n°55), gabor param 0.78, fill param 3, score: 0.7941
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_487_t49 segmented (Tiff n°56), gabor param 0.78, fill param 3, score: 0.631
# CNV_mutiples,CNV_1: Tiff CNV019_20210904_233_t49 segmented (Tiff n°57), gabor param 0.78, fill param 3, score: 0.7149
# CNV_mutiples,CNV_1: Tiff CNV022_016_t25 segmented (Tiff n°58), gabor param 0.78, fill param 3, score: 0.6074
# CNV_mutiples,CNV_1: Tiff CNV022_077_t25 segmented (Tiff n°59), gabor param 0.78, fill param 3, score: 0.6077
# CNV_mutiples,CNV_1: Tiff CNV022_077_t48 segmented (Tiff n°60), gabor param 0.78, fill param 3, score: 0.5203
# CNV_mutiples,CNV_1: Tiff CNV022_077_t49 segmented (Tiff n°61), gabor param 0.78, fill param 3, score: 0.4986
# CNV_mutiples,CNV_1: Tiff CNV026_117_t41 segmented (Tiff n°62), gabor param 0.78, fill param 3, score: 0.479
# CNV_mutiples,CNV_1: Tiff CNV026_119_t41 segmented (Tiff n°63), gabor param 0.78, fill param 3, score: 0.5048
# CNV_mutiples,CNV_1: Tiff CNV026_128_t41 segmented (Tiff n°64), gabor param 0.78, fill param 3, score: 0.5915
# CNV_mutiples,CNV_1: Tiff CNV026_136_t41 segmented (Tiff n°65), gabor param 0.78, fill param 3, score: 0.7098
# CNV_mutiples,CNV_1: Tiff CNV026_138_t41 segmented (Tiff n°66), gabor param 0.78, fill param 3, score: 0.5281
# CNV_mutiples,CNV_1: Tiff CNV028_40_t41 segmented (Tiff n°67), gabor param 0.78, fill param 3, score: 0.5672
# CNV_mutiples,CNV_1: Tiff CNV028_80_t41 segmented (Tiff n°68), gabor param 0.78, fill param 3, score: 0.6693
# CNV_mutiples,CNV_1: Tiff CNV028_82_t41 segmented (Tiff n°69), gabor param 0.78, fill param 3, score: 0.4103
# CNV_mutiples,CNV_1: Tiff CNV047_20220520_039_t41 segmented (Tiff n°70), gabor param 0.78, fill param 3, score: 0.624
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0001 segmented (Tiff n°71), gabor param 0.78, fill param 3, score: 0.8173
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0003 segmented (Tiff n°72), gabor param 0.78, fill param 3, score: 0.8153
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0004 segmented (Tiff n°73), gabor param 0.78, fill param 3, score: 0.8287
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0007 segmented (Tiff n°74), gabor param 0.78, fill param 3, score: 0.8683
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0008 segmented (Tiff n°75), gabor param 0.78, fill param 3, score: 0.8538
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0009 segmented (Tiff n°76), gabor param 0.78, fill param 3, score: 0.8479
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0010 segmented (Tiff n°77), gabor param 0.78, fill param 3, score: 0.841
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0013 segmented (Tiff n°78), gabor param 0.78, fill param 3, score: 0.8344
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0014 segmented (Tiff n°79), gabor param 0.78, fill param 3, score: 0.8325
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0015 segmented (Tiff n°80), gabor param 0.78, fill param 3, score: 0.873
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0016 segmented (Tiff n°81), gabor param 0.78, fill param 3, score: 0.8053
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0018 segmented (Tiff n°82), gabor param 0.78, fill param 3, score: 0.8198
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0020 segmented (Tiff n°83), gabor param 0.78, fill param 3, score: 0.8067
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0021 segmented (Tiff n°84), gabor param 0.78, fill param 3, score: 0.753
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0022 segmented (Tiff n°85), gabor param 0.78, fill param 3, score: 0.8046
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0023 segmented (Tiff n°86), gabor param 0.78, fill param 3, score: 0.7644
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0025 segmented (Tiff n°87), gabor param 0.78, fill param 3, score: 0.6927
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0026 segmented (Tiff n°88), gabor param 0.78, fill param 3, score: 0.7853
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0028 segmented (Tiff n°89), gabor param 0.78, fill param 3, score: 0.7824
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0029 segmented (Tiff n°90), gabor param 0.78, fill param 3, score: 0.829
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0031 segmented (Tiff n°91), gabor param 0.78, fill param 3, score: 0.7622
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0034 segmented (Tiff n°92), gabor param 0.78, fill param 3, score: 0.7426
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0035 segmented (Tiff n°93), gabor param 0.78, fill param 3, score: 0.8401
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0036 segmented (Tiff n°94), gabor param 0.78, fill param 3, score: 0.7464
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0037 segmented (Tiff n°95), gabor param 0.78, fill param 3, score: 0.7733
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0038 segmented (Tiff n°96), gabor param 0.78, fill param 3, score: 0.7944
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0039 segmented (Tiff n°97), gabor param 0.78, fill param 3, score: 0.8121
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0040 segmented (Tiff n°98), gabor param 0.78, fill param 3, score: 0.7836
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0041 segmented (Tiff n°99), gabor param 0.78, fill param 3, score: 0.7837
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0042 segmented (Tiff n°100), gabor param 0.78, fill param 3, score: 0.7765
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0043 segmented (Tiff n°101), gabor param 0.78, fill param 3, score: 0.7766
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0045 segmented (Tiff n°102), gabor param 0.78, fill param 3, score: 0.7847
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0046 segmented (Tiff n°103), gabor param 0.78, fill param 3, score: 0.7795
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0047 segmented (Tiff n°104), gabor param 0.78, fill param 3, score: 0.7641
# CNV_mutiples,CNV_1: Tiff CNV062_096_t48 segmented (Tiff n°105), gabor param 0.78, fill param 3, score: 0.5428
# CNV_mutiples,CNV_1: Tiff CNV062_119_t48 segmented (Tiff n°106), gabor param 0.78, fill param 3, score: 0.4116
# CNV_mutiples,CNV_1: Tiff CNV062_211_t19 segmented (Tiff n°107), gabor param 0.78, fill param 3, score: 0.7194
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_782_t8 segmented (Tiff n°1), gabor param 0.785, fill param 3, score: 0.7617
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_787_t8 segmented (Tiff n°2), gabor param 0.785, fill param 3, score: 0.5765
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_793_t8 segmented (Tiff n°3), gabor param 0.785, fill param 3, score: 0.6736
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_065_t1 segmented (Tiff n°4), gabor param 0.785, fill param 3, score: 0.8153
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_066_t24 segmented (Tiff n°5), gabor param 0.785, fill param 3, score: 0.823
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_067_t1 segmented (Tiff n°6), gabor param 0.785, fill param 3, score: 0.8534
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_095_t31 segmented (Tiff n°7), gabor param 0.785, fill param 3, score: 0.8223
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_095_t49 segmented (Tiff n°8), gabor param 0.785, fill param 3, score: 0.8471
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_111_t31 segmented (Tiff n°9), gabor param 0.785, fill param 3, score: 0.7564
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_111_t49 segmented (Tiff n°10), gabor param 0.785, fill param 3, score: 0.7856
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_137_t31 segmented (Tiff n°11), gabor param 0.785, fill param 3, score: 0.6435
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_137_t49 segmented (Tiff n°12), gabor param 0.785, fill param 3, score: 0.7798
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_156_t31 segmented (Tiff n°13), gabor param 0.785, fill param 3, score: 0.5981
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_156_t49 segmented (Tiff n°14), gabor param 0.785, fill param 3, score: 0.4783
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_205_t1 segmented (Tiff n°15), gabor param 0.785, fill param 3, score: 0.6548
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_205_t25 segmented (Tiff n°16), gabor param 0.785, fill param 3, score: 0.6678
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_221_t49 segmented (Tiff n°17), gabor param 0.785, fill param 3, score: 0.6173
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_409_t1 segmented (Tiff n°18), gabor param 0.785, fill param 3, score: 0.8249
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_409_t49 segmented (Tiff n°19), gabor param 0.785, fill param 3, score: 0.7288
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_410_t1 segmented (Tiff n°20), gabor param 0.785, fill param 3, score: 0.7967
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_108_t23 segmented (Tiff n°21), gabor param 0.785, fill param 3, score: 0.8226
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_108_t25 segmented (Tiff n°22), gabor param 0.785, fill param 3, score: 0.8084
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0001 segmented (Tiff n°23), gabor param 0.785, fill param 3, score: 0.6876
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0002 segmented (Tiff n°24), gabor param 0.785, fill param 3, score: 0.6825
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0003 segmented (Tiff n°25), gabor param 0.785, fill param 3, score: 0.722
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0004 segmented (Tiff n°26), gabor param 0.785, fill param 3, score: 0.6756
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0007 segmented (Tiff n°27), gabor param 0.785, fill param 3, score: 0.739
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0008 segmented (Tiff n°28), gabor param 0.785, fill param 3, score: 0.7519
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0010 segmented (Tiff n°29), gabor param 0.785, fill param 3, score: 0.7009
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0011 segmented (Tiff n°30), gabor param 0.785, fill param 3, score: 0.6952
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0012 segmented (Tiff n°31), gabor param 0.785, fill param 3, score: 0.6882
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0014 segmented (Tiff n°32), gabor param 0.785, fill param 3, score: 0.6886
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0015 segmented (Tiff n°33), gabor param 0.785, fill param 3, score: 0.7285
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0016 segmented (Tiff n°34), gabor param 0.785, fill param 3, score: 0.7332
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0018 segmented (Tiff n°35), gabor param 0.785, fill param 3, score: 0.6628
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0020 segmented (Tiff n°36), gabor param 0.785, fill param 3, score: 0.6563
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0021 segmented (Tiff n°37), gabor param 0.785, fill param 3, score: 0.6682
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0022 segmented (Tiff n°38), gabor param 0.785, fill param 3, score: 0.6828
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0023 segmented (Tiff n°39), gabor param 0.785, fill param 3, score: 0.636
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0024 segmented (Tiff n°40), gabor param 0.785, fill param 3, score: 0.7225
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0025 segmented (Tiff n°41), gabor param 0.785, fill param 3, score: 0.661
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_118_t1 segmented (Tiff n°42), gabor param 0.785, fill param 3, score: 0.7232
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_118_t25 segmented (Tiff n°43), gabor param 0.785, fill param 3, score: 0.6671
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_125_t13 segmented (Tiff n°44), gabor param 0.785, fill param 3, score: 0.7154
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_125_t25 segmented (Tiff n°45), gabor param 0.785, fill param 3, score: 0.7411
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_128_t1 segmented (Tiff n°46), gabor param 0.785, fill param 3, score: 0.638
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_128_t25 segmented (Tiff n°47), gabor param 0.785, fill param 3, score: 0.8318
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_434_t49 segmented (Tiff n°48), gabor param 0.785, fill param 3, score: 0.6385
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_435_t49 segmented (Tiff n°49), gabor param 0.785, fill param 3, score: 0.5623
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_440_t49 segmented (Tiff n°50), gabor param 0.785, fill param 3, score: 0.6688
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_441_t49 segmented (Tiff n°51), gabor param 0.785, fill param 3, score: 0.4991
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t1 segmented (Tiff n°52), gabor param 0.785, fill param 3, score: 0.6443
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t25 segmented (Tiff n°53), gabor param 0.785, fill param 3, score: 0.6095
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t49 segmented (Tiff n°54), gabor param 0.785, fill param 3, score: 0.5767
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_487_t25 segmented (Tiff n°55), gabor param 0.785, fill param 3, score: 0.7944
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_487_t49 segmented (Tiff n°56), gabor param 0.785, fill param 3, score: 0.6314
# CNV_mutiples,CNV_1: Tiff CNV019_20210904_233_t49 segmented (Tiff n°57), gabor param 0.785, fill param 3, score: 0.7156
# CNV_mutiples,CNV_1: Tiff CNV022_016_t25 segmented (Tiff n°58), gabor param 0.785, fill param 3, score: 0.6073
# CNV_mutiples,CNV_1: Tiff CNV022_077_t25 segmented (Tiff n°59), gabor param 0.785, fill param 3, score: 0.6072
# CNV_mutiples,CNV_1: Tiff CNV022_077_t48 segmented (Tiff n°60), gabor param 0.785, fill param 3, score: 0.5202
# CNV_mutiples,CNV_1: Tiff CNV022_077_t49 segmented (Tiff n°61), gabor param 0.785, fill param 3, score: 0.4984
# CNV_mutiples,CNV_1: Tiff CNV026_117_t41 segmented (Tiff n°62), gabor param 0.785, fill param 3, score: 0.4791
# CNV_mutiples,CNV_1: Tiff CNV026_119_t41 segmented (Tiff n°63), gabor param 0.785, fill param 3, score: 0.5048
# CNV_mutiples,CNV_1: Tiff CNV026_128_t41 segmented (Tiff n°64), gabor param 0.785, fill param 3, score: 0.5881
# CNV_mutiples,CNV_1: Tiff CNV026_136_t41 segmented (Tiff n°65), gabor param 0.785, fill param 3, score: 0.7499
# CNV_mutiples,CNV_1: Tiff CNV026_138_t41 segmented (Tiff n°66), gabor param 0.785, fill param 3, score: 0.5298
# CNV_mutiples,CNV_1: Tiff CNV028_40_t41 segmented (Tiff n°67), gabor param 0.785, fill param 3, score: 0.5686
# CNV_mutiples,CNV_1: Tiff CNV028_80_t41 segmented (Tiff n°68), gabor param 0.785, fill param 3, score: 0.67
# CNV_mutiples,CNV_1: Tiff CNV028_82_t41 segmented (Tiff n°69), gabor param 0.785, fill param 3, score: 0.4081
# CNV_mutiples,CNV_1: Tiff CNV047_20220520_039_t41 segmented (Tiff n°70), gabor param 0.785, fill param 3, score: 0.6242
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0001 segmented (Tiff n°71), gabor param 0.785, fill param 3, score: 0.8176
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0003 segmented (Tiff n°72), gabor param 0.785, fill param 3, score: 0.8182
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0004 segmented (Tiff n°73), gabor param 0.785, fill param 3, score: 0.8252
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0007 segmented (Tiff n°74), gabor param 0.785, fill param 3, score: 0.8684
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0008 segmented (Tiff n°75), gabor param 0.785, fill param 3, score: 0.8537
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0009 segmented (Tiff n°76), gabor param 0.785, fill param 3, score: 0.849
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0010 segmented (Tiff n°77), gabor param 0.785, fill param 3, score: 0.8411
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0013 segmented (Tiff n°78), gabor param 0.785, fill param 3, score: 0.8342
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0014 segmented (Tiff n°79), gabor param 0.785, fill param 3, score: 0.8325
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0015 segmented (Tiff n°80), gabor param 0.785, fill param 3, score: 0.8732
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0016 segmented (Tiff n°81), gabor param 0.785, fill param 3, score: 0.8054
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0018 segmented (Tiff n°82), gabor param 0.785, fill param 3, score: 0.82
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0020 segmented (Tiff n°83), gabor param 0.785, fill param 3, score: 0.8068
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0021 segmented (Tiff n°84), gabor param 0.785, fill param 3, score: 0.7529
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0022 segmented (Tiff n°85), gabor param 0.785, fill param 3, score: 0.8084
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0023 segmented (Tiff n°86), gabor param 0.785, fill param 3, score: 0.7669
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0025 segmented (Tiff n°87), gabor param 0.785, fill param 3, score: 0.6926
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0026 segmented (Tiff n°88), gabor param 0.785, fill param 3, score: 0.7854
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0028 segmented (Tiff n°89), gabor param 0.785, fill param 3, score: 0.7806
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0029 segmented (Tiff n°90), gabor param 0.785, fill param 3, score: 0.8307
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0031 segmented (Tiff n°91), gabor param 0.785, fill param 3, score: 0.7622
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0034 segmented (Tiff n°92), gabor param 0.785, fill param 3, score: 0.7429
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0035 segmented (Tiff n°93), gabor param 0.785, fill param 3, score: 0.8395
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0036 segmented (Tiff n°94), gabor param 0.785, fill param 3, score: 0.7469
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0037 segmented (Tiff n°95), gabor param 0.785, fill param 3, score: 0.774
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0038 segmented (Tiff n°96), gabor param 0.785, fill param 3, score: 0.7949
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0039 segmented (Tiff n°97), gabor param 0.785, fill param 3, score: 0.8126
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0040 segmented (Tiff n°98), gabor param 0.785, fill param 3, score: 0.7839
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0041 segmented (Tiff n°99), gabor param 0.785, fill param 3, score: 0.7843
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0042 segmented (Tiff n°100), gabor param 0.785, fill param 3, score: 0.7767
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0043 segmented (Tiff n°101), gabor param 0.785, fill param 3, score: 0.7771
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0045 segmented (Tiff n°102), gabor param 0.785, fill param 3, score: 0.7834
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0046 segmented (Tiff n°103), gabor param 0.785, fill param 3, score: 0.7794
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0047 segmented (Tiff n°104), gabor param 0.785, fill param 3, score: 0.7653
# CNV_mutiples,CNV_1: Tiff CNV062_096_t48 segmented (Tiff n°105), gabor param 0.785, fill param 3, score: 0.5402
# CNV_mutiples,CNV_1: Tiff CNV062_119_t48 segmented (Tiff n°106), gabor param 0.785, fill param 3, score: 0.4123
# CNV_mutiples,CNV_1: Tiff CNV062_211_t19 segmented (Tiff n°107), gabor param 0.785, fill param 3, score: 0.7192
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_782_t8 segmented (Tiff n°1), gabor param 0.79, fill param 3, score: 0.7622
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_787_t8 segmented (Tiff n°2), gabor param 0.79, fill param 3, score: 0.5756
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_793_t8 segmented (Tiff n°3), gabor param 0.79, fill param 3, score: 0.6741
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_065_t1 segmented (Tiff n°4), gabor param 0.79, fill param 3, score: 0.8156
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_066_t24 segmented (Tiff n°5), gabor param 0.79, fill param 3, score: 0.8224
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_067_t1 segmented (Tiff n°6), gabor param 0.79, fill param 3, score: 0.8539
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_095_t31 segmented (Tiff n°7), gabor param 0.79, fill param 3, score: 0.8227
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_095_t49 segmented (Tiff n°8), gabor param 0.79, fill param 3, score: 0.8467
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_111_t31 segmented (Tiff n°9), gabor param 0.79, fill param 3, score: 0.7553
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_111_t49 segmented (Tiff n°10), gabor param 0.79, fill param 3, score: 0.7832
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_137_t31 segmented (Tiff n°11), gabor param 0.79, fill param 3, score: 0.6436
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_137_t49 segmented (Tiff n°12), gabor param 0.79, fill param 3, score: 0.7789
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_156_t31 segmented (Tiff n°13), gabor param 0.79, fill param 3, score: 0.5973
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_156_t49 segmented (Tiff n°14), gabor param 0.79, fill param 3, score: 0.4742
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_205_t1 segmented (Tiff n°15), gabor param 0.79, fill param 3, score: 0.655
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_205_t25 segmented (Tiff n°16), gabor param 0.79, fill param 3, score: 0.6706
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_221_t49 segmented (Tiff n°17), gabor param 0.79, fill param 3, score: 0.619
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_409_t1 segmented (Tiff n°18), gabor param 0.79, fill param 3, score: 0.8239
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_409_t49 segmented (Tiff n°19), gabor param 0.79, fill param 3, score: 0.7287
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_410_t1 segmented (Tiff n°20), gabor param 0.79, fill param 3, score: 0.7973
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_108_t23 segmented (Tiff n°21), gabor param 0.79, fill param 3, score: 0.823
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_108_t25 segmented (Tiff n°22), gabor param 0.79, fill param 3, score: 0.8052
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0001 segmented (Tiff n°23), gabor param 0.79, fill param 3, score: 0.6871
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0002 segmented (Tiff n°24), gabor param 0.79, fill param 3, score: 0.6831
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0003 segmented (Tiff n°25), gabor param 0.79, fill param 3, score: 0.723
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0004 segmented (Tiff n°26), gabor param 0.79, fill param 3, score: 0.6758
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0007 segmented (Tiff n°27), gabor param 0.79, fill param 3, score: 0.7395
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0008 segmented (Tiff n°28), gabor param 0.79, fill param 3, score: 0.7498
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0010 segmented (Tiff n°29), gabor param 0.79, fill param 3, score: 0.7017
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0011 segmented (Tiff n°30), gabor param 0.79, fill param 3, score: 0.6962
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0012 segmented (Tiff n°31), gabor param 0.79, fill param 3, score: 0.6814
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0014 segmented (Tiff n°32), gabor param 0.79, fill param 3, score: 0.6889
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0015 segmented (Tiff n°33), gabor param 0.79, fill param 3, score: 0.7281
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0016 segmented (Tiff n°34), gabor param 0.79, fill param 3, score: 0.7335
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0018 segmented (Tiff n°35), gabor param 0.79, fill param 3, score: 0.6615
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0020 segmented (Tiff n°36), gabor param 0.79, fill param 3, score: 0.6564
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0021 segmented (Tiff n°37), gabor param 0.79, fill param 3, score: 0.6509
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0022 segmented (Tiff n°38), gabor param 0.79, fill param 3, score: 0.6775
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0023 segmented (Tiff n°39), gabor param 0.79, fill param 3, score: 0.6325
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0024 segmented (Tiff n°40), gabor param 0.79, fill param 3, score: 0.7182
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0025 segmented (Tiff n°41), gabor param 0.79, fill param 3, score: 0.6605
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_118_t1 segmented (Tiff n°42), gabor param 0.79, fill param 3, score: 0.7241
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_118_t25 segmented (Tiff n°43), gabor param 0.79, fill param 3, score: 0.6681
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_125_t13 segmented (Tiff n°44), gabor param 0.79, fill param 3, score: 0.7149
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_125_t25 segmented (Tiff n°45), gabor param 0.79, fill param 3, score: 0.7406
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_128_t1 segmented (Tiff n°46), gabor param 0.79, fill param 3, score: 0.6385
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_128_t25 segmented (Tiff n°47), gabor param 0.79, fill param 3, score: 0.8317
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_434_t49 segmented (Tiff n°48), gabor param 0.79, fill param 3, score: 0.6389
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_435_t49 segmented (Tiff n°49), gabor param 0.79, fill param 3, score: 0.5645
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_440_t49 segmented (Tiff n°50), gabor param 0.79, fill param 3, score: 0.6701
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_441_t49 segmented (Tiff n°51), gabor param 0.79, fill param 3, score: 0.4993
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t1 segmented (Tiff n°52), gabor param 0.79, fill param 3, score: 0.6446
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t25 segmented (Tiff n°53), gabor param 0.79, fill param 3, score: 0.6095
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t49 segmented (Tiff n°54), gabor param 0.79, fill param 3, score: 0.5357
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_487_t25 segmented (Tiff n°55), gabor param 0.79, fill param 3, score: 0.7951
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_487_t49 segmented (Tiff n°56), gabor param 0.79, fill param 3, score: 0.6332
# CNV_mutiples,CNV_1: Tiff CNV019_20210904_233_t49 segmented (Tiff n°57), gabor param 0.79, fill param 3, score: 0.7168
# CNV_mutiples,CNV_1: Tiff CNV022_016_t25 segmented (Tiff n°58), gabor param 0.79, fill param 3, score: 0.6066
# CNV_mutiples,CNV_1: Tiff CNV022_077_t25 segmented (Tiff n°59), gabor param 0.79, fill param 3, score: 0.6073
# CNV_mutiples,CNV_1: Tiff CNV022_077_t48 segmented (Tiff n°60), gabor param 0.79, fill param 3, score: 0.5202
# CNV_mutiples,CNV_1: Tiff CNV022_077_t49 segmented (Tiff n°61), gabor param 0.79, fill param 3, score: 0.486
# CNV_mutiples,CNV_1: Tiff CNV026_117_t41 segmented (Tiff n°62), gabor param 0.79, fill param 3, score: 0.4794
# CNV_mutiples,CNV_1: Tiff CNV026_119_t41 segmented (Tiff n°63), gabor param 0.79, fill param 3, score: 0.5017
# CNV_mutiples,CNV_1: Tiff CNV026_128_t41 segmented (Tiff n°64), gabor param 0.79, fill param 3, score: 0.5883
# CNV_mutiples,CNV_1: Tiff CNV026_136_t41 segmented (Tiff n°65), gabor param 0.79, fill param 3, score: 0.7506
# CNV_mutiples,CNV_1: Tiff CNV026_138_t41 segmented (Tiff n°66), gabor param 0.79, fill param 3, score: 0.5333
# CNV_mutiples,CNV_1: Tiff CNV028_40_t41 segmented (Tiff n°67), gabor param 0.79, fill param 3, score: 0.57
# CNV_mutiples,CNV_1: Tiff CNV028_80_t41 segmented (Tiff n°68), gabor param 0.79, fill param 3, score: 0.6704
# CNV_mutiples,CNV_1: Tiff CNV028_82_t41 segmented (Tiff n°69), gabor param 0.79, fill param 3, score: 0.404
# CNV_mutiples,CNV_1: Tiff CNV047_20220520_039_t41 segmented (Tiff n°70), gabor param 0.79, fill param 3, score: 0.6235
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0001 segmented (Tiff n°71), gabor param 0.79, fill param 3, score: 0.8191
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0003 segmented (Tiff n°72), gabor param 0.79, fill param 3, score: 0.8205
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0004 segmented (Tiff n°73), gabor param 0.79, fill param 3, score: 0.8243
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0007 segmented (Tiff n°74), gabor param 0.79, fill param 3, score: 0.8696
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0008 segmented (Tiff n°75), gabor param 0.79, fill param 3, score: 0.8538
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0009 segmented (Tiff n°76), gabor param 0.79, fill param 3, score: 0.8518
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0010 segmented (Tiff n°77), gabor param 0.79, fill param 3, score: 0.8425
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0013 segmented (Tiff n°78), gabor param 0.79, fill param 3, score: 0.834
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0014 segmented (Tiff n°79), gabor param 0.79, fill param 3, score: 0.8322
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0015 segmented (Tiff n°80), gabor param 0.79, fill param 3, score: 0.8732
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0016 segmented (Tiff n°81), gabor param 0.79, fill param 3, score: 0.8057
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0018 segmented (Tiff n°82), gabor param 0.79, fill param 3, score: 0.8215
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0020 segmented (Tiff n°83), gabor param 0.79, fill param 3, score: 0.8073
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0021 segmented (Tiff n°84), gabor param 0.79, fill param 3, score: 0.7514
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0022 segmented (Tiff n°85), gabor param 0.79, fill param 3, score: 0.8088
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0023 segmented (Tiff n°86), gabor param 0.79, fill param 3, score: 0.7676
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0025 segmented (Tiff n°87), gabor param 0.79, fill param 3, score: 0.6735
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0026 segmented (Tiff n°88), gabor param 0.79, fill param 3, score: 0.7845
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0028 segmented (Tiff n°89), gabor param 0.79, fill param 3, score: 0.7817
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0029 segmented (Tiff n°90), gabor param 0.79, fill param 3, score: 0.8309
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0031 segmented (Tiff n°91), gabor param 0.79, fill param 3, score: 0.7621
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0034 segmented (Tiff n°92), gabor param 0.79, fill param 3, score: 0.7448
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0035 segmented (Tiff n°93), gabor param 0.79, fill param 3, score: 0.8397
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0036 segmented (Tiff n°94), gabor param 0.79, fill param 3, score: 0.747
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0037 segmented (Tiff n°95), gabor param 0.79, fill param 3, score: 0.7743
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0038 segmented (Tiff n°96), gabor param 0.79, fill param 3, score: 0.7953
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0039 segmented (Tiff n°97), gabor param 0.79, fill param 3, score: 0.8126
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0040 segmented (Tiff n°98), gabor param 0.79, fill param 3, score: 0.7868
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0041 segmented (Tiff n°99), gabor param 0.79, fill param 3, score: 0.7868
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0042 segmented (Tiff n°100), gabor param 0.79, fill param 3, score: 0.7797
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0043 segmented (Tiff n°101), gabor param 0.79, fill param 3, score: 0.7792
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0045 segmented (Tiff n°102), gabor param 0.79, fill param 3, score: 0.7834
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0046 segmented (Tiff n°103), gabor param 0.79, fill param 3, score: 0.7792
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0047 segmented (Tiff n°104), gabor param 0.79, fill param 3, score: 0.7644
# CNV_mutiples,CNV_1: Tiff CNV062_096_t48 segmented (Tiff n°105), gabor param 0.79, fill param 3, score: 0.537
# CNV_mutiples,CNV_1: Tiff CNV062_119_t48 segmented (Tiff n°106), gabor param 0.79, fill param 3, score: 0.4125
# CNV_mutiples,CNV_1: Tiff CNV062_211_t19 segmented (Tiff n°107), gabor param 0.79, fill param 3, score: 0.7191
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_782_t8 segmented (Tiff n°1), gabor param 0.78, fill param 5, score: 0.7435
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_787_t8 segmented (Tiff n°2), gabor param 0.78, fill param 5, score: 0.5849
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_793_t8 segmented (Tiff n°3), gabor param 0.78, fill param 5, score: 0.6742
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_065_t1 segmented (Tiff n°4), gabor param 0.78, fill param 5, score: 0.8108
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_066_t24 segmented (Tiff n°5), gabor param 0.78, fill param 5, score: 0.8226
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_067_t1 segmented (Tiff n°6), gabor param 0.78, fill param 5, score: 0.8524
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_095_t31 segmented (Tiff n°7), gabor param 0.78, fill param 5, score: 0.8134
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_095_t49 segmented (Tiff n°8), gabor param 0.78, fill param 5, score: 0.8416
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_111_t31 segmented (Tiff n°9), gabor param 0.78, fill param 5, score: 0.7441
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_111_t49 segmented (Tiff n°10), gabor param 0.78, fill param 5, score: 0.7889
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_137_t31 segmented (Tiff n°11), gabor param 0.78, fill param 5, score: 0.6419
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_137_t49 segmented (Tiff n°12), gabor param 0.78, fill param 5, score: 0.7847
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_156_t31 segmented (Tiff n°13), gabor param 0.78, fill param 5, score: 0.6128
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_156_t49 segmented (Tiff n°14), gabor param 0.78, fill param 5, score: 0.4883
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_205_t1 segmented (Tiff n°15), gabor param 0.78, fill param 5, score: 0.654
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_205_t25 segmented (Tiff n°16), gabor param 0.78, fill param 5, score: 0.6667
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_221_t49 segmented (Tiff n°17), gabor param 0.78, fill param 5, score: 0.6122
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_409_t1 segmented (Tiff n°18), gabor param 0.78, fill param 5, score: 0.8207
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_409_t49 segmented (Tiff n°19), gabor param 0.78, fill param 5, score: 0.7285
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_410_t1 segmented (Tiff n°20), gabor param 0.78, fill param 5, score: 0.7929
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_108_t23 segmented (Tiff n°21), gabor param 0.78, fill param 5, score: 0.8226
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_108_t25 segmented (Tiff n°22), gabor param 0.78, fill param 5, score: 0.8167
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0001 segmented (Tiff n°23), gabor param 0.78, fill param 5, score: 0.6832
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0002 segmented (Tiff n°24), gabor param 0.78, fill param 5, score: 0.6798
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0003 segmented (Tiff n°25), gabor param 0.78, fill param 5, score: 0.7195
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0004 segmented (Tiff n°26), gabor param 0.78, fill param 5, score: 0.6718
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0007 segmented (Tiff n°27), gabor param 0.78, fill param 5, score: 0.7384
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0008 segmented (Tiff n°28), gabor param 0.78, fill param 5, score: 0.75
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0010 segmented (Tiff n°29), gabor param 0.78, fill param 5, score: 0.7042
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0011 segmented (Tiff n°30), gabor param 0.78, fill param 5, score: 0.6926
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0012 segmented (Tiff n°31), gabor param 0.78, fill param 5, score: 0.6856
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0014 segmented (Tiff n°32), gabor param 0.78, fill param 5, score: 0.6894
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0015 segmented (Tiff n°33), gabor param 0.78, fill param 5, score: 0.6902
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0016 segmented (Tiff n°34), gabor param 0.78, fill param 5, score: 0.7321
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0018 segmented (Tiff n°35), gabor param 0.78, fill param 5, score: 0.7047
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0020 segmented (Tiff n°36), gabor param 0.78, fill param 5, score: 0.6805
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0021 segmented (Tiff n°37), gabor param 0.78, fill param 5, score: 0.706
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0022 segmented (Tiff n°38), gabor param 0.78, fill param 5, score: 0.6873
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0023 segmented (Tiff n°39), gabor param 0.78, fill param 5, score: 0.6578
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0024 segmented (Tiff n°40), gabor param 0.78, fill param 5, score: 0.7215
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0025 segmented (Tiff n°41), gabor param 0.78, fill param 5, score: 0.6627
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_118_t1 segmented (Tiff n°42), gabor param 0.78, fill param 5, score: 0.7183
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_118_t25 segmented (Tiff n°43), gabor param 0.78, fill param 5, score: 0.6719
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_125_t13 segmented (Tiff n°44), gabor param 0.78, fill param 5, score: 0.7122
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_125_t25 segmented (Tiff n°45), gabor param 0.78, fill param 5, score: 0.7379
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_128_t1 segmented (Tiff n°46), gabor param 0.78, fill param 5, score: 0.6346
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_128_t25 segmented (Tiff n°47), gabor param 0.78, fill param 5, score: 0.8278
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_434_t49 segmented (Tiff n°48), gabor param 0.78, fill param 5, score: 0.6332
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_435_t49 segmented (Tiff n°49), gabor param 0.78, fill param 5, score: 0.5571
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_440_t49 segmented (Tiff n°50), gabor param 0.78, fill param 5, score: 0.6595
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_441_t49 segmented (Tiff n°51), gabor param 0.78, fill param 5, score: 0.4956
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t1 segmented (Tiff n°52), gabor param 0.78, fill param 5, score: 0.6432
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t25 segmented (Tiff n°53), gabor param 0.78, fill param 5, score: 0.6057
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t49 segmented (Tiff n°54), gabor param 0.78, fill param 5, score: 0.5733
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_487_t25 segmented (Tiff n°55), gabor param 0.78, fill param 5, score: 0.7916
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_487_t49 segmented (Tiff n°56), gabor param 0.78, fill param 5, score: 0.6221
# CNV_mutiples,CNV_1: Tiff CNV019_20210904_233_t49 segmented (Tiff n°57), gabor param 0.78, fill param 5, score: 0.7102
# CNV_mutiples,CNV_1: Tiff CNV022_016_t25 segmented (Tiff n°58), gabor param 0.78, fill param 5, score: 0.6208
# CNV_mutiples,CNV_1: Tiff CNV022_077_t25 segmented (Tiff n°59), gabor param 0.78, fill param 5, score: 0.6089
# CNV_mutiples,CNV_1: Tiff CNV022_077_t48 segmented (Tiff n°60), gabor param 0.78, fill param 5, score: 0.5234
# CNV_mutiples,CNV_1: Tiff CNV022_077_t49 segmented (Tiff n°61), gabor param 0.78, fill param 5, score: 0.5056
# CNV_mutiples,CNV_1: Tiff CNV026_117_t41 segmented (Tiff n°62), gabor param 0.78, fill param 5, score: 0.4777
# CNV_mutiples,CNV_1: Tiff CNV026_119_t41 segmented (Tiff n°63), gabor param 0.78, fill param 5, score: 0.511
# CNV_mutiples,CNV_1: Tiff CNV026_128_t41 segmented (Tiff n°64), gabor param 0.78, fill param 5, score: 0.5642
# CNV_mutiples,CNV_1: Tiff CNV026_136_t41 segmented (Tiff n°65), gabor param 0.78, fill param 5, score: 0.7046
# CNV_mutiples,CNV_1: Tiff CNV026_138_t41 segmented (Tiff n°66), gabor param 0.78, fill param 5, score: 0.5257
# CNV_mutiples,CNV_1: Tiff CNV028_40_t41 segmented (Tiff n°67), gabor param 0.78, fill param 5, score: 0.5684
# CNV_mutiples,CNV_1: Tiff CNV028_80_t41 segmented (Tiff n°68), gabor param 0.78, fill param 5, score: 0.6709
# CNV_mutiples,CNV_1: Tiff CNV028_82_t41 segmented (Tiff n°69), gabor param 0.78, fill param 5, score: 0.4702
# CNV_mutiples,CNV_1: Tiff CNV047_20220520_039_t41 segmented (Tiff n°70), gabor param 0.78, fill param 5, score: 0.6245
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0001 segmented (Tiff n°71), gabor param 0.78, fill param 5, score: 0.8167
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0003 segmented (Tiff n°72), gabor param 0.78, fill param 5, score: 0.8165
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0004 segmented (Tiff n°73), gabor param 0.78, fill param 5, score: 0.8258
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0007 segmented (Tiff n°74), gabor param 0.78, fill param 5, score: 0.8658
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0008 segmented (Tiff n°75), gabor param 0.78, fill param 5, score: 0.8532
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0009 segmented (Tiff n°76), gabor param 0.78, fill param 5, score: 0.8489
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0010 segmented (Tiff n°77), gabor param 0.78, fill param 5, score: 0.8401
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0013 segmented (Tiff n°78), gabor param 0.78, fill param 5, score: 0.833
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0014 segmented (Tiff n°79), gabor param 0.78, fill param 5, score: 0.8374
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0015 segmented (Tiff n°80), gabor param 0.78, fill param 5, score: 0.8678
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0016 segmented (Tiff n°81), gabor param 0.78, fill param 5, score: 0.8072
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0018 segmented (Tiff n°82), gabor param 0.78, fill param 5, score: 0.8263
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0020 segmented (Tiff n°83), gabor param 0.78, fill param 5, score: 0.8058
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0021 segmented (Tiff n°84), gabor param 0.78, fill param 5, score: 0.759
# ...
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0023 segmented (Tiff n°86), gabor param 0.785, fill param 12, score: 0.7593
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0025 segmented (Tiff n°87), gabor param 0.785, fill param 12, score: 0.7031
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0026 segmented (Tiff n°88), gabor param 0.785, fill param 12, score: 0.7761
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0028 segmented (Tiff n°89), gabor param 0.785, fill param 12, score: 0.7977
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0029 segmented (Tiff n°90), gabor param 0.785, fill param 12, score: 0.8314
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0031 segmented (Tiff n°91), gabor param 0.785, fill param 12, score: 0.7436
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0034 segmented (Tiff n°92), gabor param 0.785, fill param 12, score: 0.7389
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0035 segmented (Tiff n°93), gabor param 0.785, fill param 12, score: 0.8284
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0036 segmented (Tiff n°94), gabor param 0.785, fill param 12, score: 0.7344
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0037 segmented (Tiff n°95), gabor param 0.785, fill param 12, score: 0.757
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0038 segmented (Tiff n°96), gabor param 0.785, fill param 12, score: 0.7774
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0039 segmented (Tiff n°97), gabor param 0.785, fill param 12, score: 0.806
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0040 segmented (Tiff n°98), gabor param 0.785, fill param 12, score: 0.7626
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0041 segmented (Tiff n°99), gabor param 0.785, fill param 12, score: 0.7712
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0042 segmented (Tiff n°100), gabor param 0.785, fill param 12, score: 0.7493
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0043 segmented (Tiff n°101), gabor param 0.785, fill param 12, score: 0.7517
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0045 segmented (Tiff n°102), gabor param 0.785, fill param 12, score: 0.7856
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0046 segmented (Tiff n°103), gabor param 0.785, fill param 12, score: 0.7722
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0047 segmented (Tiff n°104), gabor param 0.785, fill param 12, score: 0.7494
# CNV_mutiples,CNV_1: Tiff CNV062_096_t48 segmented (Tiff n°105), gabor param 0.785, fill param 12, score: 0.5376
# CNV_mutiples,CNV_1: Tiff CNV062_119_t48 segmented (Tiff n°106), gabor param 0.785, fill param 12, score: 0.4289
# CNV_mutiples,CNV_1: Tiff CNV062_211_t19 segmented (Tiff n°107), gabor param 0.785, fill param 12, score: 0.7372
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_782_t8 segmented (Tiff n°1), gabor param 0.79, fill param 12, score: 0.7332
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_787_t8 segmented (Tiff n°2), gabor param 0.79, fill param 12, score: 0.6411
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_793_t8 segmented (Tiff n°3), gabor param 0.79, fill param 12, score: 0.5502
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_065_t1 segmented (Tiff n°4), gabor param 0.79, fill param 12, score: 0.8005
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_066_t24 segmented (Tiff n°5), gabor param 0.79, fill param 12, score: 0.8176
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_067_t1 segmented (Tiff n°6), gabor param 0.79, fill param 12, score: 0.843
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_095_t31 segmented (Tiff n°7), gabor param 0.79, fill param 12, score: 0.7977
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_095_t49 segmented (Tiff n°8), gabor param 0.79, fill param 12, score: 0.8292
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_111_t31 segmented (Tiff n°9), gabor param 0.79, fill param 12, score: 0.7414
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_111_t49 segmented (Tiff n°10), gabor param 0.79, fill param 12, score: 0.7585
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_137_t31 segmented (Tiff n°11), gabor param 0.79, fill param 12, score: 0.656
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_137_t49 segmented (Tiff n°12), gabor param 0.79, fill param 12, score: 0.7812
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_156_t31 segmented (Tiff n°13), gabor param 0.79, fill param 12, score: 0.6397
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_156_t49 segmented (Tiff n°14), gabor param 0.79, fill param 12, score: 0.5131
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_205_t1 segmented (Tiff n°15), gabor param 0.79, fill param 12, score: 0.6411
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_205_t25 segmented (Tiff n°16), gabor param 0.79, fill param 12, score: 0.6637
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_221_t49 segmented (Tiff n°17), gabor param 0.79, fill param 12, score: 0.5959
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_409_t1 segmented (Tiff n°18), gabor param 0.79, fill param 12, score: 0.7782
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_409_t49 segmented (Tiff n°19), gabor param 0.79, fill param 12, score: 0.7139
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_410_t1 segmented (Tiff n°20), gabor param 0.79, fill param 12, score: 0.7759
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_108_t23 segmented (Tiff n°21), gabor param 0.79, fill param 12, score: 0.8185
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_108_t25 segmented (Tiff n°22), gabor param 0.79, fill param 12, score: 0.7675
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0001 segmented (Tiff n°23), gabor param 0.79, fill param 12, score: 0.6671
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0002 segmented (Tiff n°24), gabor param 0.79, fill param 12, score: 0.6724
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0003 segmented (Tiff n°25), gabor param 0.79, fill param 12, score: 0.7092
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0004 segmented (Tiff n°26), gabor param 0.79, fill param 12, score: 0.671
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0007 segmented (Tiff n°27), gabor param 0.79, fill param 12, score: 0.7305
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0008 segmented (Tiff n°28), gabor param 0.79, fill param 12, score: 0.7415
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0010 segmented (Tiff n°29), gabor param 0.79, fill param 12, score: 0.7017
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0011 segmented (Tiff n°30), gabor param 0.79, fill param 12, score: 0.6853
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0012 segmented (Tiff n°31), gabor param 0.79, fill param 12, score: 0.6791
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0014 segmented (Tiff n°32), gabor param 0.79, fill param 12, score: 0.6861
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0015 segmented (Tiff n°33), gabor param 0.79, fill param 12, score: 0.6879
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0016 segmented (Tiff n°34), gabor param 0.79, fill param 12, score: 0.7276
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0018 segmented (Tiff n°35), gabor param 0.79, fill param 12, score: 0.7205
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0020 segmented (Tiff n°36), gabor param 0.79, fill param 12, score: 0.7198
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0021 segmented (Tiff n°37), gabor param 0.79, fill param 12, score: 0.7252
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0022 segmented (Tiff n°38), gabor param 0.79, fill param 12, score: 0.7073
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0023 segmented (Tiff n°39), gabor param 0.79, fill param 12, score: 0.6562
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0024 segmented (Tiff n°40), gabor param 0.79, fill param 12, score: 0.7175
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0025 segmented (Tiff n°41), gabor param 0.79, fill param 12, score: 0.6997
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_118_t1 segmented (Tiff n°42), gabor param 0.79, fill param 12, score: 0.6696
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_118_t25 segmented (Tiff n°43), gabor param 0.79, fill param 12, score: 0.6577
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_125_t13 segmented (Tiff n°44), gabor param 0.79, fill param 12, score: 0.7091
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_125_t25 segmented (Tiff n°45), gabor param 0.79, fill param 12, score: 0.7343
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_128_t1 segmented (Tiff n°46), gabor param 0.79, fill param 12, score: 0.6271
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_128_t25 segmented (Tiff n°47), gabor param 0.79, fill param 12, score: 0.8157
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_434_t49 segmented (Tiff n°48), gabor param 0.79, fill param 12, score: 0.6212
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_435_t49 segmented (Tiff n°49), gabor param 0.79, fill param 12, score: 0.5518
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_440_t49 segmented (Tiff n°50), gabor param 0.79, fill param 12, score: 0.596
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_441_t49 segmented (Tiff n°51), gabor param 0.79, fill param 12, score: 0.4758
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t1 segmented (Tiff n°52), gabor param 0.79, fill param 12, score: 0.6395
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t25 segmented (Tiff n°53), gabor param 0.79, fill param 12, score: 0.5885
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t49 segmented (Tiff n°54), gabor param 0.79, fill param 12, score: 0.5645
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_487_t25 segmented (Tiff n°55), gabor param 0.79, fill param 12, score: 0.7814
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_487_t49 segmented (Tiff n°56), gabor param 0.79, fill param 12, score: 0.6091
# CNV_mutiples,CNV_1: Tiff CNV019_20210904_233_t49 segmented (Tiff n°57), gabor param 0.79, fill param 12, score: 0.7028
# CNV_mutiples,CNV_1: Tiff CNV022_016_t25 segmented (Tiff n°58), gabor param 0.79, fill param 12, score: 0.6289
# CNV_mutiples,CNV_1: Tiff CNV022_077_t25 segmented (Tiff n°59), gabor param 0.79, fill param 12, score: 0.6064
# CNV_mutiples,CNV_1: Tiff CNV022_077_t48 segmented (Tiff n°60), gabor param 0.79, fill param 12, score: 0.5448
# CNV_mutiples,CNV_1: Tiff CNV022_077_t49 segmented (Tiff n°61), gabor param 0.79, fill param 12, score: 0.5092
# CNV_mutiples,CNV_1: Tiff CNV026_117_t41 segmented (Tiff n°62), gabor param 0.79, fill param 12, score: 0.4851
# CNV_mutiples,CNV_1: Tiff CNV026_119_t41 segmented (Tiff n°63), gabor param 0.79, fill param 12, score: 0.5056
# CNV_mutiples,CNV_1: Tiff CNV026_128_t41 segmented (Tiff n°64), gabor param 0.79, fill param 12, score: 0.5488
# CNV_mutiples,CNV_1: Tiff CNV026_136_t41 segmented (Tiff n°65), gabor param 0.79, fill param 12, score: 0.6857
# CNV_mutiples,CNV_1: Tiff CNV026_138_t41 segmented (Tiff n°66), gabor param 0.79, fill param 12, score: 0.5205
# CNV_mutiples,CNV_1: Tiff CNV028_40_t41 segmented (Tiff n°67), gabor param 0.79, fill param 12, score: 0.5768
# CNV_mutiples,CNV_1: Tiff CNV028_80_t41 segmented (Tiff n°68), gabor param 0.79, fill param 12, score: 0.7307
# CNV_mutiples,CNV_1: Tiff CNV028_82_t41 segmented (Tiff n°69), gabor param 0.79, fill param 12, score: 0.4678
# CNV_mutiples,CNV_1: Tiff CNV047_20220520_039_t41 segmented (Tiff n°70), gabor param 0.79, fill param 12, score: 0.6188
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0001 segmented (Tiff n°71), gabor param 0.79, fill param 12, score: 0.8116
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0003 segmented (Tiff n°72), gabor param 0.79, fill param 12, score: 0.8203
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0004 segmented (Tiff n°73), gabor param 0.79, fill param 12, score: 0.8196
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0007 segmented (Tiff n°74), gabor param 0.79, fill param 12, score: 0.8651
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0008 segmented (Tiff n°75), gabor param 0.79, fill param 12, score: 0.8346
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0009 segmented (Tiff n°76), gabor param 0.79, fill param 12, score: 0.8524
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0010 segmented (Tiff n°77), gabor param 0.79, fill param 12, score: 0.8401
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0013 segmented (Tiff n°78), gabor param 0.79, fill param 12, score: 0.8448
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0014 segmented (Tiff n°79), gabor param 0.79, fill param 12, score: 0.8498
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0015 segmented (Tiff n°80), gabor param 0.79, fill param 12, score: 0.6801
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0016 segmented (Tiff n°81), gabor param 0.79, fill param 12, score: 0.8205
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0018 segmented (Tiff n°82), gabor param 0.79, fill param 12, score: 0.8162
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0020 segmented (Tiff n°83), gabor param 0.79, fill param 12, score: 0.7915
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0021 segmented (Tiff n°84), gabor param 0.79, fill param 12, score: 0.7549
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0022 segmented (Tiff n°85), gabor param 0.79, fill param 12, score: 0.8023
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0023 segmented (Tiff n°86), gabor param 0.79, fill param 12, score: 0.7596
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0025 segmented (Tiff n°87), gabor param 0.79, fill param 12, score: 0.6856
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0026 segmented (Tiff n°88), gabor param 0.79, fill param 12, score: 0.7761
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0028 segmented (Tiff n°89), gabor param 0.79, fill param 12, score: 0.7985
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0029 segmented (Tiff n°90), gabor param 0.79, fill param 12, score: 0.8318
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0031 segmented (Tiff n°91), gabor param 0.79, fill param 12, score: 0.7442
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0034 segmented (Tiff n°92), gabor param 0.79, fill param 12, score: 0.7412
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0035 segmented (Tiff n°93), gabor param 0.79, fill param 12, score: 0.8285
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0036 segmented (Tiff n°94), gabor param 0.79, fill param 12, score: 0.7345
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0037 segmented (Tiff n°95), gabor param 0.79, fill param 12, score: 0.7566
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0038 segmented (Tiff n°96), gabor param 0.79, fill param 12, score: 0.7776
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0039 segmented (Tiff n°97), gabor param 0.79, fill param 12, score: 0.8069
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0040 segmented (Tiff n°98), gabor param 0.79, fill param 12, score: 0.7673
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0041 segmented (Tiff n°99), gabor param 0.79, fill param 12, score: 0.7761
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0042 segmented (Tiff n°100), gabor param 0.79, fill param 12, score: 0.7526
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0043 segmented (Tiff n°101), gabor param 0.79, fill param 12, score: 0.7523
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0045 segmented (Tiff n°102), gabor param 0.79, fill param 12, score: 0.786
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0046 segmented (Tiff n°103), gabor param 0.79, fill param 12, score: 0.7729
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0047 segmented (Tiff n°104), gabor param 0.79, fill param 12, score: 0.7499
# CNV_mutiples,CNV_1: Tiff CNV062_096_t48 segmented (Tiff n°105), gabor param 0.79, fill param 12, score: 0.5363
# CNV_mutiples,CNV_1: Tiff CNV062_119_t48 segmented (Tiff n°106), gabor param 0.79, fill param 12, score: 0.4299
# CNV_mutiples,CNV_1: Tiff CNV062_211_t19 segmented (Tiff n°107), gabor param 0.79, fill param 12, score: 0.7314
#     gabor_param  fill_param  Dice scores
# 0         0.780           3     0.711559
# 1         0.785           3     0.712050
# 2         0.790           3     0.711206
# 3         0.780           5     0.711850
# 4         0.785           5     0.711992
# 5         0.790           5     0.711666
# 6         0.780           7     0.709555
# 7         0.785           7     0.709594
# 8         0.790           7     0.709627
# 9         0.780          10     0.706074
# 10        0.785          10     0.706359
# 11        0.790          10     0.706616
# 12        0.780          12     0.704692
# 13        0.785          12     0.704737
# 14        0.790          12     0.705005

# %%
# after having tuned the gabor and fill parameter, we are going to tune the number of pixels threshold (every mask below that number of pixels is removed) 

hyperparameter_candidates = [3600,3650,3700,3750,3800]
#dice_score_pixels_nb = list(map(lambda x: [0.785,5,x,np.array(list(create_masks(file_dir,image_files_name,mask_files_name,gabor_parameter=0.785,fill_cells=5, thresh_small_objects = x ,save_predicted_mask=False).values())).mean() ] , hyperparameter_candidates))
dice_score_pixels_nb = list(map(lambda x: [0.785,5,x,np.array(list(create_masks(file_dir,image_files_name,mask_files_name,gabor_parameter=0.785,fill_cells=5, save_predicted_mask=False).values())).mean() ] , hyperparameter_candidates))
dice_score_pixels_nb=pd.DataFrame(dice_score_pixels_nb)
dice_score_pixels_nb.columns = ['gabor_param', 'fill_param', 'Min_pixels', 'Dice scores']
dice_score_pixels_nb
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/skimage/util/dtype.py:541: UserWarning: Downcasting uint16 to uint8 without scaling because max value 255 fits in uint8
#   return _convert(image, np.uint8, force_copy)
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_782_t8 segmented (Tiff n°1), gabor param 0.785, fill param 5, score: 0.744
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_787_t8 segmented (Tiff n°2), gabor param 0.785, fill param 5, score: 0.5856
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_793_t8 segmented (Tiff n°3), gabor param 0.785, fill param 5, score: 0.6736
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_065_t1 segmented (Tiff n°4), gabor param 0.785, fill param 5, score: 0.8112
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_066_t24 segmented (Tiff n°5), gabor param 0.785, fill param 5, score: 0.8228
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_067_t1 segmented (Tiff n°6), gabor param 0.785, fill param 5, score: 0.8528
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_095_t31 segmented (Tiff n°7), gabor param 0.785, fill param 5, score: 0.8137
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_095_t49 segmented (Tiff n°8), gabor param 0.785, fill param 5, score: 0.8426
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_111_t31 segmented (Tiff n°9), gabor param 0.785, fill param 5, score: 0.7422
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_111_t49 segmented (Tiff n°10), gabor param 0.785, fill param 5, score: 0.7884
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_137_t31 segmented (Tiff n°11), gabor param 0.785, fill param 5, score: 0.6428
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_137_t49 segmented (Tiff n°12), gabor param 0.785, fill param 5, score: 0.7823
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_156_t31 segmented (Tiff n°13), gabor param 0.785, fill param 5, score: 0.6128
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_156_t49 segmented (Tiff n°14), gabor param 0.785, fill param 5, score: 0.4874
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_205_t1 segmented (Tiff n°15), gabor param 0.785, fill param 5, score: 0.6544
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_205_t25 segmented (Tiff n°16), gabor param 0.785, fill param 5, score: 0.6677
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_221_t49 segmented (Tiff n°17), gabor param 0.785, fill param 5, score: 0.6131
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_409_t1 segmented (Tiff n°18), gabor param 0.785, fill param 5, score: 0.8206
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_409_t49 segmented (Tiff n°19), gabor param 0.785, fill param 5, score: 0.7288
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_410_t1 segmented (Tiff n°20), gabor param 0.785, fill param 5, score: 0.7933
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_108_t23 segmented (Tiff n°21), gabor param 0.785, fill param 5, score: 0.8226
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_108_t25 segmented (Tiff n°22), gabor param 0.785, fill param 5, score: 0.8118
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0001 segmented (Tiff n°23), gabor param 0.785, fill param 5, score: 0.6847
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0002 segmented (Tiff n°24), gabor param 0.785, fill param 5, score: 0.6805
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0003 segmented (Tiff n°25), gabor param 0.785, fill param 5, score: 0.719
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0004 segmented (Tiff n°26), gabor param 0.785, fill param 5, score: 0.6733
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0007 segmented (Tiff n°27), gabor param 0.785, fill param 5, score: 0.7387
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0008 segmented (Tiff n°28), gabor param 0.785, fill param 5, score: 0.7502
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0010 segmented (Tiff n°29), gabor param 0.785, fill param 5, score: 0.7042
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0011 segmented (Tiff n°30), gabor param 0.785, fill param 5, score: 0.6931
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0012 segmented (Tiff n°31), gabor param 0.785, fill param 5, score: 0.6859
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0014 segmented (Tiff n°32), gabor param 0.785, fill param 5, score: 0.6887
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0015 segmented (Tiff n°33), gabor param 0.785, fill param 5, score: 0.6903
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0016 segmented (Tiff n°34), gabor param 0.785, fill param 5, score: 0.7322
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0018 segmented (Tiff n°35), gabor param 0.785, fill param 5, score: 0.7145
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0020 segmented (Tiff n°36), gabor param 0.785, fill param 5, score: 0.672
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0021 segmented (Tiff n°37), gabor param 0.785, fill param 5, score: 0.7064
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0022 segmented (Tiff n°38), gabor param 0.785, fill param 5, score: 0.688
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0023 segmented (Tiff n°39), gabor param 0.785, fill param 5, score: 0.6582
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0024 segmented (Tiff n°40), gabor param 0.785, fill param 5, score: 0.7217
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0025 segmented (Tiff n°41), gabor param 0.785, fill param 5, score: 0.664
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_118_t1 segmented (Tiff n°42), gabor param 0.785, fill param 5, score: 0.7188
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_118_t25 segmented (Tiff n°43), gabor param 0.785, fill param 5, score: 0.6722
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_125_t13 segmented (Tiff n°44), gabor param 0.785, fill param 5, score: 0.7121
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_125_t25 segmented (Tiff n°45), gabor param 0.785, fill param 5, score: 0.7379
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_128_t1 segmented (Tiff n°46), gabor param 0.785, fill param 5, score: 0.6355
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_128_t25 segmented (Tiff n°47), gabor param 0.785, fill param 5, score: 0.829
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_434_t49 segmented (Tiff n°48), gabor param 0.785, fill param 5, score: 0.6335
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_435_t49 segmented (Tiff n°49), gabor param 0.785, fill param 5, score: 0.5572
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_440_t49 segmented (Tiff n°50), gabor param 0.785, fill param 5, score: 0.66
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_441_t49 segmented (Tiff n°51), gabor param 0.785, fill param 5, score: 0.4961
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t1 segmented (Tiff n°52), gabor param 0.785, fill param 5, score: 0.6432
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t25 segmented (Tiff n°53), gabor param 0.785, fill param 5, score: 0.606
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t49 segmented (Tiff n°54), gabor param 0.785, fill param 5, score: 0.5736
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_487_t25 segmented (Tiff n°55), gabor param 0.785, fill param 5, score: 0.7918
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_487_t49 segmented (Tiff n°56), gabor param 0.785, fill param 5, score: 0.6225
# CNV_mutiples,CNV_1: Tiff CNV019_20210904_233_t49 segmented (Tiff n°57), gabor param 0.785, fill param 5, score: 0.711
# CNV_mutiples,CNV_1: Tiff CNV022_016_t25 segmented (Tiff n°58), gabor param 0.785, fill param 5, score: 0.6212
# CNV_mutiples,CNV_1: Tiff CNV022_077_t25 segmented (Tiff n°59), gabor param 0.785, fill param 5, score: 0.6092
# CNV_mutiples,CNV_1: Tiff CNV022_077_t48 segmented (Tiff n°60), gabor param 0.785, fill param 5, score: 0.5235
# CNV_mutiples,CNV_1: Tiff CNV022_077_t49 segmented (Tiff n°61), gabor param 0.785, fill param 5, score: 0.506
# CNV_mutiples,CNV_1: Tiff CNV026_117_t41 segmented (Tiff n°62), gabor param 0.785, fill param 5, score: 0.4779
# CNV_mutiples,CNV_1: Tiff CNV026_119_t41 segmented (Tiff n°63), gabor param 0.785, fill param 5, score: 0.5111
# CNV_mutiples,CNV_1: Tiff CNV026_128_t41 segmented (Tiff n°64), gabor param 0.785, fill param 5, score: 0.5605
# CNV_mutiples,CNV_1: Tiff CNV026_136_t41 segmented (Tiff n°65), gabor param 0.785, fill param 5, score: 0.7064
# CNV_mutiples,CNV_1: Tiff CNV026_138_t41 segmented (Tiff n°66), gabor param 0.785, fill param 5, score: 0.5274
# CNV_mutiples,CNV_1: Tiff CNV028_40_t41 segmented (Tiff n°67), gabor param 0.785, fill param 5, score: 0.5698
# CNV_mutiples,CNV_1: Tiff CNV028_80_t41 segmented (Tiff n°68), gabor param 0.785, fill param 5, score: 0.6716
# CNV_mutiples,CNV_1: Tiff CNV028_82_t41 segmented (Tiff n°69), gabor param 0.785, fill param 5, score: 0.459
# CNV_mutiples,CNV_1: Tiff CNV047_20220520_039_t41 segmented (Tiff n°70), gabor param 0.785, fill param 5, score: 0.6249
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0001 segmented (Tiff n°71), gabor param 0.785, fill param 5, score: 0.8169
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0003 segmented (Tiff n°72), gabor param 0.785, fill param 5, score: 0.8199
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0004 segmented (Tiff n°73), gabor param 0.785, fill param 5, score: 0.8233
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0007 segmented (Tiff n°74), gabor param 0.785, fill param 5, score: 0.8659
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0008 segmented (Tiff n°75), gabor param 0.785, fill param 5, score: 0.8533
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0009 segmented (Tiff n°76), gabor param 0.785, fill param 5, score: 0.8504
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0010 segmented (Tiff n°77), gabor param 0.785, fill param 5, score: 0.8405
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0013 segmented (Tiff n°78), gabor param 0.785, fill param 5, score: 0.833
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0014 segmented (Tiff n°79), gabor param 0.785, fill param 5, score: 0.8373
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0015 segmented (Tiff n°80), gabor param 0.785, fill param 5, score: 0.8681
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0016 segmented (Tiff n°81), gabor param 0.785, fill param 5, score: 0.8072
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0018 segmented (Tiff n°82), gabor param 0.785, fill param 5, score: 0.8264
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0020 segmented (Tiff n°83), gabor param 0.785, fill param 5, score: 0.806
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0021 segmented (Tiff n°84), gabor param 0.785, fill param 5, score: 0.7591
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0022 segmented (Tiff n°85), gabor param 0.785, fill param 5, score: 0.8093
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0023 segmented (Tiff n°86), gabor param 0.785, fill param 5, score: 0.7639
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0025 segmented (Tiff n°87), gabor param 0.785, fill param 5, score: 0.697
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0026 segmented (Tiff n°88), gabor param 0.785, fill param 5, score: 0.7822
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0028 segmented (Tiff n°89), gabor param 0.785, fill param 5, score: 0.7815
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0029 segmented (Tiff n°90), gabor param 0.785, fill param 5, score: 0.8333
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0031 segmented (Tiff n°91), gabor param 0.785, fill param 5, score: 0.7609
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0034 segmented (Tiff n°92), gabor param 0.785, fill param 5, score: 0.7396
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0035 segmented (Tiff n°93), gabor param 0.785, fill param 5, score: 0.8408
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0036 segmented (Tiff n°94), gabor param 0.785, fill param 5, score: 0.7455
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0037 segmented (Tiff n°95), gabor param 0.785, fill param 5, score: 0.7696
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0038 segmented (Tiff n°96), gabor param 0.785, fill param 5, score: 0.789
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0039 segmented (Tiff n°97), gabor param 0.785, fill param 5, score: 0.8129
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0040 segmented (Tiff n°98), gabor param 0.785, fill param 5, score: 0.7768
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0041 segmented (Tiff n°99), gabor param 0.785, fill param 5, score: 0.7828
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0042 segmented (Tiff n°100), gabor param 0.785, fill param 5, score: 0.7645
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0043 segmented (Tiff n°101), gabor param 0.785, fill param 5, score: 0.7737
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0045 segmented (Tiff n°102), gabor param 0.785, fill param 5, score: 0.7787
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0046 segmented (Tiff n°103), gabor param 0.785, fill param 5, score: 0.7817
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0047 segmented (Tiff n°104), gabor param 0.785, fill param 5, score: 0.7635
# CNV_mutiples,CNV_1: Tiff CNV062_096_t48 segmented (Tiff n°105), gabor param 0.785, fill param 5, score: 0.5369
# CNV_mutiples,CNV_1: Tiff CNV062_119_t48 segmented (Tiff n°106), gabor param 0.785, fill param 5, score: 0.4134
# CNV_mutiples,CNV_1: Tiff CNV062_211_t19 segmented (Tiff n°107), gabor param 0.785, fill param 5, score: 0.7292
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_782_t8 segmented (Tiff n°1), gabor param 0.785, fill param 5, score: 0.744
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_787_t8 segmented (Tiff n°2), gabor param 0.785, fill param 5, score: 0.5856
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_793_t8 segmented (Tiff n°3), gabor param 0.785, fill param 5, score: 0.6736
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_065_t1 segmented (Tiff n°4), gabor param 0.785, fill param 5, score: 0.8112
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_066_t24 segmented (Tiff n°5), gabor param 0.785, fill param 5, score: 0.8228
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_067_t1 segmented (Tiff n°6), gabor param 0.785, fill param 5, score: 0.8528
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_095_t31 segmented (Tiff n°7), gabor param 0.785, fill param 5, score: 0.8137
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_095_t49 segmented (Tiff n°8), gabor param 0.785, fill param 5, score: 0.8426
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_111_t31 segmented (Tiff n°9), gabor param 0.785, fill param 5, score: 0.7422
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_111_t49 segmented (Tiff n°10), gabor param 0.785, fill param 5, score: 0.7884
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_137_t31 segmented (Tiff n°11), gabor param 0.785, fill param 5, score: 0.6428
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_137_t49 segmented (Tiff n°12), gabor param 0.785, fill param 5, score: 0.7823
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_156_t31 segmented (Tiff n°13), gabor param 0.785, fill param 5, score: 0.6128
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_156_t49 segmented (Tiff n°14), gabor param 0.785, fill param 5, score: 0.4874
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_205_t1 segmented (Tiff n°15), gabor param 0.785, fill param 5, score: 0.6544
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_205_t25 segmented (Tiff n°16), gabor param 0.785, fill param 5, score: 0.6677
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_221_t49 segmented (Tiff n°17), gabor param 0.785, fill param 5, score: 0.6131
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_409_t1 segmented (Tiff n°18), gabor param 0.785, fill param 5, score: 0.8206
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_409_t49 segmented (Tiff n°19), gabor param 0.785, fill param 5, score: 0.7288
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_410_t1 segmented (Tiff n°20), gabor param 0.785, fill param 5, score: 0.7933
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_108_t23 segmented (Tiff n°21), gabor param 0.785, fill param 5, score: 0.8226
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_108_t25 segmented (Tiff n°22), gabor param 0.785, fill param 5, score: 0.8118
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0001 segmented (Tiff n°23), gabor param 0.785, fill param 5, score: 0.6847
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0002 segmented (Tiff n°24), gabor param 0.785, fill param 5, score: 0.6805
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0003 segmented (Tiff n°25), gabor param 0.785, fill param 5, score: 0.719
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0004 segmented (Tiff n°26), gabor param 0.785, fill param 5, score: 0.6733
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0007 segmented (Tiff n°27), gabor param 0.785, fill param 5, score: 0.7387
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0008 segmented (Tiff n°28), gabor param 0.785, fill param 5, score: 0.7502
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0010 segmented (Tiff n°29), gabor param 0.785, fill param 5, score: 0.7042
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0011 segmented (Tiff n°30), gabor param 0.785, fill param 5, score: 0.6931
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0012 segmented (Tiff n°31), gabor param 0.785, fill param 5, score: 0.6859
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0014 segmented (Tiff n°32), gabor param 0.785, fill param 5, score: 0.6887
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0015 segmented (Tiff n°33), gabor param 0.785, fill param 5, score: 0.6903
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0016 segmented (Tiff n°34), gabor param 0.785, fill param 5, score: 0.7322
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0018 segmented (Tiff n°35), gabor param 0.785, fill param 5, score: 0.7145
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0020 segmented (Tiff n°36), gabor param 0.785, fill param 5, score: 0.672
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0021 segmented (Tiff n°37), gabor param 0.785, fill param 5, score: 0.7064
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0022 segmented (Tiff n°38), gabor param 0.785, fill param 5, score: 0.688
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0023 segmented (Tiff n°39), gabor param 0.785, fill param 5, score: 0.6582
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0024 segmented (Tiff n°40), gabor param 0.785, fill param 5, score: 0.7217
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0025 segmented (Tiff n°41), gabor param 0.785, fill param 5, score: 0.664
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_118_t1 segmented (Tiff n°42), gabor param 0.785, fill param 5, score: 0.7188
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_118_t25 segmented (Tiff n°43), gabor param 0.785, fill param 5, score: 0.6722
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_125_t13 segmented (Tiff n°44), gabor param 0.785, fill param 5, score: 0.7121
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_125_t25 segmented (Tiff n°45), gabor param 0.785, fill param 5, score: 0.7379
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_128_t1 segmented (Tiff n°46), gabor param 0.785, fill param 5, score: 0.6355
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_128_t25 segmented (Tiff n°47), gabor param 0.785, fill param 5, score: 0.829
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_434_t49 segmented (Tiff n°48), gabor param 0.785, fill param 5, score: 0.6335
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_435_t49 segmented (Tiff n°49), gabor param 0.785, fill param 5, score: 0.5572
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_440_t49 segmented (Tiff n°50), gabor param 0.785, fill param 5, score: 0.66
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_441_t49 segmented (Tiff n°51), gabor param 0.785, fill param 5, score: 0.4961
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t1 segmented (Tiff n°52), gabor param 0.785, fill param 5, score: 0.6432
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t25 segmented (Tiff n°53), gabor param 0.785, fill param 5, score: 0.606
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t49 segmented (Tiff n°54), gabor param 0.785, fill param 5, score: 0.5736
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_487_t25 segmented (Tiff n°55), gabor param 0.785, fill param 5, score: 0.7918
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_487_t49 segmented (Tiff n°56), gabor param 0.785, fill param 5, score: 0.6225
# CNV_mutiples,CNV_1: Tiff CNV019_20210904_233_t49 segmented (Tiff n°57), gabor param 0.785, fill param 5, score: 0.711
# CNV_mutiples,CNV_1: Tiff CNV022_016_t25 segmented (Tiff n°58), gabor param 0.785, fill param 5, score: 0.6212
# CNV_mutiples,CNV_1: Tiff CNV022_077_t25 segmented (Tiff n°59), gabor param 0.785, fill param 5, score: 0.6092
# CNV_mutiples,CNV_1: Tiff CNV022_077_t48 segmented (Tiff n°60), gabor param 0.785, fill param 5, score: 0.5235
# CNV_mutiples,CNV_1: Tiff CNV022_077_t49 segmented (Tiff n°61), gabor param 0.785, fill param 5, score: 0.506
# CNV_mutiples,CNV_1: Tiff CNV026_117_t41 segmented (Tiff n°62), gabor param 0.785, fill param 5, score: 0.4779
# CNV_mutiples,CNV_1: Tiff CNV026_119_t41 segmented (Tiff n°63), gabor param 0.785, fill param 5, score: 0.5111
# CNV_mutiples,CNV_1: Tiff CNV026_128_t41 segmented (Tiff n°64), gabor param 0.785, fill param 5, score: 0.5605
# CNV_mutiples,CNV_1: Tiff CNV026_136_t41 segmented (Tiff n°65), gabor param 0.785, fill param 5, score: 0.7064
# CNV_mutiples,CNV_1: Tiff CNV026_138_t41 segmented (Tiff n°66), gabor param 0.785, fill param 5, score: 0.5274
# CNV_mutiples,CNV_1: Tiff CNV028_40_t41 segmented (Tiff n°67), gabor param 0.785, fill param 5, score: 0.5698
# CNV_mutiples,CNV_1: Tiff CNV028_80_t41 segmented (Tiff n°68), gabor param 0.785, fill param 5, score: 0.6716
# CNV_mutiples,CNV_1: Tiff CNV028_82_t41 segmented (Tiff n°69), gabor param 0.785, fill param 5, score: 0.459
# CNV_mutiples,CNV_1: Tiff CNV047_20220520_039_t41 segmented (Tiff n°70), gabor param 0.785, fill param 5, score: 0.6249
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0001 segmented (Tiff n°71), gabor param 0.785, fill param 5, score: 0.8169
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0003 segmented (Tiff n°72), gabor param 0.785, fill param 5, score: 0.8199
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0004 segmented (Tiff n°73), gabor param 0.785, fill param 5, score: 0.8233
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0007 segmented (Tiff n°74), gabor param 0.785, fill param 5, score: 0.8659
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0008 segmented (Tiff n°75), gabor param 0.785, fill param 5, score: 0.8533
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0009 segmented (Tiff n°76), gabor param 0.785, fill param 5, score: 0.8504
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0010 segmented (Tiff n°77), gabor param 0.785, fill param 5, score: 0.8405
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0013 segmented (Tiff n°78), gabor param 0.785, fill param 5, score: 0.833
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0014 segmented (Tiff n°79), gabor param 0.785, fill param 5, score: 0.8373
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0015 segmented (Tiff n°80), gabor param 0.785, fill param 5, score: 0.8681
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0016 segmented (Tiff n°81), gabor param 0.785, fill param 5, score: 0.8072
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0018 segmented (Tiff n°82), gabor param 0.785, fill param 5, score: 0.8264
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0020 segmented (Tiff n°83), gabor param 0.785, fill param 5, score: 0.806
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0021 segmented (Tiff n°84), gabor param 0.785, fill param 5, score: 0.7591
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0022 segmented (Tiff n°85), gabor param 0.785, fill param 5, score: 0.8093
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0023 segmented (Tiff n°86), gabor param 0.785, fill param 5, score: 0.7639
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0025 segmented (Tiff n°87), gabor param 0.785, fill param 5, score: 0.697
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0026 segmented (Tiff n°88), gabor param 0.785, fill param 5, score: 0.7822
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0028 segmented (Tiff n°89), gabor param 0.785, fill param 5, score: 0.7815
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0029 segmented (Tiff n°90), gabor param 0.785, fill param 5, score: 0.8333
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0031 segmented (Tiff n°91), gabor param 0.785, fill param 5, score: 0.7609
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0034 segmented (Tiff n°92), gabor param 0.785, fill param 5, score: 0.7396
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0035 segmented (Tiff n°93), gabor param 0.785, fill param 5, score: 0.8408
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0036 segmented (Tiff n°94), gabor param 0.785, fill param 5, score: 0.7455
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0037 segmented (Tiff n°95), gabor param 0.785, fill param 5, score: 0.7696
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0038 segmented (Tiff n°96), gabor param 0.785, fill param 5, score: 0.789
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0039 segmented (Tiff n°97), gabor param 0.785, fill param 5, score: 0.8129
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0040 segmented (Tiff n°98), gabor param 0.785, fill param 5, score: 0.7768
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0041 segmented (Tiff n°99), gabor param 0.785, fill param 5, score: 0.7828
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0042 segmented (Tiff n°100), gabor param 0.785, fill param 5, score: 0.7645
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0043 segmented (Tiff n°101), gabor param 0.785, fill param 5, score: 0.7737
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0045 segmented (Tiff n°102), gabor param 0.785, fill param 5, score: 0.7787
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0046 segmented (Tiff n°103), gabor param 0.785, fill param 5, score: 0.7817
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0047 segmented (Tiff n°104), gabor param 0.785, fill param 5, score: 0.7635
# CNV_mutiples,CNV_1: Tiff CNV062_096_t48 segmented (Tiff n°105), gabor param 0.785, fill param 5, score: 0.5369
# CNV_mutiples,CNV_1: Tiff CNV062_119_t48 segmented (Tiff n°106), gabor param 0.785, fill param 5, score: 0.4134
# CNV_mutiples,CNV_1: Tiff CNV062_211_t19 segmented (Tiff n°107), gabor param 0.785, fill param 5, score: 0.7292
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_782_t8 segmented (Tiff n°1), gabor param 0.785, fill param 5, score: 0.744
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_787_t8 segmented (Tiff n°2), gabor param 0.785, fill param 5, score: 0.5856
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_793_t8 segmented (Tiff n°3), gabor param 0.785, fill param 5, score: 0.6736
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_065_t1 segmented (Tiff n°4), gabor param 0.785, fill param 5, score: 0.8112
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_066_t24 segmented (Tiff n°5), gabor param 0.785, fill param 5, score: 0.8228
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_067_t1 segmented (Tiff n°6), gabor param 0.785, fill param 5, score: 0.8528
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_095_t31 segmented (Tiff n°7), gabor param 0.785, fill param 5, score: 0.8137
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_095_t49 segmented (Tiff n°8), gabor param 0.785, fill param 5, score: 0.8426
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_111_t31 segmented (Tiff n°9), gabor param 0.785, fill param 5, score: 0.7422
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_111_t49 segmented (Tiff n°10), gabor param 0.785, fill param 5, score: 0.7884
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_137_t31 segmented (Tiff n°11), gabor param 0.785, fill param 5, score: 0.6428
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_137_t49 segmented (Tiff n°12), gabor param 0.785, fill param 5, score: 0.7823
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_156_t31 segmented (Tiff n°13), gabor param 0.785, fill param 5, score: 0.6128
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_156_t49 segmented (Tiff n°14), gabor param 0.785, fill param 5, score: 0.4874
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_205_t1 segmented (Tiff n°15), gabor param 0.785, fill param 5, score: 0.6544
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_205_t25 segmented (Tiff n°16), gabor param 0.785, fill param 5, score: 0.6677
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_221_t49 segmented (Tiff n°17), gabor param 0.785, fill param 5, score: 0.6131
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_409_t1 segmented (Tiff n°18), gabor param 0.785, fill param 5, score: 0.8206
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_409_t49 segmented (Tiff n°19), gabor param 0.785, fill param 5, score: 0.7288
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_410_t1 segmented (Tiff n°20), gabor param 0.785, fill param 5, score: 0.7933
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_108_t23 segmented (Tiff n°21), gabor param 0.785, fill param 5, score: 0.8226
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_108_t25 segmented (Tiff n°22), gabor param 0.785, fill param 5, score: 0.8118
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0001 segmented (Tiff n°23), gabor param 0.785, fill param 5, score: 0.6847
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0002 segmented (Tiff n°24), gabor param 0.785, fill param 5, score: 0.6805
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0003 segmented (Tiff n°25), gabor param 0.785, fill param 5, score: 0.719
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0004 segmented (Tiff n°26), gabor param 0.785, fill param 5, score: 0.6733
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0007 segmented (Tiff n°27), gabor param 0.785, fill param 5, score: 0.7387
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0008 segmented (Tiff n°28), gabor param 0.785, fill param 5, score: 0.7502
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0010 segmented (Tiff n°29), gabor param 0.785, fill param 5, score: 0.7042
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0011 segmented (Tiff n°30), gabor param 0.785, fill param 5, score: 0.6931
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0012 segmented (Tiff n°31), gabor param 0.785, fill param 5, score: 0.6859
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0014 segmented (Tiff n°32), gabor param 0.785, fill param 5, score: 0.6887
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0015 segmented (Tiff n°33), gabor param 0.785, fill param 5, score: 0.6903
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0016 segmented (Tiff n°34), gabor param 0.785, fill param 5, score: 0.7322
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0018 segmented (Tiff n°35), gabor param 0.785, fill param 5, score: 0.7145
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0020 segmented (Tiff n°36), gabor param 0.785, fill param 5, score: 0.672
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0021 segmented (Tiff n°37), gabor param 0.785, fill param 5, score: 0.7064
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0022 segmented (Tiff n°38), gabor param 0.785, fill param 5, score: 0.688
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0023 segmented (Tiff n°39), gabor param 0.785, fill param 5, score: 0.6582
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0024 segmented (Tiff n°40), gabor param 0.785, fill param 5, score: 0.7217
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0025 segmented (Tiff n°41), gabor param 0.785, fill param 5, score: 0.664
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_118_t1 segmented (Tiff n°42), gabor param 0.785, fill param 5, score: 0.7188
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_118_t25 segmented (Tiff n°43), gabor param 0.785, fill param 5, score: 0.6722
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_125_t13 segmented (Tiff n°44), gabor param 0.785, fill param 5, score: 0.7121
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_125_t25 segmented (Tiff n°45), gabor param 0.785, fill param 5, score: 0.7379
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_128_t1 segmented (Tiff n°46), gabor param 0.785, fill param 5, score: 0.6355
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_128_t25 segmented (Tiff n°47), gabor param 0.785, fill param 5, score: 0.829
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_434_t49 segmented (Tiff n°48), gabor param 0.785, fill param 5, score: 0.6335
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_435_t49 segmented (Tiff n°49), gabor param 0.785, fill param 5, score: 0.5572
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_440_t49 segmented (Tiff n°50), gabor param 0.785, fill param 5, score: 0.66
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_441_t49 segmented (Tiff n°51), gabor param 0.785, fill param 5, score: 0.4961
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t1 segmented (Tiff n°52), gabor param 0.785, fill param 5, score: 0.6432
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t25 segmented (Tiff n°53), gabor param 0.785, fill param 5, score: 0.606
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t49 segmented (Tiff n°54), gabor param 0.785, fill param 5, score: 0.5736
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_487_t25 segmented (Tiff n°55), gabor param 0.785, fill param 5, score: 0.7918
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_487_t49 segmented (Tiff n°56), gabor param 0.785, fill param 5, score: 0.6225
# CNV_mutiples,CNV_1: Tiff CNV019_20210904_233_t49 segmented (Tiff n°57), gabor param 0.785, fill param 5, score: 0.711
# CNV_mutiples,CNV_1: Tiff CNV022_016_t25 segmented (Tiff n°58), gabor param 0.785, fill param 5, score: 0.6212
# CNV_mutiples,CNV_1: Tiff CNV022_077_t25 segmented (Tiff n°59), gabor param 0.785, fill param 5, score: 0.6092
# CNV_mutiples,CNV_1: Tiff CNV022_077_t48 segmented (Tiff n°60), gabor param 0.785, fill param 5, score: 0.5235
# CNV_mutiples,CNV_1: Tiff CNV022_077_t49 segmented (Tiff n°61), gabor param 0.785, fill param 5, score: 0.506
# CNV_mutiples,CNV_1: Tiff CNV026_117_t41 segmented (Tiff n°62), gabor param 0.785, fill param 5, score: 0.4779
# CNV_mutiples,CNV_1: Tiff CNV026_119_t41 segmented (Tiff n°63), gabor param 0.785, fill param 5, score: 0.5111
# CNV_mutiples,CNV_1: Tiff CNV026_128_t41 segmented (Tiff n°64), gabor param 0.785, fill param 5, score: 0.5605
# CNV_mutiples,CNV_1: Tiff CNV026_136_t41 segmented (Tiff n°65), gabor param 0.785, fill param 5, score: 0.7064
# CNV_mutiples,CNV_1: Tiff CNV026_138_t41 segmented (Tiff n°66), gabor param 0.785, fill param 5, score: 0.5274
# CNV_mutiples,CNV_1: Tiff CNV028_40_t41 segmented (Tiff n°67), gabor param 0.785, fill param 5, score: 0.5698
# CNV_mutiples,CNV_1: Tiff CNV028_80_t41 segmented (Tiff n°68), gabor param 0.785, fill param 5, score: 0.6716
# CNV_mutiples,CNV_1: Tiff CNV028_82_t41 segmented (Tiff n°69), gabor param 0.785, fill param 5, score: 0.459
# CNV_mutiples,CNV_1: Tiff CNV047_20220520_039_t41 segmented (Tiff n°70), gabor param 0.785, fill param 5, score: 0.6249
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0001 segmented (Tiff n°71), gabor param 0.785, fill param 5, score: 0.8169
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0003 segmented (Tiff n°72), gabor param 0.785, fill param 5, score: 0.8199
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0004 segmented (Tiff n°73), gabor param 0.785, fill param 5, score: 0.8233
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0007 segmented (Tiff n°74), gabor param 0.785, fill param 5, score: 0.8659
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0008 segmented (Tiff n°75), gabor param 0.785, fill param 5, score: 0.8533
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0009 segmented (Tiff n°76), gabor param 0.785, fill param 5, score: 0.8504
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0010 segmented (Tiff n°77), gabor param 0.785, fill param 5, score: 0.8405
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0013 segmented (Tiff n°78), gabor param 0.785, fill param 5, score: 0.833
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0014 segmented (Tiff n°79), gabor param 0.785, fill param 5, score: 0.8373
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0015 segmented (Tiff n°80), gabor param 0.785, fill param 5, score: 0.8681
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0016 segmented (Tiff n°81), gabor param 0.785, fill param 5, score: 0.8072
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0018 segmented (Tiff n°82), gabor param 0.785, fill param 5, score: 0.8264
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0020 segmented (Tiff n°83), gabor param 0.785, fill param 5, score: 0.806
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0021 segmented (Tiff n°84), gabor param 0.785, fill param 5, score: 0.7591
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0022 segmented (Tiff n°85), gabor param 0.785, fill param 5, score: 0.8093
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0023 segmented (Tiff n°86), gabor param 0.785, fill param 5, score: 0.7639
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0025 segmented (Tiff n°87), gabor param 0.785, fill param 5, score: 0.697
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0026 segmented (Tiff n°88), gabor param 0.785, fill param 5, score: 0.7822
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0028 segmented (Tiff n°89), gabor param 0.785, fill param 5, score: 0.7815
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0029 segmented (Tiff n°90), gabor param 0.785, fill param 5, score: 0.8333
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0031 segmented (Tiff n°91), gabor param 0.785, fill param 5, score: 0.7609
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0034 segmented (Tiff n°92), gabor param 0.785, fill param 5, score: 0.7396
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0035 segmented (Tiff n°93), gabor param 0.785, fill param 5, score: 0.8408
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0036 segmented (Tiff n°94), gabor param 0.785, fill param 5, score: 0.7455
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0037 segmented (Tiff n°95), gabor param 0.785, fill param 5, score: 0.7696
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0038 segmented (Tiff n°96), gabor param 0.785, fill param 5, score: 0.789
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0039 segmented (Tiff n°97), gabor param 0.785, fill param 5, score: 0.8129
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0040 segmented (Tiff n°98), gabor param 0.785, fill param 5, score: 0.7768
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0041 segmented (Tiff n°99), gabor param 0.785, fill param 5, score: 0.7828
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0042 segmented (Tiff n°100), gabor param 0.785, fill param 5, score: 0.7645
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0043 segmented (Tiff n°101), gabor param 0.785, fill param 5, score: 0.7737
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0045 segmented (Tiff n°102), gabor param 0.785, fill param 5, score: 0.7787
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0046 segmented (Tiff n°103), gabor param 0.785, fill param 5, score: 0.7817
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0047 segmented (Tiff n°104), gabor param 0.785, fill param 5, score: 0.7635
# CNV_mutiples,CNV_1: Tiff CNV062_096_t48 segmented (Tiff n°105), gabor param 0.785, fill param 5, score: 0.5369
# CNV_mutiples,CNV_1: Tiff CNV062_119_t48 segmented (Tiff n°106), gabor param 0.785, fill param 5, score: 0.4134
# CNV_mutiples,CNV_1: Tiff CNV062_211_t19 segmented (Tiff n°107), gabor param 0.785, fill param 5, score: 0.7292
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_782_t8 segmented (Tiff n°1), gabor param 0.785, fill param 5, score: 0.744
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_787_t8 segmented (Tiff n°2), gabor param 0.785, fill param 5, score: 0.5856
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_793_t8 segmented (Tiff n°3), gabor param 0.785, fill param 5, score: 0.6736
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_065_t1 segmented (Tiff n°4), gabor param 0.785, fill param 5, score: 0.8112
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_066_t24 segmented (Tiff n°5), gabor param 0.785, fill param 5, score: 0.8228
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_067_t1 segmented (Tiff n°6), gabor param 0.785, fill param 5, score: 0.8528
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_095_t31 segmented (Tiff n°7), gabor param 0.785, fill param 5, score: 0.8137
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_095_t49 segmented (Tiff n°8), gabor param 0.785, fill param 5, score: 0.8426
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_111_t31 segmented (Tiff n°9), gabor param 0.785, fill param 5, score: 0.7422
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_111_t49 segmented (Tiff n°10), gabor param 0.785, fill param 5, score: 0.7884
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_137_t31 segmented (Tiff n°11), gabor param 0.785, fill param 5, score: 0.6428
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_137_t49 segmented (Tiff n°12), gabor param 0.785, fill param 5, score: 0.7823
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_156_t31 segmented (Tiff n°13), gabor param 0.785, fill param 5, score: 0.6128
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_156_t49 segmented (Tiff n°14), gabor param 0.785, fill param 5, score: 0.4874
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_205_t1 segmented (Tiff n°15), gabor param 0.785, fill param 5, score: 0.6544
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_205_t25 segmented (Tiff n°16), gabor param 0.785, fill param 5, score: 0.6677
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_221_t49 segmented (Tiff n°17), gabor param 0.785, fill param 5, score: 0.6131
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_409_t1 segmented (Tiff n°18), gabor param 0.785, fill param 5, score: 0.8206
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_409_t49 segmented (Tiff n°19), gabor param 0.785, fill param 5, score: 0.7288
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_410_t1 segmented (Tiff n°20), gabor param 0.785, fill param 5, score: 0.7933
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_108_t23 segmented (Tiff n°21), gabor param 0.785, fill param 5, score: 0.8226
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_108_t25 segmented (Tiff n°22), gabor param 0.785, fill param 5, score: 0.8118
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0001 segmented (Tiff n°23), gabor param 0.785, fill param 5, score: 0.6847
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0002 segmented (Tiff n°24), gabor param 0.785, fill param 5, score: 0.6805
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0003 segmented (Tiff n°25), gabor param 0.785, fill param 5, score: 0.719
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0004 segmented (Tiff n°26), gabor param 0.785, fill param 5, score: 0.6733
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0007 segmented (Tiff n°27), gabor param 0.785, fill param 5, score: 0.7387
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0008 segmented (Tiff n°28), gabor param 0.785, fill param 5, score: 0.7502
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0010 segmented (Tiff n°29), gabor param 0.785, fill param 5, score: 0.7042
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0011 segmented (Tiff n°30), gabor param 0.785, fill param 5, score: 0.6931
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0012 segmented (Tiff n°31), gabor param 0.785, fill param 5, score: 0.6859
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0014 segmented (Tiff n°32), gabor param 0.785, fill param 5, score: 0.6887
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0015 segmented (Tiff n°33), gabor param 0.785, fill param 5, score: 0.6903
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0016 segmented (Tiff n°34), gabor param 0.785, fill param 5, score: 0.7322
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0018 segmented (Tiff n°35), gabor param 0.785, fill param 5, score: 0.7145
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0020 segmented (Tiff n°36), gabor param 0.785, fill param 5, score: 0.672
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0021 segmented (Tiff n°37), gabor param 0.785, fill param 5, score: 0.7064
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0022 segmented (Tiff n°38), gabor param 0.785, fill param 5, score: 0.688
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0023 segmented (Tiff n°39), gabor param 0.785, fill param 5, score: 0.6582
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0024 segmented (Tiff n°40), gabor param 0.785, fill param 5, score: 0.7217
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0025 segmented (Tiff n°41), gabor param 0.785, fill param 5, score: 0.664
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_118_t1 segmented (Tiff n°42), gabor param 0.785, fill param 5, score: 0.7188
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_118_t25 segmented (Tiff n°43), gabor param 0.785, fill param 5, score: 0.6722
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_125_t13 segmented (Tiff n°44), gabor param 0.785, fill param 5, score: 0.7121
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_125_t25 segmented (Tiff n°45), gabor param 0.785, fill param 5, score: 0.7379
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_128_t1 segmented (Tiff n°46), gabor param 0.785, fill param 5, score: 0.6355
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_128_t25 segmented (Tiff n°47), gabor param 0.785, fill param 5, score: 0.829
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_434_t49 segmented (Tiff n°48), gabor param 0.785, fill param 5, score: 0.6335
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_435_t49 segmented (Tiff n°49), gabor param 0.785, fill param 5, score: 0.5572
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_440_t49 segmented (Tiff n°50), gabor param 0.785, fill param 5, score: 0.66
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_441_t49 segmented (Tiff n°51), gabor param 0.785, fill param 5, score: 0.4961
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t1 segmented (Tiff n°52), gabor param 0.785, fill param 5, score: 0.6432
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t25 segmented (Tiff n°53), gabor param 0.785, fill param 5, score: 0.606
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t49 segmented (Tiff n°54), gabor param 0.785, fill param 5, score: 0.5736
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_487_t25 segmented (Tiff n°55), gabor param 0.785, fill param 5, score: 0.7918
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_487_t49 segmented (Tiff n°56), gabor param 0.785, fill param 5, score: 0.6225
# CNV_mutiples,CNV_1: Tiff CNV019_20210904_233_t49 segmented (Tiff n°57), gabor param 0.785, fill param 5, score: 0.711
# CNV_mutiples,CNV_1: Tiff CNV022_016_t25 segmented (Tiff n°58), gabor param 0.785, fill param 5, score: 0.6212
# CNV_mutiples,CNV_1: Tiff CNV022_077_t25 segmented (Tiff n°59), gabor param 0.785, fill param 5, score: 0.6092
# CNV_mutiples,CNV_1: Tiff CNV022_077_t48 segmented (Tiff n°60), gabor param 0.785, fill param 5, score: 0.5235
# CNV_mutiples,CNV_1: Tiff CNV022_077_t49 segmented (Tiff n°61), gabor param 0.785, fill param 5, score: 0.506
# CNV_mutiples,CNV_1: Tiff CNV026_117_t41 segmented (Tiff n°62), gabor param 0.785, fill param 5, score: 0.4779
# CNV_mutiples,CNV_1: Tiff CNV026_119_t41 segmented (Tiff n°63), gabor param 0.785, fill param 5, score: 0.5111
# CNV_mutiples,CNV_1: Tiff CNV026_128_t41 segmented (Tiff n°64), gabor param 0.785, fill param 5, score: 0.5605
# CNV_mutiples,CNV_1: Tiff CNV026_136_t41 segmented (Tiff n°65), gabor param 0.785, fill param 5, score: 0.7064
# CNV_mutiples,CNV_1: Tiff CNV026_138_t41 segmented (Tiff n°66), gabor param 0.785, fill param 5, score: 0.5274
# CNV_mutiples,CNV_1: Tiff CNV028_40_t41 segmented (Tiff n°67), gabor param 0.785, fill param 5, score: 0.5698
# CNV_mutiples,CNV_1: Tiff CNV028_80_t41 segmented (Tiff n°68), gabor param 0.785, fill param 5, score: 0.6716
# CNV_mutiples,CNV_1: Tiff CNV028_82_t41 segmented (Tiff n°69), gabor param 0.785, fill param 5, score: 0.459
# CNV_mutiples,CNV_1: Tiff CNV047_20220520_039_t41 segmented (Tiff n°70), gabor param 0.785, fill param 5, score: 0.6249
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0001 segmented (Tiff n°71), gabor param 0.785, fill param 5, score: 0.8169
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0003 segmented (Tiff n°72), gabor param 0.785, fill param 5, score: 0.8199
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0004 segmented (Tiff n°73), gabor param 0.785, fill param 5, score: 0.8233
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0007 segmented (Tiff n°74), gabor param 0.785, fill param 5, score: 0.8659
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0008 segmented (Tiff n°75), gabor param 0.785, fill param 5, score: 0.8533
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0009 segmented (Tiff n°76), gabor param 0.785, fill param 5, score: 0.8504
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0010 segmented (Tiff n°77), gabor param 0.785, fill param 5, score: 0.8405
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0013 segmented (Tiff n°78), gabor param 0.785, fill param 5, score: 0.833
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0014 segmented (Tiff n°79), gabor param 0.785, fill param 5, score: 0.8373
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0015 segmented (Tiff n°80), gabor param 0.785, fill param 5, score: 0.8681
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0016 segmented (Tiff n°81), gabor param 0.785, fill param 5, score: 0.8072
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0018 segmented (Tiff n°82), gabor param 0.785, fill param 5, score: 0.8264
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0020 segmented (Tiff n°83), gabor param 0.785, fill param 5, score: 0.806
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0021 segmented (Tiff n°84), gabor param 0.785, fill param 5, score: 0.7591
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0022 segmented (Tiff n°85), gabor param 0.785, fill param 5, score: 0.8093
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0023 segmented (Tiff n°86), gabor param 0.785, fill param 5, score: 0.7639
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0025 segmented (Tiff n°87), gabor param 0.785, fill param 5, score: 0.697
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0026 segmented (Tiff n°88), gabor param 0.785, fill param 5, score: 0.7822
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0028 segmented (Tiff n°89), gabor param 0.785, fill param 5, score: 0.7815
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0029 segmented (Tiff n°90), gabor param 0.785, fill param 5, score: 0.8333
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0031 segmented (Tiff n°91), gabor param 0.785, fill param 5, score: 0.7609
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0034 segmented (Tiff n°92), gabor param 0.785, fill param 5, score: 0.7396
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0035 segmented (Tiff n°93), gabor param 0.785, fill param 5, score: 0.8408
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0036 segmented (Tiff n°94), gabor param 0.785, fill param 5, score: 0.7455
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0037 segmented (Tiff n°95), gabor param 0.785, fill param 5, score: 0.7696
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0038 segmented (Tiff n°96), gabor param 0.785, fill param 5, score: 0.789
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0039 segmented (Tiff n°97), gabor param 0.785, fill param 5, score: 0.8129
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0040 segmented (Tiff n°98), gabor param 0.785, fill param 5, score: 0.7768
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0041 segmented (Tiff n°99), gabor param 0.785, fill param 5, score: 0.7828
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0042 segmented (Tiff n°100), gabor param 0.785, fill param 5, score: 0.7645
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0043 segmented (Tiff n°101), gabor param 0.785, fill param 5, score: 0.7737
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0045 segmented (Tiff n°102), gabor param 0.785, fill param 5, score: 0.7787
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0046 segmented (Tiff n°103), gabor param 0.785, fill param 5, score: 0.7817
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0047 segmented (Tiff n°104), gabor param 0.785, fill param 5, score: 0.7635
# CNV_mutiples,CNV_1: Tiff CNV062_096_t48 segmented (Tiff n°105), gabor param 0.785, fill param 5, score: 0.5369
# CNV_mutiples,CNV_1: Tiff CNV062_119_t48 segmented (Tiff n°106), gabor param 0.785, fill param 5, score: 0.4134
# CNV_mutiples,CNV_1: Tiff CNV062_211_t19 segmented (Tiff n°107), gabor param 0.785, fill param 5, score: 0.7292
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_782_t8 segmented (Tiff n°1), gabor param 0.785, fill param 5, score: 0.744
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_787_t8 segmented (Tiff n°2), gabor param 0.785, fill param 5, score: 0.5856
# CNV_mutiples,CNV_1: Tiff CNV006_20210430_793_t8 segmented (Tiff n°3), gabor param 0.785, fill param 5, score: 0.6736
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_065_t1 segmented (Tiff n°4), gabor param 0.785, fill param 5, score: 0.8112
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_066_t24 segmented (Tiff n°5), gabor param 0.785, fill param 5, score: 0.8228
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_067_t1 segmented (Tiff n°6), gabor param 0.785, fill param 5, score: 0.8528
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_095_t31 segmented (Tiff n°7), gabor param 0.785, fill param 5, score: 0.8137
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_095_t49 segmented (Tiff n°8), gabor param 0.785, fill param 5, score: 0.8426
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_111_t31 segmented (Tiff n°9), gabor param 0.785, fill param 5, score: 0.7422
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_111_t49 segmented (Tiff n°10), gabor param 0.785, fill param 5, score: 0.7884
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_137_t31 segmented (Tiff n°11), gabor param 0.785, fill param 5, score: 0.6428
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_137_t49 segmented (Tiff n°12), gabor param 0.785, fill param 5, score: 0.7823
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_156_t31 segmented (Tiff n°13), gabor param 0.785, fill param 5, score: 0.6128
# CNV_mutiples,CNV_1: Tiff CNV010_20210606_156_t49 segmented (Tiff n°14), gabor param 0.785, fill param 5, score: 0.4874
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_205_t1 segmented (Tiff n°15), gabor param 0.785, fill param 5, score: 0.6544
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_205_t25 segmented (Tiff n°16), gabor param 0.785, fill param 5, score: 0.6677
# CNV_mutiples,CNV_1: Tiff CNV011_20210612_221_t49 segmented (Tiff n°17), gabor param 0.785, fill param 5, score: 0.6131
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_409_t1 segmented (Tiff n°18), gabor param 0.785, fill param 5, score: 0.8206
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_409_t49 segmented (Tiff n°19), gabor param 0.785, fill param 5, score: 0.7288
# CNV_mutiples,CNV_1: Tiff CNV012_20210618_410_t1 segmented (Tiff n°20), gabor param 0.785, fill param 5, score: 0.7933
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_108_t23 segmented (Tiff n°21), gabor param 0.785, fill param 5, score: 0.8226
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_108_t25 segmented (Tiff n°22), gabor param 0.785, fill param 5, score: 0.8118
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0001 segmented (Tiff n°23), gabor param 0.785, fill param 5, score: 0.6847
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0002 segmented (Tiff n°24), gabor param 0.785, fill param 5, score: 0.6805
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0003 segmented (Tiff n°25), gabor param 0.785, fill param 5, score: 0.719
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0004 segmented (Tiff n°26), gabor param 0.785, fill param 5, score: 0.6733
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0007 segmented (Tiff n°27), gabor param 0.785, fill param 5, score: 0.7387
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0008 segmented (Tiff n°28), gabor param 0.785, fill param 5, score: 0.7502
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0010 segmented (Tiff n°29), gabor param 0.785, fill param 5, score: 0.7042
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0011 segmented (Tiff n°30), gabor param 0.785, fill param 5, score: 0.6931
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0012 segmented (Tiff n°31), gabor param 0.785, fill param 5, score: 0.6859
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0014 segmented (Tiff n°32), gabor param 0.785, fill param 5, score: 0.6887
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0015 segmented (Tiff n°33), gabor param 0.785, fill param 5, score: 0.6903
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0016 segmented (Tiff n°34), gabor param 0.785, fill param 5, score: 0.7322
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0018 segmented (Tiff n°35), gabor param 0.785, fill param 5, score: 0.7145
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0020 segmented (Tiff n°36), gabor param 0.785, fill param 5, score: 0.672
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0021 segmented (Tiff n°37), gabor param 0.785, fill param 5, score: 0.7064
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0022 segmented (Tiff n°38), gabor param 0.785, fill param 5, score: 0.688
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0023 segmented (Tiff n°39), gabor param 0.785, fill param 5, score: 0.6582
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0024 segmented (Tiff n°40), gabor param 0.785, fill param 5, score: 0.7217
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_110_25-0025 segmented (Tiff n°41), gabor param 0.785, fill param 5, score: 0.664
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_118_t1 segmented (Tiff n°42), gabor param 0.785, fill param 5, score: 0.7188
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_118_t25 segmented (Tiff n°43), gabor param 0.785, fill param 5, score: 0.6722
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_125_t13 segmented (Tiff n°44), gabor param 0.785, fill param 5, score: 0.7121
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_125_t25 segmented (Tiff n°45), gabor param 0.785, fill param 5, score: 0.7379
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_128_t1 segmented (Tiff n°46), gabor param 0.785, fill param 5, score: 0.6355
# CNV_mutiples,CNV_1: Tiff CNV015_20210717_128_t25 segmented (Tiff n°47), gabor param 0.785, fill param 5, score: 0.829
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_434_t49 segmented (Tiff n°48), gabor param 0.785, fill param 5, score: 0.6335
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_435_t49 segmented (Tiff n°49), gabor param 0.785, fill param 5, score: 0.5572
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_440_t49 segmented (Tiff n°50), gabor param 0.785, fill param 5, score: 0.66
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_441_t49 segmented (Tiff n°51), gabor param 0.785, fill param 5, score: 0.4961
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t1 segmented (Tiff n°52), gabor param 0.785, fill param 5, score: 0.6432
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t25 segmented (Tiff n°53), gabor param 0.785, fill param 5, score: 0.606
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_442_t49 segmented (Tiff n°54), gabor param 0.785, fill param 5, score: 0.5736
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_487_t25 segmented (Tiff n°55), gabor param 0.785, fill param 5, score: 0.7918
# CNV_mutiples,CNV_1: Tiff CNV016_20210804_487_t49 segmented (Tiff n°56), gabor param 0.785, fill param 5, score: 0.6225
# CNV_mutiples,CNV_1: Tiff CNV019_20210904_233_t49 segmented (Tiff n°57), gabor param 0.785, fill param 5, score: 0.711
# CNV_mutiples,CNV_1: Tiff CNV022_016_t25 segmented (Tiff n°58), gabor param 0.785, fill param 5, score: 0.6212
# CNV_mutiples,CNV_1: Tiff CNV022_077_t25 segmented (Tiff n°59), gabor param 0.785, fill param 5, score: 0.6092
# CNV_mutiples,CNV_1: Tiff CNV022_077_t48 segmented (Tiff n°60), gabor param 0.785, fill param 5, score: 0.5235
# CNV_mutiples,CNV_1: Tiff CNV022_077_t49 segmented (Tiff n°61), gabor param 0.785, fill param 5, score: 0.506
# CNV_mutiples,CNV_1: Tiff CNV026_117_t41 segmented (Tiff n°62), gabor param 0.785, fill param 5, score: 0.4779
# CNV_mutiples,CNV_1: Tiff CNV026_119_t41 segmented (Tiff n°63), gabor param 0.785, fill param 5, score: 0.5111
# CNV_mutiples,CNV_1: Tiff CNV026_128_t41 segmented (Tiff n°64), gabor param 0.785, fill param 5, score: 0.5605
# CNV_mutiples,CNV_1: Tiff CNV026_136_t41 segmented (Tiff n°65), gabor param 0.785, fill param 5, score: 0.7064
# CNV_mutiples,CNV_1: Tiff CNV026_138_t41 segmented (Tiff n°66), gabor param 0.785, fill param 5, score: 0.5274
# CNV_mutiples,CNV_1: Tiff CNV028_40_t41 segmented (Tiff n°67), gabor param 0.785, fill param 5, score: 0.5698
# CNV_mutiples,CNV_1: Tiff CNV028_80_t41 segmented (Tiff n°68), gabor param 0.785, fill param 5, score: 0.6716
# CNV_mutiples,CNV_1: Tiff CNV028_82_t41 segmented (Tiff n°69), gabor param 0.785, fill param 5, score: 0.459
# CNV_mutiples,CNV_1: Tiff CNV047_20220520_039_t41 segmented (Tiff n°70), gabor param 0.785, fill param 5, score: 0.6249
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0001 segmented (Tiff n°71), gabor param 0.785, fill param 5, score: 0.8169
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0003 segmented (Tiff n°72), gabor param 0.785, fill param 5, score: 0.8199
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0004 segmented (Tiff n°73), gabor param 0.785, fill param 5, score: 0.8233
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0007 segmented (Tiff n°74), gabor param 0.785, fill param 5, score: 0.8659
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0008 segmented (Tiff n°75), gabor param 0.785, fill param 5, score: 0.8533
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0009 segmented (Tiff n°76), gabor param 0.785, fill param 5, score: 0.8504
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0010 segmented (Tiff n°77), gabor param 0.785, fill param 5, score: 0.8405
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0013 segmented (Tiff n°78), gabor param 0.785, fill param 5, score: 0.833
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0014 segmented (Tiff n°79), gabor param 0.785, fill param 5, score: 0.8373
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0015 segmented (Tiff n°80), gabor param 0.785, fill param 5, score: 0.8681
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0016 segmented (Tiff n°81), gabor param 0.785, fill param 5, score: 0.8072
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0018 segmented (Tiff n°82), gabor param 0.785, fill param 5, score: 0.8264
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0020 segmented (Tiff n°83), gabor param 0.785, fill param 5, score: 0.806
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0021 segmented (Tiff n°84), gabor param 0.785, fill param 5, score: 0.7591
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0022 segmented (Tiff n°85), gabor param 0.785, fill param 5, score: 0.8093
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0023 segmented (Tiff n°86), gabor param 0.785, fill param 5, score: 0.7639
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0025 segmented (Tiff n°87), gabor param 0.785, fill param 5, score: 0.697
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0026 segmented (Tiff n°88), gabor param 0.785, fill param 5, score: 0.7822
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0028 segmented (Tiff n°89), gabor param 0.785, fill param 5, score: 0.7815
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0029 segmented (Tiff n°90), gabor param 0.785, fill param 5, score: 0.8333
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0031 segmented (Tiff n°91), gabor param 0.785, fill param 5, score: 0.7609
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0034 segmented (Tiff n°92), gabor param 0.785, fill param 5, score: 0.7396
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0035 segmented (Tiff n°93), gabor param 0.785, fill param 5, score: 0.8408
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0036 segmented (Tiff n°94), gabor param 0.785, fill param 5, score: 0.7455
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0037 segmented (Tiff n°95), gabor param 0.785, fill param 5, score: 0.7696
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0038 segmented (Tiff n°96), gabor param 0.785, fill param 5, score: 0.789
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0039 segmented (Tiff n°97), gabor param 0.785, fill param 5, score: 0.8129
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0040 segmented (Tiff n°98), gabor param 0.785, fill param 5, score: 0.7768
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0041 segmented (Tiff n°99), gabor param 0.785, fill param 5, score: 0.7828
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0042 segmented (Tiff n°100), gabor param 0.785, fill param 5, score: 0.7645
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0043 segmented (Tiff n°101), gabor param 0.785, fill param 5, score: 0.7737
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0045 segmented (Tiff n°102), gabor param 0.785, fill param 5, score: 0.7787
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0046 segmented (Tiff n°103), gabor param 0.785, fill param 5, score: 0.7817
# CNV_mutiples,CNV_1: Tiff CNV049_20220610_200-0047 segmented (Tiff n°104), gabor param 0.785, fill param 5, score: 0.7635
# CNV_mutiples,CNV_1: Tiff CNV062_096_t48 segmented (Tiff n°105), gabor param 0.785, fill param 5, score: 0.5369
# CNV_mutiples,CNV_1: Tiff CNV062_119_t48 segmented (Tiff n°106), gabor param 0.785, fill param 5, score: 0.4134
# CNV_mutiples,CNV_1: Tiff CNV062_211_t19 segmented (Tiff n°107), gabor param 0.785, fill param 5, score: 0.7292
#    gabor_param  fill_param  Min_pixels  Dice scores
# 0        0.785           5        3600     0.711992
# 1        0.785           5        3650     0.711992
# 2        0.785           5        3700     0.711992
# 3        0.785           5        3750     0.711992
# 4        0.785           5        3800     0.711992

# %% [markdown]
# ## Predict on Test set with best hyperparameters

# %%
file_dir = '/Users/clemence/Documents_Clémence/Analysis/Tracking algorithm/Tracking-seg_Aaron-Gus_CNV/230113-CNV-optimization/test' # change this into your own path
image_files_name = 'Source images'
mask_files_name = 'Masks'
#dice_scores = np.array(list(create_masks(file_dir,image_files_name,mask_files_name,gabor_parameter=0.78,fill_cells=5,thresh_small_objects=3700,save_predicted_mask=True,compute_score=True).values()))
dice_scores = np.array(list(create_masks(file_dir,image_files_name,mask_files_name,gabor_parameter=0.785,fill_cells=5,thresh_small_objects=3700,save_predicted_mask=True,compute_score=True).values()))

print('The mean of all the dice scores on the test set is :')
print(dice_scores.mean())
print ('The standard deviation of all the dice scores on the test set is')
print(dice_scores.std())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [17], line 5
#       3 mask_files_name = 'Masks'
#       4 #dice_scores = np.array(list(create_masks(file_dir,image_files_name,mask_files_name,gabor_parameter=0.78,fill_cells=5,thresh_small_objects=3700,save_predicted_mask=True,compute_score=True).values()))
# ----> 5 dice_scores = np.array(list(create_masks(file_dir,image_files_name,mask_files_name,gabor_parameter=0.785,fill_cells=5,save_predicted_mask=True,compute_score=True).values()))
#       7 print('The mean of all the dice scores on the test set is :')
#       8 print(dice_scores.mean())
#
# Cell In [8], line 3, in create_masks(file_dir, image_files_name, mask_files_name, gabor_parameter, fill_cells, experiment_name, save_predicted_mask, compute_score, ratio_first_thresh, ratio_small_object_thresh, ratio_thresh_big_objects, ratio_canal_diameter)
#       1 def create_masks(file_dir,image_files_name,mask_files_name,gabor_parameter,fill_cells,experiment_name='CNV',save_predicted_mask=True,compute_score=True,ratio_first_thresh=300/(1920*1440),ratio_small_object_thresh=3700/(1920*1440),ratio_thresh_big_objects=30000/(1920*1440),ratio_canal_diameter=100/1440 ):
# ----> 3     experiment_types_dir = [  "".join([file_dir,'/',f]) for f in natsorted(os.listdir(file_dir)) if experiment_name in f]
#       5     if compute_score :
#       6         score_experiment=dict()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/aaronmamann/Desktop/Cleaned_Datasets_Clemence/Validation/test'
